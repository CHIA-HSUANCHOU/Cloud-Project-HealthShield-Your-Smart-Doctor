# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import json
import xgboost as xgb
from sklearn.model_selection import ParameterSampler, train_test_split, GridSearchCV, StratifiedKFold, ParameterGrid
from scipy.stats import uniform, randint
from xgboost import XGBClassifier
from sklearn.ensemble import  RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics import (
    accuracy_score, confusion_matrix, roc_auc_score, roc_curve, auc,
    precision_score, recall_score, f1_score, classification_report, balanced_accuracy_score
)
from sklearn.svm import SVC
from itertools import product
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm

# %%
df = pd.read_csv('ALL_NHANES_MERGED_20072018.csv')

# %%
df = df.rename(columns={
    "SEQN": "ID",
    "DIQ010": "diabetes",
    "RIDAGEYR": "age",
    "RIAGENDR":"gender",

    "BMXHT": "height_cm",
    "BMXWT": "weight_kg",
    "BMXBMI": "bmi",
    "BMXWAIST": "waist_cm",

    "BPXSY1":"systolic1",
    "BPXDI1":"diastolic1",
    "BPXSY2":"systolic2",
    "BPXDI2":"diastolic2",
    "BPXSY3":"systolic3",
    "BPXDI3":"diastolic3",

    "LBXGLU":"glucose_fast",
    "LBXIN":"insulin",
    "LBXGH":"HbA1c",
    "LBXTC":"cholesterol_total",
    "LBDHDD":"hdl",
    "LBDLDL":"ldl",
    "LBXTR":"triglycerides",

    "SMQ020": "ever_smoked",
    "MCQ300C": "family_diabetes",
    "ALQ130":"alcohol_drink",
    "PAQ665":"moderate_excercise",
    "PAQ650":"serious_excercise",
    "SLD012":"sleep_time",
    "HUQ010":"health_score"
})

# %%
# 先確保欄位是數值型態，才能比較 < 1e-10
# 假設所有相關欄位在重命名後都是字串，需要先轉為數值：
for col in ["systolic1", "diastolic1", "systolic2", "diastolic2", "systolic3", "diastolic3", "age"]:
    df[col] = pd.to_numeric(df[col], errors='coerce') 

# 定義要檢查的血壓和年齡欄位
columns_to_check = ['diastolic1', 'diastolic2', 'diastolic3', 'age'] 

# 對這些欄位中極小的數值賦予 NaN (代表可能是 LOD 或錯誤值)
# 這會將整個 df 中滿足條件的儲存格設為 NaN
df[columns_to_check] = df[columns_to_check].mask(df[columns_to_check].lt(1e-10))

# %%
print(df.head())
# Out:
#         ID  diabetes   age  gender  height_cm  weight_kg    bmi  waist_cm  \
# 0  41475.0       2.0  62.0     2.0      154.7      138.9  58.04     156.3
# 1  41476.0       2.0   6.0     2.0      120.4       22.0  15.18      52.7
# 2  41477.0       1.0  71.0     1.0      167.1       83.9  30.05     109.5
# 3  41478.0       2.0   1.0     2.0        NaN       11.5    NaN       NaN
# 4  41479.0       2.0  52.0     1.0      154.4       65.7  27.56      95.4
#
#    systolic1  diastolic1  ...    ldl  triglycerides  ever_smoked  \
# 0      128.0        64.0  ...    NaN            NaN          2.0
# 1        NaN         NaN  ...    NaN            NaN          NaN
# 2      144.0        60.0  ...    NaN            NaN          1.0
# 3        NaN         NaN  ...    NaN            NaN          NaN
# 4      112.0        70.0  ...  121.0           99.0          2.0
#
#    family_diabetes  alcohol_drink  moderate_excercise  serious_excercise  \
# 0              1.0            NaN                 2.0                2.0
# 1              NaN            NaN                 NaN                NaN
# 2              2.0            NaN                 2.0                2.0
# 3              NaN            NaN                 NaN                NaN
# 4              2.0            5.0                 2.0                2.0
#
#    sleep_time  health_score    Source
# 0         6.0           4.0  20072008
# 1         NaN           1.0  20072008
# 2         8.0           3.0  20072008
# 3         NaN           3.0  20072008
# 4         6.0           3.0  20072008
#
# [5 rows x 29 columns]

# %% [markdown]
# #### NHANES原始代碼：

# %%
# 3. 目標變數 'diabetes' 的清洗與轉換
# 將 'diabetes' 欄位轉為數值 (原本可能是 '1.0', '2.0', '3.0' 字串)
df["diabetes"] = pd.to_numeric(df["diabetes"], errors='coerce')

# 篩選掉 'diabetes' 為 NaN 的樣本
df = df[df["diabetes"].notna()].copy() 

# 篩選掉 'diabetes' 為 3.0 的樣本 (移除不確定或邊緣類別)
# 由於已經轉為數值，與 3.0 比較
df = df[df["diabetes"] != 3.0].copy() 

# 將 'diabetes' 中表示「沒有糖尿病」的數值 2.0 更改為 0.0 (二元化)
df.loc[df["diabetes"] == 2.0, "diabetes"] = 0.0

# %%
print(sum(df["diabetes"]==0.0))
print(sum(df["diabetes"]==1.0))
# Out:
# 51753
# 4710

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56463 entries, 0 to 57380
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  56463 non-null  float64
#  1   diabetes            56463 non-null  float64
#  2   age                 56463 non-null  float64
#  3   gender              56463 non-null  float64
#  4   height_cm           51889 non-null  float64
#  5   weight_kg           53553 non-null  float64
#  6   bmi                 51821 non-null  float64
#  7   waist_cm            49463 non-null  float64
#  8   systolic1           41252 non-null  float64
#  9   diastolic1          40774 non-null  float64
#  10  systolic2           41818 non-null  float64
#  11  diastolic2          41211 non-null  float64
#  12  systolic3           41663 non-null  float64
#  13  diastolic3          40956 non-null  float64
#  14  glucose_fast        18164 non-null  float64
#  15  insulin             17735 non-null  float64
#  16  HbA1c               37696 non-null  float64
#  17  cholesterol_total   43008 non-null  float64
#  18  hdl                 43009 non-null  float64
#  19  ldl                 17513 non-null  float64
#  20  triglycerides       17754 non-null  float64
#  21  ever_smoked         34808 non-null  float64
#  22  family_diabetes     33261 non-null  float64
#  23  alcohol_drink       20311 non-null  float64
#  24  moderate_excercise  40464 non-null  float64
#  25  serious_excercise   40468 non-null  float64
#  26  sleep_time          37572 non-null  float64
#  27  health_score        56437 non-null  float64
#  28  Source              56463 non-null  int64
# dtypes: float64(28), int64(1)
# memory usage: 12.9 MB
# None

# %%
seed = 2025
# 假設 'Diagnosis' 是目標欄位（請依你資料中的實際欄位名調整）
X = df.drop(columns=['ID',"diabetes", "Source"])
# 將目標變數從浮點數 (float) 轉換為整數 (int)
y = df['diabetes'].astype(int)

# Step 1: 先切出 20% 的測試資料
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=seed
)

# 檢查比例
print(f"Train: {len(X_train)} samples")
print(f"Test: {len(X_test)} samples")
# Out:
# Train: 45170 samples
# Test: 11293 samples

# %%
from collections import Counter
def print_class_distribution(name, y):
    counter = Counter(y)
    total = len(y)
    print(f"{name} Set Class Distribution:")
    for cls, count in counter.items():
        print(f"Class {cls}: {count} samples ({count / total:.2%})")
    print()

# 顯示類別比例
print_class_distribution("Train", y_train)
print_class_distribution("Test", y_test)
# Out:
# Train Set Class Distribution:
# Class 0: 41402 samples (91.66%)
# Class 1: 3768 samples (8.34%)
#
# Test Set Class Distribution:
# Class 0: 10351 samples (91.66%)
# Class 1: 942 samples (8.34%)

# %% [markdown]
# # Data Preprocessing Pipeline

# %%
# 三個 systolic 欄位
sys_cols = ["systolic1", "systolic2", "systolic3"]

# 三個 diastolic 欄位
dia_cols = ["diastolic1", "diastolic2", "diastolic3"]

def missing_pattern_report(df, cols, name=""):
    # 計算每列缺失數量
    missing_count = df[cols].isna().sum(axis=1)

    total = len(df)

    report = {
        "all_missing (3/3)": (missing_count == 3).sum(),
        "two_missing (2/3)": (missing_count == 2).sum(),
        "one_missing (1/3)": (missing_count == 1).sum(),
        "none_missing (0/3)": (missing_count == 0).sum(),
    }

    # 轉成比例
    report_pct = {k: f"{v} ({v/total*100:.2f}%)" for k, v in report.items()}

    print(f"\n=== Missing Report for {name} ===")
    for k, v in report_pct.items():
        print(f"{k}: {v}")

    return report_pct


# 對 systolic 舒張壓做報告
sys_report = missing_pattern_report(X_train, sys_cols, name="Systolic BP")
dia_report = missing_pattern_report(X_train, dia_cols, name="Diastolic BP")
# Out:
# === Missing Report for Systolic BP ===
# all_missing (3/3): 10825 (23.97%)
# two_missing (2/3): 671 (1.49%)
# one_missing (1/3): 2023 (4.48%)
# none_missing (0/3): 31651 (70.07%)
#
# === Missing Report for Diastolic BP ===
# all_missing (3/3): 11046 (24.45%)
# two_missing (2/3): 869 (1.92%)
# one_missing (1/3): 2378 (5.26%)
# none_missing (0/3): 30877 (68.36%)

# %%
## height/weight/bmi
def fill_height_weight_bmi_partial(df):
    h = df["height_cm"]
    w = df["weight_kg"]
    b = df["bmi"]

    # 補 BMI：有身高與體重，但 BMI 缺
    mask_bmi_missing = b.isna() & h.notna() & w.notna()
    df.loc[mask_bmi_missing, "bmi"] = df.loc[mask_bmi_missing, "weight_kg"] / (df.loc[mask_bmi_missing, "height_cm"] / 100) ** 2

    # 補體重：有身高與 BMI，但體重缺
    mask_weight_missing = w.isna() & h.notna() & b.notna()
    df.loc[mask_weight_missing, "weight_kg"] = df.loc[mask_weight_missing, "bmi"] * (df.loc[mask_weight_missing, "height_cm"] / 100) ** 2

    # 補身高：有體重與 BMI，但身高缺
    mask_height_missing = h.isna() & w.notna() & b.notna()
    df.loc[mask_height_missing, "height_cm"] = np.sqrt(df.loc[mask_height_missing, "weight_kg"] / df.loc[mask_height_missing, "bmi"]) * 100

    return df

def fill_remaining_height_weight_bmi(df, median_height, median_weight):
    # === 情況 1: height_weight_missing (身高 + 體重缺，BMI 有值) ===
    mask_height_weight_missing = df["height_cm"].isna() & df["weight_kg"].isna() & df["bmi"].notna()
    df.loc[mask_height_weight_missing, "weight_kg"] = median_weight
    # 使用填補後的體重 & 現有 BMI 算出身高
    df.loc[mask_height_weight_missing, "height_cm"] = np.sqrt(
        df.loc[mask_height_weight_missing, "weight_kg"] / df.loc[mask_height_weight_missing, "bmi"]
    ) * 100

    # === 情況 2: height_bmi_missing (身高 + BMI 缺) ===
    mask_height_bmi_missing = df["height_cm"].isna() & df["weight_kg"].notna() & df["bmi"].isna()
    df.loc[mask_height_bmi_missing, "height_cm"] = median_height
    # 使用補完的身高 & 現有體重計算 BMI
    df.loc[mask_height_bmi_missing, "bmi"] = df.loc[mask_height_bmi_missing, "weight_kg"] / (
        (df.loc[mask_height_bmi_missing, "height_cm"] / 100) ** 2
    )

    # === 情況 3: weight_bmi_missing (體重 + BMI 缺) ===
    mask_weight_bmi_missing = df["weight_kg"].isna() & df["height_cm"].notna() & df["bmi"].isna()
    df.loc[mask_weight_bmi_missing, "weight_kg"] = median_weight
    # 使用補完的體重 & 現有身高計算 BMI
    df.loc[mask_weight_bmi_missing, "bmi"] = df.loc[mask_weight_bmi_missing, "weight_kg"] / (
        (df.loc[mask_weight_bmi_missing, "height_cm"] / 100) ** 2
    )

    # === 情況 4: all_missing (全部缺) ===
    mask_all_missing = df["height_cm"].isna() & df["weight_kg"].isna() & df["bmi"].isna()
    df.loc[mask_all_missing, "height_cm"] = median_height
    df.loc[mask_all_missing, "weight_kg"] = median_weight
    df.loc[mask_all_missing, "bmi"] = df.loc[mask_all_missing, "weight_kg"] / (
        (df.loc[mask_all_missing, "height_cm"] / 100) ** 2
    )

    return df


# 1. 先補 X_train 的 height/weight/bmi 的可推情況（不補中位數）
X_train = fill_height_weight_bmi_partial(X_train)

# 2. 現在再算中位數
train_median_height = X_train["height_cm"].median()
train_median_weight = X_train["weight_kg"].median()

# 3. 補剩下缺的欄位
X_train = fill_remaining_height_weight_bmi(X_train, train_median_height, train_median_weight)

# 4. 用同樣中位數去補 X_test
X_test = fill_height_weight_bmi_partial(X_test)
X_test = fill_remaining_height_weight_bmi(X_test, train_median_height, train_median_weight)

# 假設欄位已重命名並轉為數值
systolic_cols = ['systolic1', 'systolic2', 'systolic3']
diastolic_cols = ['diastolic1', 'diastolic2', 'diastolic3']
X_train['systolic_avg'] = X_train[systolic_cols].mean(axis=1)
X_test['systolic_avg']  = X_test[systolic_cols].mean(axis=1)

X_train['diastolic_avg'] = X_train[diastolic_cols].mean(axis=1)
X_test['diastolic_avg']  = X_test[diastolic_cols].mean(axis=1)

# 年齡 >= 20 → 用中位數補
alcohol_median = X_train.loc[X_train["age"] >= 20, "alcohol_drink"].median()

X_train.loc[X_train["age"] < 20, "alcohol_drink"] = X_train.loc[X_train["age"] < 20, "alcohol_drink"].fillna(0)
X_test.loc[X_test["age"] < 20, "alcohol_drink"] = X_test.loc[X_test["age"] < 20, "alcohol_drink"].fillna(0)

X_train["alcohol_drink"] = X_train["alcohol_drink"].fillna(alcohol_median)
X_test["alcohol_drink"] = X_test["alcohol_drink"].fillna(alcohol_median)

## 中位數填補
# 1. 定義要補的欄位
median_fill_columns = [
    "age", "waist_cm", "glucose_fast", "insulin", "HbA1c", "cholesterol_total", "hdl", "ldl", "triglycerides",
    "sleep_time", "health_score", 'systolic_avg', 'diastolic_avg'
]


# 2. 根據 X_train 計算中位數
train_medians = X_train[median_fill_columns].median()

# 3. 使用中位數填補缺失
X_train[median_fill_columns] = X_train[median_fill_columns].fillna(train_medians)
X_test[median_fill_columns] = X_test[median_fill_columns].fillna(train_medians)


X_train.loc[X_train["age"] < 20, "ever_smoked"] = X_train.loc[X_train["age"] < 20, "ever_smoked"].fillna(2)
X_test.loc[X_test["age"] < 20, "ever_smoked"] = X_test.loc[X_test["age"] < 20, "ever_smoked"].fillna(2)

# 其他類別型欄位（排除 wheezing_sleep）
other_categorical = [
    "ever_smoked", "family_diabetes","moderate_excercise", "serious_excercise"
]

X_train[other_categorical] = X_train[other_categorical].fillna(3)
X_test[other_categorical] = X_test[other_categorical].fillna(3)

all_bp_cols = systolic_cols + diastolic_cols
X_train = X_train.drop(columns=all_bp_cols)
X_test = X_test.drop(columns=all_bp_cols)

# %%
def missing_report(df):
    missing_count = df.isnull().sum()
    missing_pct = (missing_count / len(df)) * 100
    report = pd.DataFrame({
        'MissingCount': missing_count,
        'MissingPercent': missing_pct
    }).sort_values(by='MissingPercent', ascending=False)
    report = report[report['MissingPercent'] > 0]
    return report
print("\n=== Training Set Missing Value Report ===")
print(missing_report(X_train))


print("\n=== Test Set Missing Value Report ===")
print(missing_report(X_test))
# Out:
# === Training Set Missing Value Report ===
# Empty DataFrame
# Columns: [MissingCount, MissingPercent]
# Index: []
#
# === Test Set Missing Value Report ===
# Empty DataFrame
# Columns: [MissingCount, MissingPercent]
# Index: []

# %%
print(X_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45170 entries, 9986 to 47610
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 45170 non-null  float64
#  1   gender              45170 non-null  float64
#  2   height_cm           45170 non-null  float64
#  3   weight_kg           45170 non-null  float64
#  4   bmi                 45170 non-null  float64
#  5   waist_cm            45170 non-null  float64
#  6   glucose_fast        45170 non-null  float64
#  7   insulin             45170 non-null  float64
#  8   HbA1c               45170 non-null  float64
#  9   cholesterol_total   45170 non-null  float64
#  10  hdl                 45170 non-null  float64
#  11  ldl                 45170 non-null  float64
#  12  triglycerides       45170 non-null  float64
#  13  ever_smoked         45170 non-null  float64
#  14  family_diabetes     45170 non-null  float64
#  15  alcohol_drink       45170 non-null  float64
#  16  moderate_excercise  45170 non-null  float64
#  17  serious_excercise   45170 non-null  float64
#  18  sleep_time          45170 non-null  float64
#  19  health_score        45170 non-null  float64
#  20  systolic_avg        45170 non-null  float64
#  21  diastolic_avg       45170 non-null  float64
# dtypes: float64(22)
# memory usage: 7.9 MB
# None

# %%
print(X_train.head())
# Out:
#         age  gender  height_cm  weight_kg        bmi  waist_cm  glucose_fast  \
# 9986    9.0     2.0      132.6       33.9  19.280000      66.7          99.0
# 33272  40.0     1.0      179.8      101.5  31.400000      94.6          93.0
# 7086    8.0     1.0      141.4       34.3  17.160000      58.6          99.0
# 15800   1.0     2.0      161.9       12.5   4.768879      88.5          99.0
# 49867   3.0     1.0      100.1       16.2  16.200000      88.5          99.0
#
#        insulin  HbA1c  cholesterol_total  ...  triglycerides  ever_smoked  \
# 9986     10.16    5.5              144.0  ...           94.0          2.0
# 33272     7.43    5.2              153.0  ...           64.0          1.0
# 7086     10.16    5.5              152.0  ...           94.0          2.0
# 15800    10.16    5.5              178.0  ...           94.0          2.0
# 49867    10.16    5.5              178.0  ...           94.0          2.0
#
#        family_diabetes  alcohol_drink  moderate_excercise  serious_excercise  \
# 9986               3.0            0.0                 3.0                3.0
# 33272              1.0            2.0                 1.0                1.0
# 7086               3.0            0.0                 3.0                3.0
# 15800              3.0            0.0                 3.0                3.0
# 49867              3.0            0.0                 3.0                3.0
#
#        sleep_time  health_score  systolic_avg  diastolic_avg
# 9986          7.0           1.0     90.666667      37.333333
# 33272         7.0           3.0    107.333333      69.333333
# 7086          7.0           1.0     98.000000      46.000000
# 15800         7.0           1.0    116.000000      67.333333
# 49867         7.0           3.0    116.000000      67.333333
#
# [5 rows x 22 columns]

# %%
print(X_test.head())
# Out:
#         age  gender  height_cm  weight_kg    bmi  waist_cm  glucose_fast  \
# 48569  20.0     1.0      165.2      100.6  36.90     110.5          99.0
# 18733  65.0     1.0      175.2      100.0  32.58     116.4          99.0
# 26803  20.0     1.0      170.6       84.4  29.00      93.4         105.0
# 22057   7.0     2.0      121.2       28.9  19.70      64.5          99.0
# 5777    7.0     2.0      133.8       41.1  22.96      81.4          99.0
#
#        insulin  HbA1c  cholesterol_total  ...  triglycerides  ever_smoked  \
# 48569    10.16    5.1              229.0  ...           94.0          2.0
# 18733    10.16    8.7              160.0  ...           94.0          1.0
# 26803     8.58    5.0              218.0  ...          119.0          1.0
# 22057    10.16    5.5              160.0  ...           94.0          2.0
# 5777     10.16    5.5              119.0  ...           94.0          2.0
#
#        family_diabetes  alcohol_drink  moderate_excercise  serious_excercise  \
# 48569              1.0            3.0                 2.0                1.0
# 18733              1.0            1.0                 2.0                2.0
# 26803              1.0            2.0                 2.0                1.0
# 22057              3.0            0.0                 3.0                3.0
# 5777               3.0            0.0                 3.0                3.0
#
#        sleep_time  health_score  systolic_avg  diastolic_avg
# 48569         8.0           4.0    132.666667      94.666667
# 18733         7.0           4.0    100.000000      50.666667
# 26803         8.0           4.0    118.666667      62.000000
# 22057         7.0           3.0    116.000000      67.333333
# 5777          7.0           4.0    116.000000      67.333333
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Preprocessing

# %%
minmax_columns = [
    "age", "height_cm", "weight_kg", "bmi",
    "waist_cm", "glucose_fast", "insulin", "HbA1c", "cholesterol_total", "hdl", "ldl", "triglycerides",
    "alcohol_drink", "sleep_time", "health_score", 'systolic_avg', 'diastolic_avg'
]

onehot_columns = [
    "gender", "ever_smoked", "family_diabetes","moderate_excercise", "serious_excercise"
]

# MinMax normalization
scaler = MinMaxScaler()
X_train[minmax_columns] = scaler.fit_transform(X_train[minmax_columns])
X_test[minmax_columns] = scaler.transform(X_test[minmax_columns])

for col in onehot_columns:
    X_train[col] = X_train[col].astype(str)
    X_test[col] = X_test[col].astype(str)

# One-Hot Encoding
X_train = pd.get_dummies(X_train, columns=onehot_columns)
X_test = pd.get_dummies(X_test, columns=onehot_columns)

# 補齊測試集欄位
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# 確保所有 one-hot 欄位為 int 而非 bool
X_train = X_train.astype({col: int for col in X_train.select_dtypes(bool).columns})
X_test = X_test.astype({col: int for col in X_test.select_dtypes(bool).columns})
print(X_train.head())
print(X_test.head())
# Out:
#             age  height_cm  weight_kg       bmi  waist_cm  glucose_fast  \
# 9986   0.101266   0.429365   0.118026  0.204278  0.204674      0.138544
# 33272  0.493671   0.803968   0.408155  0.351315  0.402266      0.127886
# 7086   0.088608   0.499206   0.119742  0.178559  0.147309      0.138544
# 15800  0.000000   0.661905   0.026180  0.028233  0.359065      0.138544
# 49867  0.025316   0.171429   0.042060  0.166913  0.359065      0.138544
#
#         insulin     HbA1c  cholesterol_total       hdl  ...  ever_smoked_3.0  \
# 9986   0.015478  0.225806           0.112732  0.173516  ...                0
# 33272  0.011261  0.206452           0.124668  0.136986  ...                0
# 7086   0.015478  0.225806           0.123342  0.255708  ...                0
# 15800  0.015478  0.225806           0.157825  0.200913  ...                0
# 49867  0.015478  0.225806           0.157825  0.200913  ...                0
#
#        family_diabetes_1.0  family_diabetes_2.0  family_diabetes_3.0  \
# 9986                     0                    0                    1
# 33272                    1                    0                    0
# 7086                     0                    0                    1
# 15800                    0                    0                    1
# 49867                    0                    0                    1
#
#        moderate_excercise_1.0  moderate_excercise_2.0  moderate_excercise_3.0  \
# 9986                        0                       0                       1
# 33272                       1                       0                       0
# 7086                        0                       0                       1
# 15800                       0                       0                       1
# 49867                       0                       0                       1
#
#        serious_excercise_1.0  serious_excercise_2.0  serious_excercise_3.0
# 9986                       0                      0                      1
# 33272                      1                      0                      0
# 7086                       0                      0                      1
# 15800                      0                      0                      1
# 49867                      0                      0                      1
#
# [5 rows x 31 columns]
#             age  height_cm  weight_kg       bmi  waist_cm  glucose_fast  \
# 48569  0.240506   0.688095   0.404292  0.418040  0.514873      0.138544
# 18733  0.810127   0.767460   0.401717  0.365631  0.556657      0.138544
# 26803  0.240506   0.730952   0.334764  0.322199  0.393768      0.149201
# 22057  0.075949   0.338889   0.096567  0.209374  0.189093      0.138544
# 5777   0.075949   0.438889   0.148927  0.248923  0.308782      0.138544
#
#         insulin     HbA1c  cholesterol_total       hdl  ...  ever_smoked_3.0  \
# 48569  0.015478  0.200000           0.225464  0.141553  ...                0
# 18733  0.015478  0.432258           0.133952  0.191781  ...                0
# 26803  0.013038  0.193548           0.210875  0.155251  ...                0
# 22057  0.015478  0.225806           0.133952  0.210046  ...                0
# 5777   0.015478  0.225806           0.079576  0.141553  ...                0
#
#        family_diabetes_1.0  family_diabetes_2.0  family_diabetes_3.0  \
# 48569                    1                    0                    0
# 18733                    1                    0                    0
# 26803                    1                    0                    0
# 22057                    0                    0                    1
# 5777                     0                    0                    1
#
#        moderate_excercise_1.0  moderate_excercise_2.0  moderate_excercise_3.0  \
# 48569                       0                       1                       0
# 18733                       0                       1                       0
# 26803                       0                       1                       0
# 22057                       0                       0                       1
# 5777                        0                       0                       1
#
#        serious_excercise_1.0  serious_excercise_2.0  serious_excercise_3.0
# 48569                      1                      0                      0
# 18733                      0                      1                      0
# 26803                      1                      0                      0
# 22057                      0                      0                      1
# 5777                       0                      0                      1
#
# [5 rows x 31 columns]

# %%
print(list(X_train.columns))
# Out:
# ['age', 'height_cm', 'weight_kg', 'bmi', 'waist_cm', 'glucose_fast', 'insulin', 'HbA1c', 'cholesterol_total', 'hdl', 'ldl', 'triglycerides', 'alcohol_drink', 'sleep_time', 'health_score', 'systolic_avg', 'diastolic_avg', 'gender_1.0', 'gender_2.0', 'ever_smoked_1.0', 'ever_smoked_2.0', 'ever_smoked_3.0', 'family_diabetes_1.0', 'family_diabetes_2.0', 'family_diabetes_3.0', 'moderate_excercise_1.0', 'moderate_excercise_2.0', 'moderate_excercise_3.0', 'serious_excercise_1.0', 'serious_excercise_2.0', 'serious_excercise_3.0']

# %%
x = X_train.values
y = y_train.values

# %% [markdown]
# ## balanced-accuracy

# %% [markdown]
# #### Random Forest(balanced_weight)

# %%
def compute_metrics(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    balanced_acc = (sensitivity + specificity) / 2
    return balanced_acc, accuracy, sensitivity, specificity

# %%
# 參數網格
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 15, 20],
    "min_samples_split": [2, 3, 4, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2", None],
    "max_leaf_nodes": [10, 20, 30, 40]
}


param_list = list(ParameterGrid(param_grid))

print(f"Total combinations: {len(param_list)}")
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None

print("Running Grid Search with 5-Fold CV (train/val metrics)...\n")

for i, param in tqdm(enumerate(param_list)):
    fold_train_bal_acc = []
    fold_val_bal_acc = []

    fold_train_acc = []
    fold_val_acc = []

    fold_train_sens = []
    fold_val_sens = []

    fold_train_spec = []
    fold_val_spec = []

    for fold_idx, (train_idx, val_idx) in enumerate(cv.split(x, y)):
        x_train_fold, y_train_fold = x[train_idx], y[train_idx]
        x_val_fold, y_val_fold = x[val_idx], y[val_idx]

        clf = RandomForestClassifier(
            **param,
            random_state=seed,
            n_jobs=-1,
            class_weight='balanced'
        )
        clf.fit(x_train_fold, y_train_fold)

        # 預測
        y_train_pred = clf.predict(x_train_fold)
        y_val_pred = clf.predict(x_val_fold)

        # 計算指標
        train_bal_acc, train_acc, train_sens, train_spec = compute_metrics(y_train_fold, y_train_pred)
        val_bal_acc, val_acc, val_sens, val_spec = compute_metrics(y_val_fold, y_val_pred)

        # 累積
        fold_train_bal_acc.append(train_bal_acc)
        fold_val_bal_acc.append(val_bal_acc)

        fold_train_acc.append(train_acc)
        fold_val_acc.append(val_acc)

        fold_train_sens.append(train_sens)
        fold_val_sens.append(val_sens)

        fold_train_spec.append(train_spec)
        fold_val_spec.append(val_spec)

    # 平均
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_val_bal_acc = np.mean(fold_val_bal_acc)

    avg_train_acc = np.mean(fold_train_acc)
    avg_val_acc = np.mean(fold_val_acc)

    avg_train_sens = np.mean(fold_train_sens)
    avg_val_sens = np.mean(fold_val_sens)

    avg_train_spec = np.mean(fold_train_spec)
    avg_val_spec = np.mean(fold_val_spec)

    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params = param
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec
        }

# %%
print("Best Params:", best_params)
print(f"Best Balanced Accuracy: {best_score:.4f}")
print(f"Best Accuracy:           {best_metrics['Accuracy']:.4f}")
print(f"Best Sensitivity:        {best_metrics['Sensitivity']:.4f}")
print(f"Best Specificity:        {best_metrics['Specificity']:.4f}")
print(f"Best Training Balanced Accuracy:   {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Training Accuracy:            {best_metrics['Train Accuracy']:.4f}")
print(f"Best Training Sensitivity:         {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Training Specificity:         {best_metrics['Train Specificity']:.4f}")

# %% [markdown]
# ##### Test

# %%
print("\nTraining final model on full training data with best parameters...")
final_model = RandomForestClassifier(
    **best_params,
    random_state=seed,
    n_jobs=-1,
    class_weight='balanced'
)
final_model.fit(x, y)

# 預測 Test Set
y_test_proba = final_model.predict_proba(X_test.values)[:, 1]
y_test_pred = (y_test_proba >= 0.5).astype(int)

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_proba)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# Training final model on full training data with best parameters...
#
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 112                  63
# Actual Negative                 143                1644
# Sensitivity (Recall, TPR): 0.6400
# Specificity (TNR):         0.9200
# Accuracy:                  0.8950
# Balanced Accuracy:         0.7800
# AUC:                       0.8565
# F1 Score:         0.5209

# %% [markdown]
# #### Logistic Regression(balanced-weight)

# %%
C_list = [2 ** i for i in range(-10, 11)]
penalty_list = ['l1', 'l2'] # 新增正則化類型列表

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None

print("Running Grid Search over C with 5-Fold Stratified CV...\n")

# --- 雙層迴圈開始 ---
for penalty in penalty_list:
    print(f"================ Running Penalty: {penalty.upper()} ================")
    
    # 針對 L1 必須使用 saga，針對 L2 使用 lbfgs (除非使用 liblinear)
    if penalty == 'l1':
        # saga 支持 L1 和 L2
        solver_type = "saga" 
    else:
        # lbfgs 速度快，但只支持 L2
        solver_type = "lbfgs" 

    for C in tqdm(C_list, desc=f"C Search ({penalty.upper()})"):
        
        # 指標列表初始化
        fold_train_bal_acc = []
        fold_train_acc = []
        fold_train_sens = []
        fold_train_spec = []

        fold_val_bal_acc = []
        fold_val_acc = []
        fold_val_sens = []
        fold_val_spec = []

        for fold, (train_idx, val_idx) in enumerate(cv.split(x, y), 1):
            x_train_fold, y_train_fold = x[train_idx], y[train_idx]
            x_val_fold, y_val_fold = x[val_idx], y[val_idx]

            clf = LogisticRegression(
                C=C,
                penalty=penalty,
                solver=solver_type,
                class_weight="balanced",
                max_iter=5000,
                random_state=seed,
                tol=1e-4,
                n_jobs=-1
            )
            clf.fit(x_train_fold, y_train_fold)
            # --- Train
            y_train_pred = clf.predict(x_train_fold)
            tn, fp, fn, tp = confusion_matrix(y_train_fold, y_train_pred).ravel()
            train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
            train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
            train_acc = (tp + tn) / (tp + tn + fp + fn)
            train_bal_acc = (train_sens + train_spec) / 2

            fold_train_bal_acc.append(train_bal_acc)
            fold_train_acc.append(train_acc)
            fold_train_sens.append(train_sens)
            fold_train_spec.append(train_spec)

            # --- Validation
            y_val_pred = clf.predict(x_val_fold)
            tn, fp, fn, tp = confusion_matrix(y_val_fold, y_val_pred).ravel()
            val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
            val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
            val_acc = (tp + tn) / (tp + tn + fp + fn)
            val_bal_acc = (val_sens + val_spec) / 2

            fold_val_bal_acc.append(val_bal_acc)
            fold_val_acc.append(val_acc)
            fold_val_sens.append(val_sens)
            fold_val_spec.append(val_spec)

        #print(f"C={C:<10} Fold {fold}:")
        #print(f"  Train - BalAcc: {train_bal_acc:.4f} Acc: {train_acc:.4f} Sens: {train_sens:.4f} Spec: {train_spec:.4f}")
        #print(f"  Val   - BalAcc: {val_bal_acc:.4f} Acc: {val_acc:.4f} Sens: {val_sens:.4f} Spec: {val_spec:.4f}")

        # === Mean over folds
        avg_train_bal_acc = np.mean(fold_train_bal_acc)
        avg_train_acc = np.mean(fold_train_acc)
        avg_train_sens = np.mean(fold_train_sens)
        avg_train_spec = np.mean(fold_train_spec)

        avg_val_bal_acc = np.mean(fold_val_bal_acc)
        avg_val_acc = np.mean(fold_val_acc)
        avg_val_sens = np.mean(fold_val_sens)
        avg_val_spec = np.mean(fold_val_spec)

        print(f"\nMean over folds for C={C}, penalty={penalty}:")
        print(f"  Train - BalAcc: {avg_train_bal_acc:.4f} Acc: {avg_train_acc:.4f} Sens: {avg_train_sens:.4f} Spec: {avg_train_spec:.4f}")
        print(f"  Val   - BalAcc: {avg_val_bal_acc:.4f} Acc: {avg_val_acc:.4f} Sens: {avg_val_sens:.4f} Spec: {avg_val_spec:.4f}\n")

        # --- Best tracking
        if avg_val_bal_acc > best_score:
            best_score = avg_val_bal_acc
            best_C = C
            best_penalty = penalty
            best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec,
            }
# Out:
# Running Grid Search over C with 5-Fold Stratified CV...
#
# ================ Running Penalty: L1 ================
# C Search (L1):   5%|▍         | 1/21 [00:07<02:36,  7.85s/it]
# Mean over folds for C=0.0009765625, penalty=l1:
#   Train - BalAcc: 0.8163 Acc: 0.7497 Sens: 0.8962 Spec: 0.7364
#   Val   - BalAcc: 0.8163 Acc: 0.7499 Sens: 0.8960 Spec: 0.7366
# C Search (L1):  10%|▉         | 2/21 [00:44<07:55, 25.03s/it]
# Mean over folds for C=0.001953125, penalty=l1:
#   Train - BalAcc: 0.8351 Acc: 0.7778 Sens: 0.9039 Spec: 0.7664
#   Val   - BalAcc: 0.8348 Acc: 0.7777 Sens: 0.9034 Spec: 0.7663
# C Search (L1):  14%|█▍        | 3/21 [01:09<07:28, 24.91s/it]
# Mean over folds for C=0.00390625, penalty=l1:
#   Train - BalAcc: 0.8621 Acc: 0.8253 Sens: 0.9062 Spec: 0.8180
#   Val   - BalAcc: 0.8624 Acc: 0.8253 Sens: 0.9068 Spec: 0.8179
# C Search (L1):  19%|█▉        | 4/21 [01:20<05:27, 19.25s/it]
# Mean over folds for C=0.0078125, penalty=l1:
#   Train - BalAcc: 0.8753 Acc: 0.8519 Sens: 0.9034 Spec: 0.8473
#   Val   - BalAcc: 0.8749 Acc: 0.8516 Sens: 0.9029 Spec: 0.8469
# C Search (L1):  24%|██▍       | 5/21 [01:28<04:03, 15.24s/it]
# Mean over folds for C=0.015625, penalty=l1:
#   Train - BalAcc: 0.8815 Acc: 0.8685 Sens: 0.8971 Spec: 0.8659
#   Val   - BalAcc: 0.8816 Acc: 0.8683 Sens: 0.8976 Spec: 0.8656
# C Search (L1):  29%|██▊       | 6/21 [01:35<03:04, 12.32s/it]
# Mean over folds for C=0.03125, penalty=l1:
#   Train - BalAcc: 0.8855 Acc: 0.8800 Sens: 0.8921 Spec: 0.8789
#   Val   - BalAcc: 0.8853 Acc: 0.8798 Sens: 0.8920 Spec: 0.8787
# C Search (L1):  33%|███▎      | 7/21 [01:41<02:26, 10.47s/it]
# Mean over folds for C=0.0625, penalty=l1:
#   Train - BalAcc: 0.8877 Acc: 0.8853 Sens: 0.8906 Spec: 0.8848
#   Val   - BalAcc: 0.8878 Acc: 0.8852 Sens: 0.8909 Spec: 0.8847
# C Search (L1):  38%|███▊      | 8/21 [01:48<02:01,  9.38s/it]
# Mean over folds for C=0.125, penalty=l1:
#   Train - BalAcc: 0.8886 Acc: 0.8882 Sens: 0.8891 Spec: 0.8881
#   Val   - BalAcc: 0.8877 Acc: 0.8880 Sens: 0.8875 Spec: 0.8880
# C Search (L1):  43%|████▎     | 9/21 [01:56<01:44,  8.74s/it]
# Mean over folds for C=0.25, penalty=l1:
#   Train - BalAcc: 0.8889 Acc: 0.8894 Sens: 0.8883 Spec: 0.8895
#   Val   - BalAcc: 0.8873 Acc: 0.8890 Sens: 0.8854 Spec: 0.8893
# C Search (L1):  48%|████▊     | 10/21 [02:03<01:31,  8.33s/it]
# Mean over folds for C=0.5, penalty=l1:
#   Train - BalAcc: 0.8891 Acc: 0.8901 Sens: 0.8879 Spec: 0.8903
#   Val   - BalAcc: 0.8875 Acc: 0.8897 Sens: 0.8848 Spec: 0.8902
# C Search (L1):  52%|█████▏    | 11/21 [02:11<01:21,  8.16s/it]
# Mean over folds for C=1, penalty=l1:
#   Train - BalAcc: 0.8891 Acc: 0.8902 Sens: 0.8877 Spec: 0.8905
#   Val   - BalAcc: 0.8875 Acc: 0.8899 Sens: 0.8846 Spec: 0.8904
# C Search (L1):  57%|█████▋    | 12/21 [02:24<01:26,  9.59s/it]
# Mean over folds for C=2, penalty=l1:
#   Train - BalAcc: 0.8892 Acc: 0.8904 Sens: 0.8877 Spec: 0.8906
#   Val   - BalAcc: 0.8876 Acc: 0.8903 Sens: 0.8843 Spec: 0.8909
# C Search (L1):  62%|██████▏   | 13/21 [02:39<01:31, 11.39s/it]
# Mean over folds for C=4, penalty=l1:
#   Train - BalAcc: 0.8892 Acc: 0.8904 Sens: 0.8878 Spec: 0.8907
#   Val   - BalAcc: 0.8876 Acc: 0.8902 Sens: 0.8846 Spec: 0.8907
# C Search (L1):  67%|██████▋   | 14/21 [03:12<02:04, 17.78s/it]
# Mean over folds for C=8, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8905 Sens: 0.8878 Spec: 0.8908
#   Val   - BalAcc: 0.8877 Acc: 0.8903 Sens: 0.8846 Spec: 0.8908
# C Search (L1):  71%|███████▏  | 15/21 [03:48<02:19, 23.32s/it]
# Mean over folds for C=16, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8905 Sens: 0.8877 Spec: 0.8908
#   Val   - BalAcc: 0.8877 Acc: 0.8903 Sens: 0.8846 Spec: 0.8908
# C Search (L1):  76%|███████▌  | 16/21 [04:47<02:50, 34.11s/it]
# Mean over folds for C=32, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8906 Sens: 0.8877 Spec: 0.8909
#   Val   - BalAcc: 0.8877 Acc: 0.8903 Sens: 0.8846 Spec: 0.8908
# C Search (L1):  81%|████████  | 17/21 [05:01<01:51, 27.97s/it]
# Mean over folds for C=64, penalty=l1:
#   Train - BalAcc: 0.8892 Acc: 0.8906 Sens: 0.8876 Spec: 0.8909
#   Val   - BalAcc: 0.8877 Acc: 0.8904 Sens: 0.8846 Spec: 0.8909
# C Search (L1):  86%|████████▌ | 18/21 [05:13<01:09, 23.28s/it]
# Mean over folds for C=128, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8906 Sens: 0.8877 Spec: 0.8908
#   Val   - BalAcc: 0.8877 Acc: 0.8903 Sens: 0.8846 Spec: 0.8909
# C Search (L1):  90%|█████████ | 19/21 [05:25<00:39, 19.96s/it]
# Mean over folds for C=256, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8906 Sens: 0.8877 Spec: 0.8909
#   Val   - BalAcc: 0.8877 Acc: 0.8903 Sens: 0.8846 Spec: 0.8909
# C Search (L1):  95%|█████████▌| 20/21 [05:38<00:17, 17.69s/it]
# Mean over folds for C=512, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8906 Sens: 0.8877 Spec: 0.8909
#   Val   - BalAcc: 0.8876 Acc: 0.8903 Sens: 0.8843 Spec: 0.8909
# C Search (L1): 100%|██████████| 21/21 [05:50<00:00, 16.71s/it]
# Mean over folds for C=1024, penalty=l1:
#   Train - BalAcc: 0.8893 Acc: 0.8906 Sens: 0.8877 Spec: 0.8909
#   Val   - BalAcc: 0.8876 Acc: 0.8903 Sens: 0.8843 Spec: 0.8909
#
# ================ Running Penalty: L2 ================
# C Search (L2):   5%|▍         | 1/21 [00:50<16:41, 50.09s/it]
# Mean over folds for C=0.0009765625, penalty=l2:
#   Train - BalAcc: 0.8183 Acc: 0.7506 Sens: 0.8995 Spec: 0.7370
#   Val   - BalAcc: 0.8172 Acc: 0.7505 Sens: 0.8973 Spec: 0.7371
# C Search (L2):  10%|▉         | 2/21 [01:34<14:48, 46.77s/it]
# Mean over folds for C=0.001953125, penalty=l2:
#   Train - BalAcc: 0.8278 Acc: 0.7674 Sens: 0.9003 Spec: 0.7553
#   Val   - BalAcc: 0.8286 Acc: 0.7678 Sens: 0.9015 Spec: 0.7556
# C Search (L2):  14%|█▍        | 3/21 [01:55<10:31, 35.10s/it]
# Mean over folds for C=0.00390625, penalty=l2:
#   Train - BalAcc: 0.8384 Acc: 0.7858 Sens: 0.9016 Spec: 0.7753
#   Val   - BalAcc: 0.8390 Acc: 0.7858 Sens: 0.9029 Spec: 0.7752
# C Search (L2):  19%|█▉        | 4/21 [02:01<06:38, 23.46s/it]
# Mean over folds for C=0.0078125, penalty=l2:
#   Train - BalAcc: 0.8508 Acc: 0.8068 Sens: 0.9037 Spec: 0.7980
#   Val   - BalAcc: 0.8507 Acc: 0.8065 Sens: 0.9037 Spec: 0.7977
# C Search (L2):  24%|██▍       | 5/21 [02:07<04:33, 17.06s/it]
# Mean over folds for C=0.015625, penalty=l2:
#   Train - BalAcc: 0.8616 Acc: 0.8253 Sens: 0.9051 Spec: 0.8180
#   Val   - BalAcc: 0.8608 Acc: 0.8247 Sens: 0.9042 Spec: 0.8174
# C Search (L2):  29%|██▊       | 6/21 [02:12<03:18, 13.23s/it]
# Mean over folds for C=0.03125, penalty=l2:
#   Train - BalAcc: 0.8696 Acc: 0.8415 Sens: 0.9034 Spec: 0.8358
#   Val   - BalAcc: 0.8690 Acc: 0.8414 Sens: 0.9021 Spec: 0.8358
# C Search (L2):  33%|███▎      | 7/21 [02:18<02:31, 10.83s/it]
# Mean over folds for C=0.0625, penalty=l2:
#   Train - BalAcc: 0.8753 Acc: 0.8551 Sens: 0.8995 Spec: 0.8511
#   Val   - BalAcc: 0.8745 Acc: 0.8551 Sens: 0.8978 Spec: 0.8512
# C Search (L2):  38%|███▊      | 8/21 [02:24<02:01,  9.31s/it]
# Mean over folds for C=0.125, penalty=l2:
#   Train - BalAcc: 0.8813 Acc: 0.8664 Sens: 0.8991 Spec: 0.8635
#   Val   - BalAcc: 0.8808 Acc: 0.8663 Sens: 0.8984 Spec: 0.8633
# C Search (L2):  43%|████▎     | 9/21 [02:30<01:39,  8.33s/it]
# Mean over folds for C=0.25, penalty=l2:
#   Train - BalAcc: 0.8847 Acc: 0.8750 Sens: 0.8965 Spec: 0.8730
#   Val   - BalAcc: 0.8839 Acc: 0.8746 Sens: 0.8952 Spec: 0.8727
# C Search (L2):  48%|████▊     | 10/21 [02:37<01:24,  7.68s/it]
# Mean over folds for C=0.5, penalty=l2:
#   Train - BalAcc: 0.8870 Acc: 0.8813 Sens: 0.8938 Spec: 0.8802
#   Val   - BalAcc: 0.8855 Acc: 0.8803 Sens: 0.8917 Spec: 0.8793
# C Search (L2):  52%|█████▏    | 11/21 [02:43<01:11,  7.16s/it]
# Mean over folds for C=1, penalty=l2:
#   Train - BalAcc: 0.8881 Acc: 0.8857 Sens: 0.8909 Spec: 0.8852
#   Val   - BalAcc: 0.8871 Acc: 0.8851 Sens: 0.8896 Spec: 0.8847
# C Search (L2):  57%|█████▋    | 12/21 [02:49<01:01,  6.80s/it]
# Mean over folds for C=2, penalty=l2:
#   Train - BalAcc: 0.8886 Acc: 0.8882 Sens: 0.8892 Spec: 0.8881
#   Val   - BalAcc: 0.8874 Acc: 0.8878 Sens: 0.8869 Spec: 0.8878
# C Search (L2):  62%|██████▏   | 13/21 [02:55<00:52,  6.56s/it]
# Mean over folds for C=4, penalty=l2:
#   Train - BalAcc: 0.8890 Acc: 0.8895 Sens: 0.8884 Spec: 0.8896
#   Val   - BalAcc: 0.8873 Acc: 0.8888 Sens: 0.8854 Spec: 0.8892
# C Search (L2):  67%|██████▋   | 14/21 [03:01<00:44,  6.39s/it]
# Mean over folds for C=8, penalty=l2:
#   Train - BalAcc: 0.8889 Acc: 0.8898 Sens: 0.8878 Spec: 0.8900
#   Val   - BalAcc: 0.8876 Acc: 0.8894 Sens: 0.8854 Spec: 0.8898
# C Search (L2):  71%|███████▏  | 15/21 [03:07<00:37,  6.28s/it]
# Mean over folds for C=16, penalty=l2:
#   Train - BalAcc: 0.8892 Acc: 0.8904 Sens: 0.8877 Spec: 0.8907
#   Val   - BalAcc: 0.8879 Acc: 0.8902 Sens: 0.8851 Spec: 0.8907
# C Search (L2):  76%|███████▌  | 16/21 [03:13<00:30,  6.18s/it]
# Mean over folds for C=32, penalty=l2:
#   Train - BalAcc: 0.8892 Acc: 0.8905 Sens: 0.8876 Spec: 0.8908
#   Val   - BalAcc: 0.8877 Acc: 0.8902 Sens: 0.8846 Spec: 0.8908
# C Search (L2):  81%|████████  | 17/21 [03:19<00:24,  6.12s/it]
# Mean over folds for C=64, penalty=l2:
#   Train - BalAcc: 0.8894 Acc: 0.8906 Sens: 0.8879 Spec: 0.8909
#   Val   - BalAcc: 0.8879 Acc: 0.8900 Sens: 0.8854 Spec: 0.8905
# C Search (L2):  86%|████████▌ | 18/21 [03:25<00:18,  6.10s/it]
# Mean over folds for C=128, penalty=l2:
#   Train - BalAcc: 0.8894 Acc: 0.8907 Sens: 0.8877 Spec: 0.8910
#   Val   - BalAcc: 0.8881 Acc: 0.8904 Sens: 0.8854 Spec: 0.8909
# C Search (L2):  90%|█████████ | 19/21 [03:31<00:12,  6.09s/it]
# Mean over folds for C=256, penalty=l2:
#   Train - BalAcc: 0.8893 Acc: 0.8907 Sens: 0.8877 Spec: 0.8910
#   Val   - BalAcc: 0.8880 Acc: 0.8903 Sens: 0.8851 Spec: 0.8908
# C Search (L2):  95%|█████████▌| 20/21 [03:37<00:06,  6.06s/it]
# Mean over folds for C=512, penalty=l2:
#   Train - BalAcc: 0.8893 Acc: 0.8907 Sens: 0.8877 Spec: 0.8910
#   Val   - BalAcc: 0.8879 Acc: 0.8904 Sens: 0.8848 Spec: 0.8909
# C Search (L2): 100%|██████████| 21/21 [03:43<00:00, 10.63s/it]
# Mean over folds for C=1024, penalty=l2:
#   Train - BalAcc: 0.8893 Acc: 0.8907 Sens: 0.8877 Spec: 0.8910
#   Val   - BalAcc: 0.8880 Acc: 0.8904 Sens: 0.8851 Spec: 0.8909

# %%
print("\n Best Grid Search Result:")
print(f"Best C: {best_C}")
print(f"Best Penalty: {best_penalty}")
print(f"Best Validation Balanced Accuracy: {best_metrics['Balanced Accuracy']:.4f}")
print(f"Best Validation Accuracy:          {best_metrics['Accuracy']:.4f}")
print(f"Best Validation Sensitivity:       {best_metrics['Sensitivity']:.4f}")
print(f"Best Validation Specificity:       {best_metrics['Specificity']:.4f}")
print(f"Best Training Balanced Accuracy:   {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Training Accuracy:            {best_metrics['Train Accuracy']:.4f}")
print(f"Best Training Sensitivity:         {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Training Specificity:         {best_metrics['Train Specificity']:.4f}")
# Out:
#  Best Grid Search Result:
# Best C: 128
# Best Penalty: l2
# Best Validation Balanced Accuracy: 0.8881
# Best Validation Accuracy:          0.8904
# Best Validation Sensitivity:       0.8854
# Best Validation Specificity:       0.8909
# Best Training Balanced Accuracy:   0.8894
# Best Training Accuracy:            0.8907
# Best Training Sensitivity:         0.8877
# Best Training Specificity:         0.8910

# %% [markdown]
# ##### Test

# %%
if best_penalty == 'l1':
    # saga 支持 L1 和 L2
    solver_type = "saga" 
else:
    # lbfgs 速度快，但只支持 L2
    solver_type = "lbfgs" 


# 取得最佳參數
final_model = LogisticRegression(
    C=best_C,
    penalty=best_penalty,
    max_iter=5000,
    solver=solver_type,
    class_weight='balanced',
    random_state=seed
)
final_model.fit(x, y)


# 預測
y_test_proba = final_model.predict_proba(X_test.values)[:, 1]
y_test_pred = (y_test_proba >= 0.5).astype(int)


# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_proba)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 848                  94
# Actual Negative                1132                9219
# Sensitivity (Recall, TPR): 0.9002
# Specificity (TNR):         0.8906
# Accuracy:                  0.8914
# Balanced Accuracy:         0.8954
# AUC:                       0.9589
# F1 Score:         0.5804

# %% [markdown]
# #### SVM(balanced-weight)

# %%
# 定義超參數範圍
C_list = [2 ** i for i in range(-10, -5)]
gamma_list = [2 ** i for i in range(-10, 11)]
param_grid = list(product(C_list, gamma_list))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None


print("Running Grid Search over C and gamma with 5-Fold Stratified CV...\n")

for C, gamma in tqdm(param_grid):
    fold_train_bal_acc = []
    fold_train_acc = []
    fold_train_sens = []
    fold_train_spec = []

    fold_val_bal_acc = []
    fold_val_acc = []
    fold_val_sens = []
    fold_val_spec = []

    for fold, (train_idx, val_idx) in enumerate(cv.split(x, y), 1):
        x_train_fold, y_train_fold = x[train_idx], y[train_idx]
        x_val_fold, y_val_fold = x[val_idx], y[val_idx]

        clf = SVC(
            C=C,
            gamma=gamma,
            kernel='rbf',
            class_weight='balanced',
            probability=False,
            random_state=seed,
            cache_size=1000
        )
        clf.fit(x_train_fold, y_train_fold)

        # --- Train
        y_train_pred = clf.predict(x_train_fold)
        tn, fp, fn, tp = confusion_matrix(y_train_fold, y_train_pred).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_acc = (tp + tn) / (tp + tn + fp + fn)
        train_bal_acc = (train_sens + train_spec) / 2

        fold_train_bal_acc.append(train_bal_acc)
        fold_train_acc.append(train_acc)
        fold_train_sens.append(train_sens)
        fold_train_spec.append(train_spec)

        # --- Validation
        y_val_pred = clf.predict(x_val_fold)
        tn, fp, fn, tp = confusion_matrix(y_val_fold, y_val_pred).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        val_acc = (tp + tn) / (tp + tn + fp + fn)
        val_bal_acc = (val_sens + val_spec) / 2

        fold_val_bal_acc.append(val_bal_acc)
        fold_val_acc.append(val_acc)
        fold_val_sens.append(val_sens)
        fold_val_spec.append(val_spec)

    # === Mean over folds
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_train_acc = np.mean(fold_train_acc)
    avg_train_sens = np.mean(fold_train_sens)
    avg_train_spec = np.mean(fold_train_spec)

    avg_val_bal_acc = np.mean(fold_val_bal_acc)
    avg_val_acc = np.mean(fold_val_acc)
    avg_val_sens = np.mean(fold_val_sens)
    avg_val_spec = np.mean(fold_val_spec)

    print(f"\nMean over folds for C={C}, gamma={gamma}:")
    print(f"  Train - BalAcc: {avg_train_bal_acc:.4f} Acc: {avg_train_acc:.4f} Sens: {avg_train_sens:.4f} Spec: {avg_train_spec:.4f}")
    print(f"  Val   - BalAcc: {avg_val_bal_acc:.4f} Acc: {avg_val_acc:.4f} Sens: {avg_val_sens:.4f} Spec: {avg_val_spec:.4f}\n")

    # --- Best tracking
    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params = (C, gamma)
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec,
        }
# Out:
# Running Grid Search over C and gamma with 5-Fold Stratified CV...
#   1%|          | 1/105 [12:39<21:55:59, 759.22s/it]
# Mean over folds for C=0.0009765625, gamma=0.0009765625:
#   Train - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   Val   - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   2%|▏         | 2/105 [25:12<21:37:39, 755.92s/it]
# Mean over folds for C=0.0009765625, gamma=0.001953125:
#   Train - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   Val   - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   3%|▎         | 3/105 [37:49<21:25:26, 756.14s/it]
# Mean over folds for C=0.0009765625, gamma=0.00390625:
#   Train - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   Val   - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   4%|▍         | 4/105 [50:12<21:04:32, 751.21s/it]
# Mean over folds for C=0.0009765625, gamma=0.0078125:
#   Train - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   Val   - BalAcc: 0.5000 Acc: 0.5833 Sens: 0.4000 Spec: 0.6000
#   5%|▍         | 5/105 [1:02:36<20:47:38, 748.58s/it]
# Mean over folds for C=0.0009765625, gamma=0.015625:
#   Train - BalAcc: 0.7461 Acc: 0.5788 Sens: 0.9469 Spec: 0.5453
#   Val   - BalAcc: 0.7440 Acc: 0.5770 Sens: 0.9445 Spec: 0.5435
#   6%|▌         | 6/105 [1:13:33<19:43:30, 717.28s/it]
# Mean over folds for C=0.0009765625, gamma=0.03125:
#   Train - BalAcc: 0.7485 Acc: 0.5662 Sens: 0.9672 Spec: 0.5297
#   Val   - BalAcc: 0.7480 Acc: 0.5660 Sens: 0.9666 Spec: 0.5295
#   7%|▋         | 7/105 [1:23:09<18:15:58, 671.01s/it]
# Mean over folds for C=0.0009765625, gamma=0.0625:
#   Train - BalAcc: 0.7579 Acc: 0.5887 Sens: 0.9609 Spec: 0.5548
#   Val   - BalAcc: 0.7578 Acc: 0.5886 Sens: 0.9610 Spec: 0.5547
#   8%|▊         | 8/105 [1:32:04<16:54:57, 627.81s/it]
# Mean over folds for C=0.0009765625, gamma=0.125:
#   Train - BalAcc: 0.7778 Acc: 0.6342 Sens: 0.9502 Spec: 0.6055
#   Val   - BalAcc: 0.7777 Acc: 0.6343 Sens: 0.9498 Spec: 0.6056
#   9%|▊         | 9/105 [1:40:58<15:57:44, 598.59s/it]
# Mean over folds for C=0.0009765625, gamma=0.25:
#   Train - BalAcc: 0.7895 Acc: 0.6723 Sens: 0.9301 Spec: 0.6489
#   Val   - BalAcc: 0.7898 Acc: 0.6721 Sens: 0.9310 Spec: 0.6486

# %%
print("\n✅ Best Grid Search Result:")
print(f"Best C: {best_params[0]}")
print(f"Best gamma: {best_params[1]}")
print(f"Best Validation Balanced Accuracy: {best_metrics['Balanced Accuracy']:.4f}")
print(f"Best Validation Accuracy:          {best_metrics['Accuracy']:.4f}")
print(f"Best Validation Sensitivity:       {best_metrics['Sensitivity']:.4f}")
print(f"Best Validation Specificity:       {best_metrics['Specificity']:.4f}")
print(f"Best Training Balanced Accuracy:   {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Training Accuracy:            {best_metrics['Train Accuracy']:.4f}")
print(f"Best Training Sensitivity:         {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Training Specificity:         {best_metrics['Train Specificity']:.4f}")

# %% [markdown]
# ##### Test

# %%
# 取得最佳參數
best_C = best_params[0]
best_gamma = best_params[1]

final_model = SVC(
    C=best_C,
    gamma=best_gamma,
    kernel='rbf',
    probability=False,
    class_weight='balanced',
    random_state=seed,
    cache_size=1000
)

final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test.values)                  # 分類標籤
y_test_score = final_model.decision_function(X_test.values)
# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_score)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # 取得最佳參數
# ----> 2 best_C = best_params[0]
#       3 best_gamma = best_params[1]
#       5 final_model = SVC(
#       6     C=best_C,
#       7     gamma=best_gamma,
#    (...)     12     cache_size=1000
#      13 )
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# 定義超參數範圍
C_list = [2 ** i for i in range(-5, 0)]
gamma_list = [2 ** i for i in range(-10, 11)]
param_grid = list(product(C_list, gamma_list))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None


print("Running Grid Search over C and gamma with 5-Fold Stratified CV...\n")

for C, gamma in tqdm(param_grid):
    fold_train_bal_acc = []
    fold_train_acc = []
    fold_train_sens = []
    fold_train_spec = []

    fold_val_bal_acc = []
    fold_val_acc = []
    fold_val_sens = []
    fold_val_spec = []

    for fold, (train_idx, val_idx) in enumerate(cv.split(x, y), 1):
        x_train_fold, y_train_fold = x[train_idx], y[train_idx]
        x_val_fold, y_val_fold = x[val_idx], y[val_idx]

        clf = SVC(
            C=C,
            gamma=gamma,
            kernel='rbf',
            class_weight='balanced',
            probability=False,
            random_state=seed,
            cache_size=1000
        )
        clf.fit(x_train_fold, y_train_fold)

        # --- Train
        y_train_pred = clf.predict(x_train_fold)
        tn, fp, fn, tp = confusion_matrix(y_train_fold, y_train_pred).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_acc = (tp + tn) / (tp + tn + fp + fn)
        train_bal_acc = (train_sens + train_spec) / 2

        fold_train_bal_acc.append(train_bal_acc)
        fold_train_acc.append(train_acc)
        fold_train_sens.append(train_sens)
        fold_train_spec.append(train_spec)

        # --- Validation
        y_val_pred = clf.predict(x_val_fold)
        tn, fp, fn, tp = confusion_matrix(y_val_fold, y_val_pred).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        val_acc = (tp + tn) / (tp + tn + fp + fn)
        val_bal_acc = (val_sens + val_spec) / 2

        fold_val_bal_acc.append(val_bal_acc)
        fold_val_acc.append(val_acc)
        fold_val_sens.append(val_sens)
        fold_val_spec.append(val_spec)

    # === Mean over folds
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_train_acc = np.mean(fold_train_acc)
    avg_train_sens = np.mean(fold_train_sens)
    avg_train_spec = np.mean(fold_train_spec)

    avg_val_bal_acc = np.mean(fold_val_bal_acc)
    avg_val_acc = np.mean(fold_val_acc)
    avg_val_sens = np.mean(fold_val_sens)
    avg_val_spec = np.mean(fold_val_spec)

    print(f"\nMean over folds for C={C}, gamma={gamma}:")
    print(f"  Train - BalAcc: {avg_train_bal_acc:.4f} Acc: {avg_train_acc:.4f} Sens: {avg_train_sens:.4f} Spec: {avg_train_spec:.4f}")
    print(f"  Val   - BalAcc: {avg_val_bal_acc:.4f} Acc: {avg_val_acc:.4f} Sens: {avg_val_sens:.4f} Spec: {avg_val_spec:.4f}\n")

    # --- Best tracking
    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params = (C, gamma)
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec,
        }

# %%
print("\n✅ Best Grid Search Result:")
print(f"Best C: {best_params[0]}")
print(f"Best gamma: {best_params[1]}")
print(f"Best Validation Balanced Accuracy: {best_metrics['Balanced Accuracy']:.4f}")
print(f"Best Validation Accuracy:          {best_metrics['Accuracy']:.4f}")
print(f"Best Validation Sensitivity:       {best_metrics['Sensitivity']:.4f}")
print(f"Best Validation Specificity:       {best_metrics['Specificity']:.4f}")
print(f"Best Training Balanced Accuracy:   {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Training Accuracy:            {best_metrics['Train Accuracy']:.4f}")
print(f"Best Training Sensitivity:         {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Training Specificity:         {best_metrics['Train Specificity']:.4f}")

# %%
# 取得最佳參數
best_C = best_params[0]
best_gamma = best_params[1]

final_model = SVC(
    C=best_C,
    gamma=best_gamma,
    kernel='rbf',
    probability=False,
    class_weight='balanced',
    random_state=seed,
    cache_size=1000
)

final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test.values)                  # 分類標籤
y_test_score = final_model.decision_function(X_test.values)
# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_score)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:         {f1:.4f}")

# %% [markdown]
# #### XGboost

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({np.int64(0): 7149, np.int64(1): 698})
# scale_pos_weight = 10.2421

# %%
# 參數網格
param_grid = {
    "colsample_bytree": [0.3, 0.5, 0.7, 1.0],
    "gamma": [0, 0.1, 0.5, 1, 5],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
    "max_depth": [3, 5, 7, 10],
    "n_estimators": [200, 400, 600, 800, 1000],
    "subsample": [0.3, 0.5, 0.7]
}


param_list = list(ParameterGrid(param_grid))

print(f"Total combinations: {len(param_list)}")
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None

print("Running Grid Search with 5-Fold CV (train/val metrics)...\n")

for i, param in tqdm(enumerate(param_list)):
    fold_train_bal_acc = []
    fold_val_bal_acc = []

    fold_train_acc = []
    fold_val_acc = []

    fold_train_sens = []
    fold_val_sens = []

    fold_train_spec = []
    fold_val_spec = []

    for fold_idx, (train_idx, val_idx) in enumerate(cv.split(x, y)):
        x_train_fold, y_train_fold = x[train_idx], y[train_idx]
        x_val_fold, y_val_fold = x[val_idx], y[val_idx]

        clf = xgb.XGBClassifier(
            **param,
            eval_metric="logloss",
            tree_method="hist",
            device="cuda",
            scale_pos_weight=scale_pos_weight,
            random_state=seed
        )
        clf.fit(x_train_fold, y_train_fold)

        # 預測
        y_train_pred = clf.predict(x_train_fold)
        y_val_pred = clf.predict(x_val_fold)

        # 計算指標
        train_bal_acc, train_acc, train_sens, train_spec = compute_metrics(y_train_fold, y_train_pred)
        val_bal_acc, val_acc, val_sens, val_spec = compute_metrics(y_val_fold, y_val_pred)

        # 累積
        fold_train_bal_acc.append(train_bal_acc)
        fold_val_bal_acc.append(val_bal_acc)

        fold_train_acc.append(train_acc)
        fold_val_acc.append(val_acc)

        fold_train_sens.append(train_sens)
        fold_val_sens.append(val_sens)

        fold_train_spec.append(train_spec)
        fold_val_spec.append(val_spec)

    # 平均
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_val_bal_acc = np.mean(fold_val_bal_acc)

    avg_train_acc = np.mean(fold_train_acc)
    avg_val_acc = np.mean(fold_val_acc)

    avg_train_sens = np.mean(fold_train_sens)
    avg_val_sens = np.mean(fold_val_sens)

    avg_train_spec = np.mean(fold_train_spec)
    avg_val_spec = np.mean(fold_val_spec)

    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params = param
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec
        }

# %%
print("Best Params:", best_params)
print(f"Best Balanced Accuracy: {best_score:.4f}")
print(f"Best Accuracy:           {best_metrics['Accuracy']:.4f}")
print(f"Best Sensitivity:        {best_metrics['Sensitivity']:.4f}")
print(f"Best Specificity:        {best_metrics['Specificity']:.4f}")
print(f"Best Training Balanced Accuracy:   {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Training Accuracy:            {best_metrics['Train Accuracy']:.4f}")
print(f"Best Training Sensitivity:         {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Training Specificity:         {best_metrics['Train Specificity']:.4f}")

# %% [markdown]
# ##### Test

# %%
print("\nTraining final model on full training data with best parameters...")
final_model = xgb.XGBClassifier(
    **best_params,
    eval_metric="logloss",
    tree_method="hist",
    device="cuda",
    scale_pos_weight=scale_pos_weight,
    random_state=seed
)
final_model.fit(x, y)


# 預測 Test Set
y_test_proba = final_model.predict_proba(X_test.values)[:, 1]
y_test_pred = (y_test_proba >= 0.5).astype(int)

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_proba)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:                  {f1:.4f}")

# %% [markdown]
# #### Adaboost(balanced-weight)

# %%
# === 超參數範圍 (三層 Grid Search) ===
n_estimators_list = [50, 100, 150, 200, 250, 300, 350, 400]
learning_rate_list = [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1.0]
base_estimators = [
    DecisionTreeClassifier(max_depth=1, class_weight="balanced"),
    DecisionTreeClassifier(max_depth=2, class_weight="balanced"),
    DecisionTreeClassifier(max_depth=3, class_weight="balanced"),
]
param_grid = list(product(n_estimators_list, learning_rate_list, base_estimators))

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None

print("Running Grid Search over n_estimators, learning_rate, and base_estimator with 5-Fold Stratified CV...\n")

for n_estimators, lr, base in tqdm(param_grid):
    fold_train_bal_acc, fold_val_bal_acc = [], []
    fold_train_acc, fold_val_acc = [], []
    fold_train_sens, fold_val_sens = [], []
    fold_train_spec, fold_val_spec = [], []

    for train_idx, val_idx in cv.split(x, y):
        x_train_fold, y_train_fold = x[train_idx], y[train_idx]
        x_val_fold, y_val_fold = x[val_idx], y[val_idx]

        # === AdaBoost 模型 ===
        clf = AdaBoostClassifier(
            estimator=base,
            n_estimators=n_estimators,
            learning_rate=lr,
            random_state=seed
        )
        clf.fit(x_train_fold, y_train_fold)

        # === 訓練集
        y_train_pred = clf.predict(x_train_fold)
        tn, fp, fn, tp = confusion_matrix(y_train_fold, y_train_pred).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_acc = (tp + tn) / (tp + tn + fp + fn)
        train_bal_acc = (train_sens + train_spec) / 2

        fold_train_bal_acc.append(train_bal_acc)
        fold_train_acc.append(train_acc)
        fold_train_sens.append(train_sens)
        fold_train_spec.append(train_spec)

        # === 驗證集
        y_val_pred = clf.predict(x_val_fold)
        tn, fp, fn, tp = confusion_matrix(y_val_fold, y_val_pred).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        val_acc = (tp + tn) / (tp + tn + fp + fn)
        val_bal_acc = (val_sens + val_spec) / 2

        fold_val_bal_acc.append(val_bal_acc)
        fold_val_acc.append(val_acc)
        fold_val_sens.append(val_sens)
        fold_val_spec.append(val_spec)

    # === 平均結果
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_train_acc = np.mean(fold_train_acc)
    avg_train_sens = np.mean(fold_train_sens)
    avg_train_spec = np.mean(fold_train_spec)

    avg_val_bal_acc = np.mean(fold_val_bal_acc)
    avg_val_acc = np.mean(fold_val_acc)
    avg_val_sens = np.mean(fold_val_sens)
    avg_val_spec = np.mean(fold_val_spec)

    print(f"\nMean over folds for n_estimators={n_estimators}, lr={lr}, base={base}:")
    print(f"  Train - BalAcc: {avg_train_bal_acc:.4f} Acc: {avg_train_acc:.4f} Sens: {avg_train_sens:.4f} Spec: {avg_train_spec:.4f}")
    print(f"  Val   - BalAcc: {avg_val_bal_acc:.4f} Acc: {avg_val_acc:.4f} Sens: {avg_val_sens:.4f} Spec: {avg_val_spec:.4f}\n")

    # === 更新最佳結果
    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params = (n_estimators, lr, base)
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec,
        }

print("\n✅ Best Grid Search Result:")
print(f"Best n_estimators: {best_params[0]}")
print(f"Best learning_rate: {best_params[1]}")
print(f"Best base_estimator: {best_params[2]}")
print(f"Best Train Balanced Accuracy: {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Train Accuracy:          {best_metrics['Train Accuracy']:.4f}")
print(f"Best Train Sensitivity:       {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Train Specificity:       {best_metrics['Train Specificity']:.4f}")
print(f"Best Validation Balanced Accuracy: {best_metrics['Balanced Accuracy']:.4f}")
print(f"Best Validation Accuracy:          {best_metrics['Accuracy']:.4f}")
print(f"Best Validation Sensitivity:       {best_metrics['Sensitivity']:.4f}")
print(f"Best Validation Specificity:       {best_metrics['Specificity']:.4f}")
# Out:
# Running Grid Search over n_estimators, learning_rate, and base_estimator with 5-Fold Stratified CV...
#   0%|          | 0/168 [00:00<?, ?it/s]
# Mean over folds for n_estimators=50, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=50, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8096 Acc: 0.8751 Sens: 0.7300 Spec: 0.8893
#   Val   - BalAcc: 0.7971 Acc: 0.8708 Sens: 0.7075 Spec: 0.8867
#
#
# Mean over folds for n_estimators=50, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=50, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8133 Acc: 0.8698 Sens: 0.7446 Spec: 0.8820
#   Val   - BalAcc: 0.7970 Acc: 0.8647 Sens: 0.7148 Spec: 0.8793
#
#
# Mean over folds for n_estimators=50, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8043 Acc: 0.8851 Sens: 0.7059 Spec: 0.9026
#   Val   - BalAcc: 0.7960 Acc: 0.8828 Sens: 0.6904 Spec: 0.9015
#
#
# Mean over folds for n_estimators=50, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8077 Acc: 0.8887 Sens: 0.7092 Spec: 0.9062
#   Val   - BalAcc: 0.7984 Acc: 0.8861 Sens: 0.6919 Spec: 0.9050
#
#
# Mean over folds for n_estimators=50, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=50, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=50, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=50, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=50, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=50, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=50, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=50, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=100, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=100, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8092 Acc: 0.8738 Sens: 0.7307 Spec: 0.8878
#   Val   - BalAcc: 0.7986 Acc: 0.8700 Sens: 0.7119 Spec: 0.8854
#
#
# Mean over folds for n_estimators=100, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8043 Acc: 0.8851 Sens: 0.7059 Spec: 0.9026
#   Val   - BalAcc: 0.7960 Acc: 0.8828 Sens: 0.6904 Spec: 0.9015
#
#
# Mean over folds for n_estimators=100, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8073 Acc: 0.8886 Sens: 0.7084 Spec: 0.9062
#   Val   - BalAcc: 0.7985 Acc: 0.8862 Sens: 0.6919 Spec: 0.9052
#
#
# Mean over folds for n_estimators=100, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=100, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=100, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=100, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=100, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=100, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=100, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=100, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=100, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=150, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=150, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8120 Acc: 0.8665 Sens: 0.7457 Spec: 0.8783
#   Val   - BalAcc: 0.7986 Acc: 0.8616 Sens: 0.7219 Spec: 0.8752
#
#
# Mean over folds for n_estimators=150, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8059 Acc: 0.8934 Sens: 0.6995 Spec: 0.9123
#   Val   - BalAcc: 0.8006 Acc: 0.8924 Sens: 0.6890 Spec: 0.9123
#
#
# Mean over folds for n_estimators=150, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=150, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=150, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=150, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=150, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=150, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=150, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=150, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=150, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=200, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=200, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8133 Acc: 0.8706 Sens: 0.7436 Spec: 0.8830
#   Val   - BalAcc: 0.7973 Acc: 0.8652 Sens: 0.7148 Spec: 0.8798
#
#
# Mean over folds for n_estimators=200, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8005 Acc: 0.8933 Sens: 0.6876 Spec: 0.9134
#
#
# Mean over folds for n_estimators=200, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=200, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=200, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=200, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=200, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=200, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=200, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=200, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=250, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=250, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8136 Acc: 0.8701 Sens: 0.7450 Spec: 0.8823
#   Val   - BalAcc: 0.7972 Acc: 0.8649 Sens: 0.7148 Spec: 0.8796
#
#
# Mean over folds for n_estimators=250, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8005 Acc: 0.8933 Sens: 0.6876 Spec: 0.9134
#
#
# Mean over folds for n_estimators=250, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=250, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=250, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=250, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=250, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=250, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=250, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=250, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=250, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=300, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8072 Acc: 0.8566 Sens: 0.7471 Spec: 0.8673
#   Val   - BalAcc: 0.8014 Acc: 0.8561 Sens: 0.7348 Spec: 0.8680
#
#
# Mean over folds for n_estimators=300, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8138 Acc: 0.8721 Sens: 0.7428 Spec: 0.8847
#   Val   - BalAcc: 0.7964 Acc: 0.8659 Sens: 0.7119 Spec: 0.8810
#
#
# Mean over folds for n_estimators=300, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8005 Acc: 0.8933 Sens: 0.6876 Spec: 0.9134
#
#
# Mean over folds for n_estimators=300, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=300, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=300, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=300, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=300, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=300, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=300, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=300, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=350, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8077 Acc: 0.8654 Sens: 0.7375 Spec: 0.8779
#   Val   - BalAcc: 0.7987 Acc: 0.8630 Sens: 0.7205 Spec: 0.8769
#
#
# Mean over folds for n_estimators=350, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8134 Acc: 0.8714 Sens: 0.7428 Spec: 0.8840
#   Val   - BalAcc: 0.7982 Acc: 0.8668 Sens: 0.7148 Spec: 0.8817
#
#
# Mean over folds for n_estimators=350, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8005 Acc: 0.8933 Sens: 0.6876 Spec: 0.9134
#
#
# Mean over folds for n_estimators=350, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=350, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=350, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=350, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=350, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=350, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=350, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=350, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=350, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=400, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8049 Acc: 0.8827 Sens: 0.7102 Spec: 0.8995
#   Val   - BalAcc: 0.7968 Acc: 0.8807 Sens: 0.6947 Spec: 0.8989
#
#
# Mean over folds for n_estimators=400, lr=0.001, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8121 Acc: 0.8770 Sens: 0.7332 Spec: 0.8911
#   Val   - BalAcc: 0.7981 Acc: 0.8737 Sens: 0.7062 Spec: 0.8901
#
#
# Mean over folds for n_estimators=400, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.005, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8005 Acc: 0.8933 Sens: 0.6876 Spec: 0.9134
#
#
# Mean over folds for n_estimators=400, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.01, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8044 Acc: 0.8945 Sens: 0.6948 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=400, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.05, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8065 Acc: 0.8919 Sens: 0.7027 Spec: 0.9103
#   Val   - BalAcc: 0.7996 Acc: 0.8894 Sens: 0.6904 Spec: 0.9088
#
#
# Mean over folds for n_estimators=400, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8029 Acc: 0.8871 Sens: 0.7006 Spec: 0.9053
#   Val   - BalAcc: 0.7973 Acc: 0.8852 Sens: 0.6905 Spec: 0.9042
#
#
# Mean over folds for n_estimators=400, lr=0.1, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8052 Acc: 0.8924 Sens: 0.6991 Spec: 0.9113
#   Val   - BalAcc: 0.8011 Acc: 0.8909 Sens: 0.6919 Spec: 0.9103
#
#
# Mean over folds for n_estimators=400, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=400, lr=0.5, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# Mean over folds for n_estimators=400, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=1):
#   Train - BalAcc: 0.7995 Acc: 0.8951 Sens: 0.6834 Spec: 0.9157
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=400, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=2):
#   Train - BalAcc: 0.8067 Acc: 0.8536 Sens: 0.7496 Spec: 0.8638
#   Val   - BalAcc: 0.8046 Acc: 0.8537 Sens: 0.7449 Spec: 0.8643
#
#
# Mean over folds for n_estimators=400, lr=1.0, base=DecisionTreeClassifier(class_weight='balanced', max_depth=3):
#   Train - BalAcc: 0.8113 Acc: 0.8723 Sens: 0.7371 Spec: 0.8855
#   Val   - BalAcc: 0.7990 Acc: 0.8684 Sens: 0.7147 Spec: 0.8833
#
#
# ✅ Best Grid Search Result:
# Best n_estimators: 50
# Best learning_rate: 0.001
# Best base_estimator: DecisionTreeClassifier(class_weight='balanced', max_depth=2)
# Best Train Balanced Accuracy: 0.8067
# Best Train Accuracy:          0.8536
# Best Train Sensitivity:       0.7496
# Best Train Specificity:       0.8638
# Best Validation Balanced Accuracy: 0.8046
# Best Validation Accuracy:          0.8537
# Best Validation Sensitivity:       0.7449
# Best Validation Specificity:       0.8643

# %% [markdown]
# ##### Test

# %%
# === 用最佳參數訓練 Final Model ===
best_n_estimators, best_lr, best_base = best_params
final_model = AdaBoostClassifier(
    estimator=best_base,
    n_estimators=best_n_estimators,
    learning_rate=best_lr,
    random_state=seed
)
final_model.fit(x, y)


y_test_pred = final_model.predict(X_test.values)
y_test_proba = final_model.predict_proba(X_test.values)[:, 1]

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_proba)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 混淆矩陣 DataFrame (Wikipedia 格式)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:                  {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 127                  48
# Actual Negative                 246                1541
# Sensitivity (Recall, TPR): 0.7257
# Specificity (TNR):         0.8623
# Accuracy:                  0.8502
# Balanced Accuracy:         0.7940
# AUC:                       0.7940
# F1 Score:                  0.4635

# %% [markdown]
# #### Catboost(balanced-weight)

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({np.int64(0): 7149, np.int64(1): 698})
# scale_pos_weight = 10.2421

# %%
x = X_train
y = y_train

# %%
# === 超參數範圍 (Grid Search for CatBoost) ===
n_estimators_list = [100, 200, 300, 400, 500, 600, 700, 800]
learning_rate_list = [0.001, 0.005, 0.01, 0.05, 0.1, 0.2]
max_depth_list = [3, 5, 7, 9]
l2_leaf_reg_list = [2**i for i in range(1, 7)]
param_grid = list(product(n_estimators_list, learning_rate_list, max_depth_list, l2_leaf_reg_list))
class_weights = {0: 1.0, 1: scale_pos_weight}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

best_score = 0
best_params = None
best_metrics = None

print("Running Grid Search over n_estimators, learning_rate, max_depth with 5-Fold Stratified CV...\n")

for n_estimators, lr, max_depth, l2_leaf_reg in tqdm(param_grid):
    fold_train_bal_acc, fold_val_bal_acc = [], []
    fold_train_acc, fold_val_acc = [], []
    fold_train_sens, fold_val_sens = [], []
    fold_train_spec, fold_val_spec = [], []

    for train_idx, val_idx in cv.split(x, y):
        x_train_fold, y_train_fold = x.iloc[train_idx], y.iloc[train_idx]
        x_val_fold, y_val_fold     = x.iloc[val_idx], y.iloc[val_idx]

        # === CatBoost 模型 ===
        clf = CatBoostClassifier(
        iterations=n_estimators,
        learning_rate=lr,
        depth=max_depth,
        l2_leaf_reg=l2_leaf_reg,
        loss_function="Logloss",
        eval_metric="BalancedAccuracy",  # CPU 模式支援 BalancedAccuracy
        class_weights=class_weights,
        random_seed=seed,
        verbose=0,
        task_type="CPU"   # 改成 CPU
        )

        clf.fit(x_train_fold, y_train_fold)
        # === 訓練集
        y_train_pred = clf.predict(x_train_fold)
        tn, fp, fn, tp = confusion_matrix(y_train_fold, y_train_pred).ravel()
        train_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        train_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        train_acc = (tp + tn) / (tp + tn + fp + fn)
        train_bal_acc = (train_sens + train_spec) / 2

        fold_train_bal_acc.append(train_bal_acc)
        fold_train_acc.append(train_acc)
        fold_train_sens.append(train_sens)
        fold_train_spec.append(train_spec)

        # === 驗證集
        y_val_pred = clf.predict(x_val_fold)
        tn, fp, fn, tp = confusion_matrix(y_val_fold, y_val_pred).ravel()
        val_sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        val_spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        val_acc = (tp + tn) / (tp + tn + fp + fn)
        val_bal_acc = (val_sens + val_spec) / 2

        fold_val_bal_acc.append(val_bal_acc)
        fold_val_acc.append(val_acc)
        fold_val_sens.append(val_sens)
        fold_val_spec.append(val_spec)

    # === 平均結果
    avg_train_bal_acc = np.mean(fold_train_bal_acc)
    avg_train_acc = np.mean(fold_train_acc)
    avg_train_sens = np.mean(fold_train_sens)
    avg_train_spec = np.mean(fold_train_spec)

    avg_val_bal_acc = np.mean(fold_val_bal_acc)
    avg_val_acc = np.mean(fold_val_acc)
    avg_val_sens = np.mean(fold_val_sens)
    avg_val_spec = np.mean(fold_val_spec)

    print(f"\nMean over folds for n_estimators={n_estimators}, lr={lr}, max_depth={max_depth}, l2_leaf_reg={l2_leaf_reg}:")
    print(f"  Train - BalAcc: {avg_train_bal_acc:.4f} Acc: {avg_train_acc:.4f} Sens: {avg_train_sens:.4f} Spec: {avg_train_spec:.4f}")
    print(f"  Val   - BalAcc: {avg_val_bal_acc:.4f} Acc: {avg_val_acc:.4f} Sens: {avg_val_sens:.4f} Spec: {avg_val_spec:.4f}\n")

    # === 更新最佳結果
    if avg_val_bal_acc > best_score:
        best_score = avg_val_bal_acc
        best_params =  (n_estimators, lr, max_depth, l2_leaf_reg)
        best_metrics = {
            "Balanced Accuracy": avg_val_bal_acc,
            "Accuracy": avg_val_acc,
            "Sensitivity": avg_val_sens,
            "Specificity": avg_val_spec,
            "Train Balanced Accuracy": avg_train_bal_acc,
            "Train Accuracy": avg_train_acc,
            "Train Sensitivity": avg_train_sens,
            "Train Specificity": avg_train_spec,
        }

print("\n✅ Best Grid Search Result:")
print("\n✅ Best Grid Search Result:")
print(f"Best n_estimators: {best_params[0]}")
print(f"Best learning_rate: {best_params[1]}")
print(f"Best max_depth:     {best_params[2]}")
print(f"Best l2_leaf_reg:   {best_params[3]}")
print(f"Best Train Balanced Accuracy: {best_metrics['Train Balanced Accuracy']:.4f}")
print(f"Best Train Accuracy:          {best_metrics['Train Accuracy']:.4f}")
print(f"Best Train Sensitivity:       {best_metrics['Train Sensitivity']:.4f}")
print(f"Best Train Specificity:       {best_metrics['Train Specificity']:.4f}")
print(f"Best Validation Balanced Accuracy: {best_metrics['Balanced Accuracy']:.4f}")
print(f"Best Validation Accuracy:          {best_metrics['Accuracy']:.4f}")
print(f"Best Validation Sensitivity:       {best_metrics['Sensitivity']:.4f}")
print(f"Best Validation Specificity:       {best_metrics['Specificity']:.4f}")
# Out:
# Running Grid Search over n_estimators, learning_rate, max_depth with 5-Fold Stratified CV...
#   0%|          | 0/1152 [00:00<?, ?it/s]
# 串流輸出內容已截斷至最後 5000 行。
# Mean over folds for n_estimators=200, lr=0.001, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8050 Acc: 0.8962 Sens: 0.6941 Spec: 0.9159
#   Val   - BalAcc: 0.7988 Acc: 0.8950 Sens: 0.6818 Spec: 0.9158
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8038 Acc: 0.8960 Sens: 0.6916 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8029 Acc: 0.8958 Sens: 0.6898 Spec: 0.9159
#   Val   - BalAcc: 0.7988 Acc: 0.8950 Sens: 0.6818 Spec: 0.9158
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8024 Acc: 0.8956 Sens: 0.6891 Spec: 0.9158
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8016 Acc: 0.8955 Sens: 0.6873 Spec: 0.9158
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.7993 Acc: 0.8952 Sens: 0.6827 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8133 Acc: 0.8977 Sens: 0.7106 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8125 Acc: 0.8975 Sens: 0.7092 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8947 Sens: 0.6818 Spec: 0.9155
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8102 Acc: 0.8969 Sens: 0.7049 Spec: 0.9156
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8078 Acc: 0.8965 Sens: 0.6999 Spec: 0.9157
#   Val   - BalAcc: 0.7986 Acc: 0.8946 Sens: 0.6818 Spec: 0.9154
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8046 Acc: 0.8959 Sens: 0.6934 Spec: 0.9157
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=200, lr=0.001, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8009 Acc: 0.8955 Sens: 0.6859 Spec: 0.9159
#   Val   - BalAcc: 0.7988 Acc: 0.8950 Sens: 0.6818 Spec: 0.9158
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.8034 Acc: 0.8956 Sens: 0.6913 Spec: 0.9155
#   Val   - BalAcc: 0.7986 Acc: 0.8946 Sens: 0.6818 Spec: 0.9154
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8040 Acc: 0.8954 Sens: 0.6927 Spec: 0.9152
#   Val   - BalAcc: 0.8007 Acc: 0.8949 Sens: 0.6861 Spec: 0.9152
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8029 Acc: 0.8953 Sens: 0.6905 Spec: 0.9153
#   Val   - BalAcc: 0.7992 Acc: 0.8945 Sens: 0.6833 Spec: 0.9151
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8028 Acc: 0.8952 Sens: 0.6905 Spec: 0.9151
#   Val   - BalAcc: 0.7998 Acc: 0.8945 Sens: 0.6847 Spec: 0.9150
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8013 Acc: 0.8950 Sens: 0.6873 Spec: 0.9153
#   Val   - BalAcc: 0.7992 Acc: 0.8946 Sens: 0.6833 Spec: 0.9152
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8012 Acc: 0.8949 Sens: 0.6873 Spec: 0.9151
#   Val   - BalAcc: 0.8006 Acc: 0.8947 Sens: 0.6861 Spec: 0.9151
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8127 Acc: 0.8969 Sens: 0.7102 Spec: 0.9152
#   Val   - BalAcc: 0.7998 Acc: 0.8944 Sens: 0.6847 Spec: 0.9148
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8124 Acc: 0.8969 Sens: 0.7095 Spec: 0.9152
#   Val   - BalAcc: 0.7996 Acc: 0.8941 Sens: 0.6847 Spec: 0.9145
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8120 Acc: 0.8968 Sens: 0.7088 Spec: 0.9151
#   Val   - BalAcc: 0.8002 Acc: 0.8940 Sens: 0.6861 Spec: 0.9143
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8102 Acc: 0.8960 Sens: 0.7059 Spec: 0.9145
#   Val   - BalAcc: 0.8000 Acc: 0.8936 Sens: 0.6861 Spec: 0.9138
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8079 Acc: 0.8955 Sens: 0.7013 Spec: 0.9144
#   Val   - BalAcc: 0.8007 Acc: 0.8937 Sens: 0.6876 Spec: 0.9138
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8060 Acc: 0.8950 Sens: 0.6977 Spec: 0.9143
#   Val   - BalAcc: 0.8006 Acc: 0.8935 Sens: 0.6876 Spec: 0.9136
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8278 Acc: 0.9002 Sens: 0.7396 Spec: 0.9159
#   Val   - BalAcc: 0.7986 Acc: 0.8946 Sens: 0.6818 Spec: 0.9154
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8246 Acc: 0.8995 Sens: 0.7335 Spec: 0.9157
#   Val   - BalAcc: 0.7992 Acc: 0.8946 Sens: 0.6833 Spec: 0.9152
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8225 Acc: 0.8989 Sens: 0.7296 Spec: 0.9154
#   Val   - BalAcc: 0.7999 Acc: 0.8946 Sens: 0.6847 Spec: 0.9151
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8177 Acc: 0.8977 Sens: 0.7203 Spec: 0.9151
#   Val   - BalAcc: 0.7997 Acc: 0.8942 Sens: 0.6847 Spec: 0.9147
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8132 Acc: 0.8966 Sens: 0.7117 Spec: 0.9147
#   Val   - BalAcc: 0.8002 Acc: 0.8940 Sens: 0.6861 Spec: 0.9143
#
#
# Mean over folds for n_estimators=200, lr=0.005, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8092 Acc: 0.8959 Sens: 0.7038 Spec: 0.9147
#   Val   - BalAcc: 0.7990 Acc: 0.8941 Sens: 0.6833 Spec: 0.9147
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8027 Acc: 0.8940 Sens: 0.6916 Spec: 0.9137
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8026 Acc: 0.8942 Sens: 0.6913 Spec: 0.9140
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8031 Acc: 0.8935 Sens: 0.6930 Spec: 0.9131
#   Val   - BalAcc: 0.8003 Acc: 0.8931 Sens: 0.6876 Spec: 0.9131
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8034 Acc: 0.8935 Sens: 0.6938 Spec: 0.9130
#   Val   - BalAcc: 0.8001 Acc: 0.8927 Sens: 0.6876 Spec: 0.9127
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8024 Acc: 0.8934 Sens: 0.6916 Spec: 0.9131
#   Val   - BalAcc: 0.8002 Acc: 0.8928 Sens: 0.6876 Spec: 0.9129
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8024 Acc: 0.8934 Sens: 0.6916 Spec: 0.9131
#   Val   - BalAcc: 0.8004 Acc: 0.8932 Sens: 0.6876 Spec: 0.9133
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.8132 Acc: 0.8945 Sens: 0.7142 Spec: 0.9122
#   Val   - BalAcc: 0.7987 Acc: 0.8912 Sens: 0.6861 Spec: 0.9112
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8123 Acc: 0.8941 Sens: 0.7127 Spec: 0.9118
#   Val   - BalAcc: 0.7997 Acc: 0.8907 Sens: 0.6890 Spec: 0.9103
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8110 Acc: 0.8932 Sens: 0.7110 Spec: 0.9110
#   Val   - BalAcc: 0.7995 Acc: 0.8904 Sens: 0.6890 Spec: 0.9101
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8107 Acc: 0.8934 Sens: 0.7102 Spec: 0.9112
#   Val   - BalAcc: 0.8001 Acc: 0.8903 Sens: 0.6904 Spec: 0.9098
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8096 Acc: 0.8927 Sens: 0.7084 Spec: 0.9107
#   Val   - BalAcc: 0.8007 Acc: 0.8901 Sens: 0.6919 Spec: 0.9095
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8094 Acc: 0.8921 Sens: 0.7088 Spec: 0.9100
#   Val   - BalAcc: 0.8007 Acc: 0.8901 Sens: 0.6919 Spec: 0.9095
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8239 Acc: 0.8981 Sens: 0.7335 Spec: 0.9142
#   Val   - BalAcc: 0.7996 Acc: 0.8930 Sens: 0.6861 Spec: 0.9131
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8236 Acc: 0.8979 Sens: 0.7332 Spec: 0.9139
#   Val   - BalAcc: 0.7999 Acc: 0.8922 Sens: 0.6876 Spec: 0.9122
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8224 Acc: 0.8970 Sens: 0.7317 Spec: 0.9131
#   Val   - BalAcc: 0.8005 Acc: 0.8922 Sens: 0.6890 Spec: 0.9120
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8196 Acc: 0.8957 Sens: 0.7271 Spec: 0.9122
#   Val   - BalAcc: 0.7995 Acc: 0.8904 Sens: 0.6890 Spec: 0.9101
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8160 Acc: 0.8942 Sens: 0.7210 Spec: 0.9111
#   Val   - BalAcc: 0.7986 Acc: 0.8899 Sens: 0.6876 Spec: 0.9096
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8123 Acc: 0.8930 Sens: 0.7142 Spec: 0.9105
#   Val   - BalAcc: 0.7991 Acc: 0.8896 Sens: 0.6890 Spec: 0.9092
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8448 Acc: 0.9054 Sens: 0.7711 Spec: 0.9185
#   Val   - BalAcc: 0.7987 Acc: 0.8947 Sens: 0.6818 Spec: 0.9155
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8406 Acc: 0.9030 Sens: 0.7647 Spec: 0.9165
#   Val   - BalAcc: 0.7991 Acc: 0.8944 Sens: 0.6833 Spec: 0.9150
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8368 Acc: 0.9011 Sens: 0.7586 Spec: 0.9150
#   Val   - BalAcc: 0.7987 Acc: 0.8936 Sens: 0.6833 Spec: 0.9141
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8316 Acc: 0.8995 Sens: 0.7489 Spec: 0.9142
#   Val   - BalAcc: 0.8009 Acc: 0.8930 Sens: 0.6890 Spec: 0.9129
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8257 Acc: 0.8979 Sens: 0.7378 Spec: 0.9135
#   Val   - BalAcc: 0.8004 Acc: 0.8921 Sens: 0.6890 Spec: 0.9119
#
#
# Mean over folds for n_estimators=200, lr=0.01, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8182 Acc: 0.8960 Sens: 0.7235 Spec: 0.9129
#   Val   - BalAcc: 0.7996 Acc: 0.8917 Sens: 0.6876 Spec: 0.9116
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8184 Acc: 0.8882 Sens: 0.7335 Spec: 0.9033
#   Val   - BalAcc: 0.8044 Acc: 0.8839 Sens: 0.7076 Spec: 0.9011
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8191 Acc: 0.8880 Sens: 0.7353 Spec: 0.9029
#   Val   - BalAcc: 0.8032 Acc: 0.8829 Sens: 0.7062 Spec: 0.9001
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8174 Acc: 0.8861 Sens: 0.7339 Spec: 0.9010
#   Val   - BalAcc: 0.8003 Acc: 0.8824 Sens: 0.7005 Spec: 0.9001
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8175 Acc: 0.8862 Sens: 0.7339 Spec: 0.9011
#   Val   - BalAcc: 0.8027 Acc: 0.8820 Sens: 0.7062 Spec: 0.8991
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8147 Acc: 0.8842 Sens: 0.7303 Spec: 0.8992
#   Val   - BalAcc: 0.8031 Acc: 0.8816 Sens: 0.7076 Spec: 0.8986
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8146 Acc: 0.8836 Sens: 0.7307 Spec: 0.8986
#   Val   - BalAcc: 0.8061 Acc: 0.8811 Sens: 0.7148 Spec: 0.8973
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.8562 Acc: 0.9058 Sens: 0.7958 Spec: 0.9165
#   Val   - BalAcc: 0.7993 Acc: 0.8887 Sens: 0.6904 Spec: 0.9081
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8526 Acc: 0.9028 Sens: 0.7915 Spec: 0.9137
#   Val   - BalAcc: 0.7998 Acc: 0.8885 Sens: 0.6918 Spec: 0.9077
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8501 Acc: 0.9012 Sens: 0.7880 Spec: 0.9123
#   Val   - BalAcc: 0.8013 Acc: 0.8877 Sens: 0.6961 Spec: 0.9064
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8445 Acc: 0.8983 Sens: 0.7790 Spec: 0.9100
#   Val   - BalAcc: 0.8014 Acc: 0.8867 Sens: 0.6976 Spec: 0.9052
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8389 Acc: 0.8949 Sens: 0.7708 Spec: 0.9070
#   Val   - BalAcc: 0.8040 Acc: 0.8867 Sens: 0.7033 Spec: 0.9046
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8334 Acc: 0.8911 Sens: 0.7633 Spec: 0.9036
#   Val   - BalAcc: 0.8047 Acc: 0.8845 Sens: 0.7076 Spec: 0.9018
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.9247 Acc: 0.9394 Sens: 0.9069 Spec: 0.9426
#   Val   - BalAcc: 0.7898 Acc: 0.9010 Sens: 0.6546 Spec: 0.9250
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9175 Acc: 0.9335 Sens: 0.8979 Spec: 0.9370
#   Val   - BalAcc: 0.7911 Acc: 0.8986 Sens: 0.6603 Spec: 0.9218
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9054 Acc: 0.9266 Sens: 0.8797 Spec: 0.9312
#   Val   - BalAcc: 0.7967 Acc: 0.8959 Sens: 0.6761 Spec: 0.9173
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8924 Acc: 0.9197 Sens: 0.8592 Spec: 0.9255
#   Val   - BalAcc: 0.7965 Acc: 0.8932 Sens: 0.6790 Spec: 0.9141
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8791 Acc: 0.9119 Sens: 0.8392 Spec: 0.9190
#   Val   - BalAcc: 0.7985 Acc: 0.8896 Sens: 0.6876 Spec: 0.9094
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8614 Acc: 0.9032 Sens: 0.8105 Spec: 0.9123
#   Val   - BalAcc: 0.7991 Acc: 0.8861 Sens: 0.6933 Spec: 0.9049
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.9808 Acc: 0.9762 Sens: 0.9864 Spec: 0.9752
#   Val   - BalAcc: 0.7718 Acc: 0.9093 Sens: 0.6045 Spec: 0.9390
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.9700 Acc: 0.9649 Sens: 0.9764 Spec: 0.9637
#   Val   - BalAcc: 0.7752 Acc: 0.9061 Sens: 0.6160 Spec: 0.9344
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9572 Acc: 0.9539 Sens: 0.9613 Spec: 0.9531
#   Val   - BalAcc: 0.7896 Acc: 0.9030 Sens: 0.6517 Spec: 0.9275
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9450 Acc: 0.9425 Sens: 0.9481 Spec: 0.9419
#   Val   - BalAcc: 0.7929 Acc: 0.9007 Sens: 0.6618 Spec: 0.9240
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9256 Acc: 0.9298 Sens: 0.9205 Spec: 0.9307
#   Val   - BalAcc: 0.7963 Acc: 0.8964 Sens: 0.6747 Spec: 0.9180
#
#
# Mean over folds for n_estimators=200, lr=0.05, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8987 Acc: 0.9167 Sens: 0.8768 Spec: 0.9206
#   Val   - BalAcc: 0.7979 Acc: 0.8909 Sens: 0.6847 Spec: 0.9110
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8585 Acc: 0.9020 Sens: 0.8055 Spec: 0.9114
#   Val   - BalAcc: 0.7958 Acc: 0.8836 Sens: 0.6890 Spec: 0.9026
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8565 Acc: 0.9011 Sens: 0.8023 Spec: 0.9107
#   Val   - BalAcc: 0.7951 Acc: 0.8847 Sens: 0.6861 Spec: 0.9040
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8546 Acc: 0.8994 Sens: 0.8001 Spec: 0.9091
#   Val   - BalAcc: 0.7956 Acc: 0.8857 Sens: 0.6861 Spec: 0.9052
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8496 Acc: 0.8973 Sens: 0.7915 Spec: 0.9076
#   Val   - BalAcc: 0.7988 Acc: 0.8833 Sens: 0.6961 Spec: 0.9015
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8407 Acc: 0.8941 Sens: 0.7758 Spec: 0.9057
#   Val   - BalAcc: 0.8009 Acc: 0.8824 Sens: 0.7019 Spec: 0.9000
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8354 Acc: 0.8912 Sens: 0.7675 Spec: 0.9033
#   Val   - BalAcc: 0.8006 Acc: 0.8806 Sens: 0.7033 Spec: 0.8979
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9380 Acc: 0.9392 Sens: 0.9366 Spec: 0.9395
#   Val   - BalAcc: 0.7898 Acc: 0.8986 Sens: 0.6575 Spec: 0.9221
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.9303 Acc: 0.9336 Sens: 0.9262 Spec: 0.9343
#   Val   - BalAcc: 0.7904 Acc: 0.8961 Sens: 0.6618 Spec: 0.9190
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.9208 Acc: 0.9296 Sens: 0.9101 Spec: 0.9315
#   Val   - BalAcc: 0.7897 Acc: 0.8937 Sens: 0.6632 Spec: 0.9162
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.9106 Acc: 0.9243 Sens: 0.8940 Spec: 0.9272
#   Val   - BalAcc: 0.7937 Acc: 0.8927 Sens: 0.6732 Spec: 0.9141
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8968 Acc: 0.9162 Sens: 0.8732 Spec: 0.9204
#   Val   - BalAcc: 0.7941 Acc: 0.8899 Sens: 0.6775 Spec: 0.9106
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8804 Acc: 0.9092 Sens: 0.8453 Spec: 0.9154
#   Val   - BalAcc: 0.7979 Acc: 0.8886 Sens: 0.6876 Spec: 0.9082
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.9831 Acc: 0.9775 Sens: 0.9900 Spec: 0.9763
#   Val   - BalAcc: 0.7618 Acc: 0.9088 Sens: 0.5830 Spec: 0.9405
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9774 Acc: 0.9694 Sens: 0.9871 Spec: 0.9677
#   Val   - BalAcc: 0.7610 Acc: 0.9049 Sens: 0.5859 Spec: 0.9361
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9675 Acc: 0.9591 Sens: 0.9778 Spec: 0.9573
#   Val   - BalAcc: 0.7804 Acc: 0.9039 Sens: 0.6302 Spec: 0.9306
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9588 Acc: 0.9499 Sens: 0.9696 Spec: 0.9480
#   Val   - BalAcc: 0.7835 Acc: 0.9001 Sens: 0.6417 Spec: 0.9253
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9464 Acc: 0.9395 Sens: 0.9549 Spec: 0.9380
#   Val   - BalAcc: 0.7891 Acc: 0.8973 Sens: 0.6575 Spec: 0.9207
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.9259 Acc: 0.9283 Sens: 0.9230 Spec: 0.9288
#   Val   - BalAcc: 0.7912 Acc: 0.8930 Sens: 0.6675 Spec: 0.9150
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.9983 Acc: 0.9969 Sens: 1.0000 Spec: 0.9966
#   Val   - BalAcc: 0.7360 Acc: 0.9135 Sens: 0.5200 Spec: 0.9519
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.9956 Acc: 0.9929 Sens: 0.9989 Spec: 0.9923
#   Val   - BalAcc: 0.7478 Acc: 0.9139 Sens: 0.5458 Spec: 0.9498
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9907 Acc: 0.9856 Sens: 0.9968 Spec: 0.9845
#   Val   - BalAcc: 0.7636 Acc: 0.9109 Sens: 0.5844 Spec: 0.9428
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9827 Acc: 0.9747 Sens: 0.9925 Spec: 0.9730
#   Val   - BalAcc: 0.7714 Acc: 0.9075 Sens: 0.6059 Spec: 0.9369
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9731 Acc: 0.9610 Sens: 0.9878 Spec: 0.9584
#   Val   - BalAcc: 0.7789 Acc: 0.9035 Sens: 0.6274 Spec: 0.9305
#
#
# Mean over folds for n_estimators=200, lr=0.1, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9573 Acc: 0.9457 Sens: 0.9713 Spec: 0.9432
#   Val   - BalAcc: 0.7921 Acc: 0.9005 Sens: 0.6603 Spec: 0.9239
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.9210 Acc: 0.9272 Sens: 0.9133 Spec: 0.9286
#   Val   - BalAcc: 0.7838 Acc: 0.8901 Sens: 0.6546 Spec: 0.9131
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.9138 Acc: 0.9251 Sens: 0.9001 Spec: 0.9275
#   Val   - BalAcc: 0.7892 Acc: 0.8893 Sens: 0.6675 Spec: 0.9109
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.9080 Acc: 0.9210 Sens: 0.8922 Spec: 0.9238
#   Val   - BalAcc: 0.7852 Acc: 0.8856 Sens: 0.6632 Spec: 0.9073
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.9013 Acc: 0.9183 Sens: 0.8807 Spec: 0.9219
#   Val   - BalAcc: 0.7894 Acc: 0.8849 Sens: 0.6732 Spec: 0.9056
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8933 Acc: 0.9137 Sens: 0.8685 Spec: 0.9181
#   Val   - BalAcc: 0.7900 Acc: 0.8861 Sens: 0.6732 Spec: 0.9068
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8792 Acc: 0.9074 Sens: 0.8449 Spec: 0.9134
#   Val   - BalAcc: 0.7956 Acc: 0.8844 Sens: 0.6875 Spec: 0.9036
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9808 Acc: 0.9729 Sens: 0.9903 Spec: 0.9712
#   Val   - BalAcc: 0.7573 Acc: 0.9040 Sens: 0.5787 Spec: 0.9358
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.9757 Acc: 0.9675 Sens: 0.9857 Spec: 0.9658
#   Val   - BalAcc: 0.7554 Acc: 0.9017 Sens: 0.5773 Spec: 0.9334
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.9726 Acc: 0.9621 Sens: 0.9853 Spec: 0.9599
#   Val   - BalAcc: 0.7655 Acc: 0.9025 Sens: 0.5988 Spec: 0.9322
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.9623 Acc: 0.9534 Sens: 0.9731 Spec: 0.9514
#   Val   - BalAcc: 0.7735 Acc: 0.8972 Sens: 0.6231 Spec: 0.9239
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.9498 Acc: 0.9427 Sens: 0.9585 Spec: 0.9412
#   Val   - BalAcc: 0.7822 Acc: 0.8941 Sens: 0.6460 Spec: 0.9183
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.9392 Acc: 0.9346 Sens: 0.9448 Spec: 0.9336
#   Val   - BalAcc: 0.7944 Acc: 0.8941 Sens: 0.6732 Spec: 0.9157
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.9982 Acc: 0.9970 Sens: 0.9996 Spec: 0.9967
#   Val   - BalAcc: 0.7342 Acc: 0.9137 Sens: 0.5157 Spec: 0.9526
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9964 Acc: 0.9937 Sens: 0.9996 Spec: 0.9931
#   Val   - BalAcc: 0.7402 Acc: 0.9117 Sens: 0.5315 Spec: 0.9488
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9927 Acc: 0.9876 Sens: 0.9989 Spec: 0.9865
#   Val   - BalAcc: 0.7443 Acc: 0.9088 Sens: 0.5443 Spec: 0.9443
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9880 Acc: 0.9807 Sens: 0.9968 Spec: 0.9792
#   Val   - BalAcc: 0.7589 Acc: 0.9095 Sens: 0.5758 Spec: 0.9421
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9791 Acc: 0.9691 Sens: 0.9914 Spec: 0.9669
#   Val   - BalAcc: 0.7684 Acc: 0.9031 Sens: 0.6045 Spec: 0.9323
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.9700 Acc: 0.9572 Sens: 0.9857 Spec: 0.9544
#   Val   - BalAcc: 0.7748 Acc: 0.8995 Sens: 0.6231 Spec: 0.9264
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7197 Acc: 0.9168 Sens: 0.4799 Spec: 0.9594
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.9999 Acc: 0.9997 Sens: 1.0000 Spec: 0.9997
#   Val   - BalAcc: 0.7178 Acc: 0.9158 Sens: 0.4770 Spec: 0.9586
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9990 Acc: 0.9982 Sens: 1.0000 Spec: 0.9980
#   Val   - BalAcc: 0.7321 Acc: 0.9136 Sens: 0.5114 Spec: 0.9529
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9969 Acc: 0.9943 Sens: 1.0000 Spec: 0.9937
#   Val   - BalAcc: 0.7486 Acc: 0.9141 Sens: 0.5472 Spec: 0.9499
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9916 Acc: 0.9852 Sens: 0.9993 Spec: 0.9839
#   Val   - BalAcc: 0.7634 Acc: 0.9118 Sens: 0.5830 Spec: 0.9439
#
#
# Mean over folds for n_estimators=200, lr=0.2, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9829 Acc: 0.9739 Sens: 0.9939 Spec: 0.9720
#   Val   - BalAcc: 0.7666 Acc: 0.9057 Sens: 0.5974 Spec: 0.9358
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.7991 Acc: 0.8952 Sens: 0.6823 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.7991 Acc: 0.8952 Sens: 0.6823 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.7991 Acc: 0.8952 Sens: 0.6823 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.7991 Acc: 0.8952 Sens: 0.6823 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.7991 Acc: 0.8952 Sens: 0.6823 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6819 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8061 Acc: 0.8964 Sens: 0.6963 Spec: 0.9159
#   Val   - BalAcc: 0.7988 Acc: 0.8950 Sens: 0.6818 Spec: 0.9158
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8052 Acc: 0.8962 Sens: 0.6945 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8047 Acc: 0.8961 Sens: 0.6934 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8028 Acc: 0.8957 Sens: 0.6898 Spec: 0.9158
#   Val   - BalAcc: 0.7995 Acc: 0.8950 Sens: 0.6833 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8023 Acc: 0.8956 Sens: 0.6887 Spec: 0.9158
#   Val   - BalAcc: 0.7995 Acc: 0.8950 Sens: 0.6833 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8000 Acc: 0.8953 Sens: 0.6841 Spec: 0.9159
#   Val   - BalAcc: 0.7989 Acc: 0.8951 Sens: 0.6818 Spec: 0.9159
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8160 Acc: 0.8981 Sens: 0.7160 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8949 Sens: 0.6818 Spec: 0.9157
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8143 Acc: 0.8979 Sens: 0.7127 Spec: 0.9159
#   Val   - BalAcc: 0.7987 Acc: 0.8947 Sens: 0.6818 Spec: 0.9155
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8119 Acc: 0.8972 Sens: 0.7081 Spec: 0.9157
#   Val   - BalAcc: 0.7986 Acc: 0.8946 Sens: 0.6818 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8098 Acc: 0.8967 Sens: 0.7042 Spec: 0.9155
#   Val   - BalAcc: 0.8000 Acc: 0.8949 Sens: 0.6847 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8056 Acc: 0.8960 Sens: 0.6956 Spec: 0.9155
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.001, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8016 Acc: 0.8956 Sens: 0.6873 Spec: 0.9159
#   Val   - BalAcc: 0.7988 Acc: 0.8950 Sens: 0.6818 Spec: 0.9158
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.7994 Acc: 0.8949 Sens: 0.6834 Spec: 0.9155
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.7997 Acc: 0.8950 Sens: 0.6837 Spec: 0.9156
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.7996 Acc: 0.8949 Sens: 0.6837 Spec: 0.9155
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.7995 Acc: 0.8950 Sens: 0.6834 Spec: 0.9156
#   Val   - BalAcc: 0.7987 Acc: 0.8947 Sens: 0.6818 Spec: 0.9155
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.7998 Acc: 0.8950 Sens: 0.6841 Spec: 0.9156
#   Val   - BalAcc: 0.7994 Acc: 0.8949 Sens: 0.6833 Spec: 0.9155
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.7994 Acc: 0.8948 Sens: 0.6834 Spec: 0.9154
#   Val   - BalAcc: 0.7993 Acc: 0.8947 Sens: 0.6833 Spec: 0.9154
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.8070 Acc: 0.8954 Sens: 0.6995 Spec: 0.9145
#   Val   - BalAcc: 0.8001 Acc: 0.8938 Sens: 0.6861 Spec: 0.9141
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8079 Acc: 0.8949 Sens: 0.7020 Spec: 0.9138
#   Val   - BalAcc: 0.7996 Acc: 0.8930 Sens: 0.6861 Spec: 0.9131
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8071 Acc: 0.8949 Sens: 0.7002 Spec: 0.9139
#   Val   - BalAcc: 0.7996 Acc: 0.8930 Sens: 0.6861 Spec: 0.9131
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8063 Acc: 0.8945 Sens: 0.6991 Spec: 0.9136
#   Val   - BalAcc: 0.8006 Acc: 0.8935 Sens: 0.6876 Spec: 0.9136
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8057 Acc: 0.8944 Sens: 0.6977 Spec: 0.9137
#   Val   - BalAcc: 0.8002 Acc: 0.8928 Sens: 0.6876 Spec: 0.9129
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8049 Acc: 0.8940 Sens: 0.6966 Spec: 0.9132
#   Val   - BalAcc: 0.7999 Acc: 0.8923 Sens: 0.6876 Spec: 0.9123
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8195 Acc: 0.8978 Sens: 0.7242 Spec: 0.9147
#   Val   - BalAcc: 0.7995 Acc: 0.8938 Sens: 0.6847 Spec: 0.9143
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8179 Acc: 0.8973 Sens: 0.7213 Spec: 0.9145
#   Val   - BalAcc: 0.7991 Acc: 0.8932 Sens: 0.6847 Spec: 0.9136
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8159 Acc: 0.8969 Sens: 0.7174 Spec: 0.9144
#   Val   - BalAcc: 0.7996 Acc: 0.8930 Sens: 0.6861 Spec: 0.9131
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8143 Acc: 0.8957 Sens: 0.7153 Spec: 0.9133
#   Val   - BalAcc: 0.7999 Acc: 0.8923 Sens: 0.6876 Spec: 0.9123
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8121 Acc: 0.8950 Sens: 0.7113 Spec: 0.9130
#   Val   - BalAcc: 0.8001 Acc: 0.8926 Sens: 0.6876 Spec: 0.9126
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8105 Acc: 0.8943 Sens: 0.7084 Spec: 0.9125
#   Val   - BalAcc: 0.7994 Acc: 0.8914 Sens: 0.6876 Spec: 0.9113
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8359 Acc: 0.9021 Sens: 0.7554 Spec: 0.9164
#   Val   - BalAcc: 0.7985 Acc: 0.8945 Sens: 0.6818 Spec: 0.9152
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8329 Acc: 0.9010 Sens: 0.7500 Spec: 0.9157
#   Val   - BalAcc: 0.7992 Acc: 0.8945 Sens: 0.6833 Spec: 0.9151
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8296 Acc: 0.9000 Sens: 0.7439 Spec: 0.9152
#   Val   - BalAcc: 0.7998 Acc: 0.8944 Sens: 0.6847 Spec: 0.9148
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8254 Acc: 0.8989 Sens: 0.7360 Spec: 0.9148
#   Val   - BalAcc: 0.8001 Acc: 0.8938 Sens: 0.6861 Spec: 0.9141
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8180 Acc: 0.8971 Sens: 0.7217 Spec: 0.9142
#   Val   - BalAcc: 0.8008 Acc: 0.8938 Sens: 0.6876 Spec: 0.9140
#
#
# Mean over folds for n_estimators=300, lr=0.005, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8142 Acc: 0.8959 Sens: 0.7149 Spec: 0.9136
#   Val   - BalAcc: 0.8007 Acc: 0.8937 Sens: 0.6876 Spec: 0.9138
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8080 Acc: 0.8912 Sens: 0.7067 Spec: 0.9093
#   Val   - BalAcc: 0.7998 Acc: 0.8898 Sens: 0.6904 Spec: 0.9092
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8071 Acc: 0.8911 Sens: 0.7049 Spec: 0.9093
#   Val   - BalAcc: 0.8005 Acc: 0.8898 Sens: 0.6918 Spec: 0.9091
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8080 Acc: 0.8910 Sens: 0.7070 Spec: 0.9089
#   Val   - BalAcc: 0.8009 Acc: 0.8894 Sens: 0.6933 Spec: 0.9085
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8079 Acc: 0.8905 Sens: 0.7074 Spec: 0.9084
#   Val   - BalAcc: 0.8005 Acc: 0.8887 Sens: 0.6933 Spec: 0.9078
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8070 Acc: 0.8906 Sens: 0.7052 Spec: 0.9087
#   Val   - BalAcc: 0.8015 Acc: 0.8894 Sens: 0.6947 Spec: 0.9084
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8067 Acc: 0.8899 Sens: 0.7056 Spec: 0.9079
#   Val   - BalAcc: 0.7996 Acc: 0.8881 Sens: 0.6919 Spec: 0.9073
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.8165 Acc: 0.8932 Sens: 0.7231 Spec: 0.9098
#   Val   - BalAcc: 0.8003 Acc: 0.8895 Sens: 0.6919 Spec: 0.9088
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8172 Acc: 0.8930 Sens: 0.7249 Spec: 0.9095
#   Val   - BalAcc: 0.8010 Acc: 0.8884 Sens: 0.6947 Spec: 0.9073
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8159 Acc: 0.8922 Sens: 0.7231 Spec: 0.9087
#   Val   - BalAcc: 0.7987 Acc: 0.8877 Sens: 0.6904 Spec: 0.9070
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8140 Acc: 0.8913 Sens: 0.7199 Spec: 0.9080
#   Val   - BalAcc: 0.8009 Acc: 0.8882 Sens: 0.6947 Spec: 0.9071
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8136 Acc: 0.8904 Sens: 0.7203 Spec: 0.9070
#   Val   - BalAcc: 0.8012 Acc: 0.8876 Sens: 0.6962 Spec: 0.9063
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8125 Acc: 0.8897 Sens: 0.7185 Spec: 0.9065
#   Val   - BalAcc: 0.8020 Acc: 0.8867 Sens: 0.6990 Spec: 0.9050
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.8354 Acc: 0.9005 Sens: 0.7561 Spec: 0.9146
#   Val   - BalAcc: 0.7999 Acc: 0.8923 Sens: 0.6876 Spec: 0.9123
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.8345 Acc: 0.8996 Sens: 0.7554 Spec: 0.9137
#   Val   - BalAcc: 0.7999 Acc: 0.8912 Sens: 0.6890 Spec: 0.9109
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.8308 Acc: 0.8979 Sens: 0.7493 Spec: 0.9124
#   Val   - BalAcc: 0.8016 Acc: 0.8907 Sens: 0.6933 Spec: 0.9099
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.8278 Acc: 0.8959 Sens: 0.7450 Spec: 0.9106
#   Val   - BalAcc: 0.8010 Acc: 0.8896 Sens: 0.6933 Spec: 0.9088
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.8236 Acc: 0.8938 Sens: 0.7382 Spec: 0.9090
#   Val   - BalAcc: 0.8010 Acc: 0.8884 Sens: 0.6947 Spec: 0.9073
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8195 Acc: 0.8917 Sens: 0.7317 Spec: 0.9073
#   Val   - BalAcc: 0.8008 Acc: 0.8868 Sens: 0.6961 Spec: 0.9054
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.8690 Acc: 0.9167 Sens: 0.8109 Spec: 0.9271
#   Val   - BalAcc: 0.7968 Acc: 0.8972 Sens: 0.6747 Spec: 0.9189
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.8605 Acc: 0.9111 Sens: 0.7991 Spec: 0.9220
#   Val   - BalAcc: 0.7986 Acc: 0.8958 Sens: 0.6804 Spec: 0.9168
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.8530 Acc: 0.9061 Sens: 0.7883 Spec: 0.9176
#   Val   - BalAcc: 0.7989 Acc: 0.8940 Sens: 0.6833 Spec: 0.9145
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.8449 Acc: 0.9024 Sens: 0.7751 Spec: 0.9148
#   Val   - BalAcc: 0.7997 Acc: 0.8919 Sens: 0.6876 Spec: 0.9119
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.8371 Acc: 0.8993 Sens: 0.7615 Spec: 0.9127
#   Val   - BalAcc: 0.7995 Acc: 0.8903 Sens: 0.6890 Spec: 0.9099
#
#
# Mean over folds for n_estimators=300, lr=0.01, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8285 Acc: 0.8962 Sens: 0.7461 Spec: 0.9109
#   Val   - BalAcc: 0.7995 Acc: 0.8891 Sens: 0.6904 Spec: 0.9085
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8390 Acc: 0.8954 Sens: 0.7704 Spec: 0.9076
#   Val   - BalAcc: 0.8018 Acc: 0.8852 Sens: 0.7004 Spec: 0.9032
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8358 Acc: 0.8940 Sens: 0.7650 Spec: 0.9066
#   Val   - BalAcc: 0.7985 Acc: 0.8839 Sens: 0.6947 Spec: 0.9024
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8336 Acc: 0.8928 Sens: 0.7615 Spec: 0.9057
#   Val   - BalAcc: 0.7995 Acc: 0.8833 Sens: 0.6976 Spec: 0.9014
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8329 Acc: 0.8916 Sens: 0.7615 Spec: 0.9043
#   Val   - BalAcc: 0.8007 Acc: 0.8831 Sens: 0.7004 Spec: 0.9010
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8284 Acc: 0.8899 Sens: 0.7536 Spec: 0.9032
#   Val   - BalAcc: 0.7996 Acc: 0.8824 Sens: 0.6990 Spec: 0.9003
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8254 Acc: 0.8887 Sens: 0.7486 Spec: 0.9023
#   Val   - BalAcc: 0.8037 Acc: 0.8816 Sens: 0.7090 Spec: 0.8984
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9046 Acc: 0.9251 Sens: 0.8797 Spec: 0.9296
#   Val   - BalAcc: 0.7967 Acc: 0.8946 Sens: 0.6775 Spec: 0.9158
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.8962 Acc: 0.9202 Sens: 0.8671 Spec: 0.9254
#   Val   - BalAcc: 0.7969 Acc: 0.8927 Sens: 0.6804 Spec: 0.9134
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.8889 Acc: 0.9168 Sens: 0.8549 Spec: 0.9228
#   Val   - BalAcc: 0.7918 Acc: 0.8917 Sens: 0.6704 Spec: 0.9133
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.8796 Acc: 0.9113 Sens: 0.8410 Spec: 0.9181
#   Val   - BalAcc: 0.7982 Acc: 0.8893 Sens: 0.6876 Spec: 0.9089
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.8673 Acc: 0.9054 Sens: 0.8209 Spec: 0.9137
#   Val   - BalAcc: 0.7985 Acc: 0.8873 Sens: 0.6904 Spec: 0.9066
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.8549 Acc: 0.8997 Sens: 0.8005 Spec: 0.9094
#   Val   - BalAcc: 0.8017 Acc: 0.8873 Sens: 0.6976 Spec: 0.9059
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.9708 Acc: 0.9645 Sens: 0.9785 Spec: 0.9632
#   Val   - BalAcc: 0.7787 Acc: 0.9079 Sens: 0.6217 Spec: 0.9358
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9593 Acc: 0.9547 Sens: 0.9649 Spec: 0.9537
#   Val   - BalAcc: 0.7857 Acc: 0.9053 Sens: 0.6403 Spec: 0.9312
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9508 Acc: 0.9468 Sens: 0.9556 Spec: 0.9459
#   Val   - BalAcc: 0.7934 Acc: 0.9028 Sens: 0.6604 Spec: 0.9264
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9382 Acc: 0.9378 Sens: 0.9388 Spec: 0.9377
#   Val   - BalAcc: 0.7902 Acc: 0.8982 Sens: 0.6589 Spec: 0.9215
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9195 Acc: 0.9275 Sens: 0.9097 Spec: 0.9293
#   Val   - BalAcc: 0.7949 Acc: 0.8938 Sens: 0.6747 Spec: 0.9152
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.8970 Acc: 0.9166 Sens: 0.8732 Spec: 0.9209
#   Val   - BalAcc: 0.7975 Acc: 0.8903 Sens: 0.6847 Spec: 0.9103
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 0.9941 Acc: 0.9914 Sens: 0.9975 Spec: 0.9908
#   Val   - BalAcc: 0.7538 Acc: 0.9142 Sens: 0.5586 Spec: 0.9489
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.9878 Acc: 0.9831 Sens: 0.9936 Spec: 0.9821
#   Val   - BalAcc: 0.7653 Acc: 0.9104 Sens: 0.5887 Spec: 0.9418
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9806 Acc: 0.9735 Sens: 0.9893 Spec: 0.9720
#   Val   - BalAcc: 0.7766 Acc: 0.9075 Sens: 0.6174 Spec: 0.9358
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9732 Acc: 0.9617 Sens: 0.9871 Spec: 0.9593
#   Val   - BalAcc: 0.7824 Acc: 0.9039 Sens: 0.6346 Spec: 0.9302
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9578 Acc: 0.9475 Sens: 0.9703 Spec: 0.9453
#   Val   - BalAcc: 0.7898 Acc: 0.9010 Sens: 0.6546 Spec: 0.9250
#
#
# Mean over folds for n_estimators=300, lr=0.05, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9349 Acc: 0.9320 Sens: 0.9384 Spec: 0.9314
#   Val   - BalAcc: 0.7922 Acc: 0.8947 Sens: 0.6675 Spec: 0.9169
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.8953 Acc: 0.9173 Sens: 0.8685 Spec: 0.9221
#   Val   - BalAcc: 0.7931 Acc: 0.8894 Sens: 0.6761 Spec: 0.9102
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.8900 Acc: 0.9141 Sens: 0.8607 Spec: 0.9193
#   Val   - BalAcc: 0.7948 Acc: 0.8900 Sens: 0.6790 Spec: 0.9106
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.8861 Acc: 0.9121 Sens: 0.8546 Spec: 0.9177
#   Val   - BalAcc: 0.7893 Acc: 0.8872 Sens: 0.6703 Spec: 0.9084
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.8787 Acc: 0.9091 Sens: 0.8417 Spec: 0.9157
#   Val   - BalAcc: 0.7933 Acc: 0.8861 Sens: 0.6804 Spec: 0.9061
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8689 Acc: 0.9048 Sens: 0.8252 Spec: 0.9126
#   Val   - BalAcc: 0.7976 Acc: 0.8845 Sens: 0.6918 Spec: 0.9033
#
#
# Mean over folds for n_estimators=300, lr=0.1, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8568 Acc: 0.8988 Sens: 0.8059 Spec: 0.9078
# ...
#   Val   - BalAcc: 0.7905 Acc: 0.9057 Sens: 0.6503 Spec: 0.9306
#
#
# Mean over folds for n_estimators=800, lr=0.01, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9399 Acc: 0.9437 Sens: 0.9352 Spec: 0.9446
#   Val   - BalAcc: 0.7925 Acc: 0.9011 Sens: 0.6603 Spec: 0.9246
#
#
# Mean over folds for n_estimators=800, lr=0.01, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9200 Acc: 0.9311 Sens: 0.9065 Spec: 0.9335
#   Val   - BalAcc: 0.7932 Acc: 0.8977 Sens: 0.6661 Spec: 0.9203
#
#
# Mean over folds for n_estimators=800, lr=0.01, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9001 Acc: 0.9207 Sens: 0.8750 Spec: 0.9252
#   Val   - BalAcc: 0.7974 Acc: 0.8947 Sens: 0.6790 Spec: 0.9158
#
#
# Mean over folds for n_estimators=800, lr=0.01, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.8746 Acc: 0.9090 Sens: 0.8327 Spec: 0.9165
#   Val   - BalAcc: 0.8005 Acc: 0.8909 Sens: 0.6904 Spec: 0.9105
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.9193 Acc: 0.9286 Sens: 0.9080 Spec: 0.9306
#   Val   - BalAcc: 0.7902 Acc: 0.8922 Sens: 0.6661 Spec: 0.9143
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.9144 Acc: 0.9256 Sens: 0.9008 Spec: 0.9281
#   Val   - BalAcc: 0.7897 Acc: 0.8913 Sens: 0.6660 Spec: 0.9133
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.9067 Acc: 0.9221 Sens: 0.8879 Spec: 0.9254
#   Val   - BalAcc: 0.7907 Acc: 0.8921 Sens: 0.6675 Spec: 0.9140
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.9000 Acc: 0.9185 Sens: 0.8775 Spec: 0.9225
#   Val   - BalAcc: 0.7948 Acc: 0.8901 Sens: 0.6789 Spec: 0.9108
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.8887 Acc: 0.9140 Sens: 0.8578 Spec: 0.9195
#   Val   - BalAcc: 0.7894 Acc: 0.8873 Sens: 0.6703 Spec: 0.9085
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.8742 Acc: 0.9068 Sens: 0.8345 Spec: 0.9139
#   Val   - BalAcc: 0.7973 Acc: 0.8876 Sens: 0.6875 Spec: 0.9071
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9814 Acc: 0.9744 Sens: 0.9900 Spec: 0.9729
#   Val   - BalAcc: 0.7597 Acc: 0.9072 Sens: 0.5802 Spec: 0.9392
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.9766 Acc: 0.9683 Sens: 0.9867 Spec: 0.9665
#   Val   - BalAcc: 0.7636 Acc: 0.9051 Sens: 0.5916 Spec: 0.9357
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.9705 Acc: 0.9616 Sens: 0.9814 Spec: 0.9597
#   Val   - BalAcc: 0.7673 Acc: 0.9035 Sens: 0.6016 Spec: 0.9330
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.9609 Acc: 0.9520 Sens: 0.9717 Spec: 0.9501
#   Val   - BalAcc: 0.7784 Acc: 0.8991 Sens: 0.6317 Spec: 0.9252
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.9498 Acc: 0.9421 Sens: 0.9592 Spec: 0.9405
#   Val   - BalAcc: 0.7843 Acc: 0.8969 Sens: 0.6475 Spec: 0.9212
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.9362 Acc: 0.9332 Sens: 0.9398 Spec: 0.9326
#   Val   - BalAcc: 0.7909 Acc: 0.8959 Sens: 0.6632 Spec: 0.9186
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 0.9988 Acc: 0.9978 Sens: 1.0000 Spec: 0.9976
#   Val   - BalAcc: 0.7357 Acc: 0.9154 Sens: 0.5171 Spec: 0.9543
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9964 Acc: 0.9934 Sens: 1.0000 Spec: 0.9927
#   Val   - BalAcc: 0.7483 Acc: 0.9160 Sens: 0.5444 Spec: 0.9523
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9922 Acc: 0.9875 Sens: 0.9979 Spec: 0.9865
#   Val   - BalAcc: 0.7553 Acc: 0.9122 Sens: 0.5644 Spec: 0.9461
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9868 Acc: 0.9801 Sens: 0.9950 Spec: 0.9786
#   Val   - BalAcc: 0.7617 Acc: 0.9098 Sens: 0.5816 Spec: 0.9418
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9799 Acc: 0.9705 Sens: 0.9914 Spec: 0.9685
#   Val   - BalAcc: 0.7732 Acc: 0.9072 Sens: 0.6102 Spec: 0.9362
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.9699 Acc: 0.9570 Sens: 0.9857 Spec: 0.9542
#   Val   - BalAcc: 0.7820 Acc: 0.9033 Sens: 0.6346 Spec: 0.9295
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7168 Acc: 0.9163 Sens: 0.4742 Spec: 0.9594
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 0.9998 Acc: 0.9996 Sens: 1.0000 Spec: 0.9996
#   Val   - BalAcc: 0.7276 Acc: 0.9170 Sens: 0.4971 Spec: 0.9580
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 0.9990 Acc: 0.9982 Sens: 1.0000 Spec: 0.9981
#   Val   - BalAcc: 0.7340 Acc: 0.9135 Sens: 0.5157 Spec: 0.9523
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9970 Acc: 0.9946 Sens: 1.0000 Spec: 0.9941
#   Val   - BalAcc: 0.7516 Acc: 0.9137 Sens: 0.5544 Spec: 0.9488
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9914 Acc: 0.9859 Sens: 0.9982 Spec: 0.9847
#   Val   - BalAcc: 0.7633 Acc: 0.9116 Sens: 0.5830 Spec: 0.9436
#
#
# Mean over folds for n_estimators=800, lr=0.05, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9836 Acc: 0.9737 Sens: 0.9957 Spec: 0.9715
#   Val   - BalAcc: 0.7734 Acc: 0.9076 Sens: 0.6102 Spec: 0.9366
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.9662 Acc: 0.9581 Sens: 0.9760 Spec: 0.9563
#   Val   - BalAcc: 0.7730 Acc: 0.9010 Sens: 0.6174 Spec: 0.9287
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.9643 Acc: 0.9552 Sens: 0.9753 Spec: 0.9533
#   Val   - BalAcc: 0.7730 Acc: 0.8986 Sens: 0.6202 Spec: 0.9257
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.9571 Acc: 0.9495 Sens: 0.9663 Spec: 0.9479
#   Val   - BalAcc: 0.7747 Acc: 0.8982 Sens: 0.6245 Spec: 0.9249
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.9484 Acc: 0.9425 Sens: 0.9556 Spec: 0.9412
#   Val   - BalAcc: 0.7792 Acc: 0.8958 Sens: 0.6374 Spec: 0.9210
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.9335 Acc: 0.9337 Sens: 0.9334 Spec: 0.9337
#   Val   - BalAcc: 0.7833 Acc: 0.8916 Sens: 0.6517 Spec: 0.9150
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.9212 Acc: 0.9268 Sens: 0.9144 Spec: 0.9280
#   Val   - BalAcc: 0.7852 Acc: 0.8890 Sens: 0.6589 Spec: 0.9115
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9978 Acc: 0.9960 Sens: 1.0000 Spec: 0.9956
#   Val   - BalAcc: 0.7329 Acc: 0.9127 Sens: 0.5143 Spec: 0.9516
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.9956 Acc: 0.9925 Sens: 0.9993 Spec: 0.9918
#   Val   - BalAcc: 0.7421 Acc: 0.9130 Sens: 0.5343 Spec: 0.9499
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.9923 Acc: 0.9877 Sens: 0.9979 Spec: 0.9867
#   Val   - BalAcc: 0.7443 Acc: 0.9098 Sens: 0.5429 Spec: 0.9456
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.9865 Acc: 0.9795 Sens: 0.9950 Spec: 0.9780
#   Val   - BalAcc: 0.7507 Acc: 0.9075 Sens: 0.5601 Spec: 0.9414
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.9797 Acc: 0.9691 Sens: 0.9925 Spec: 0.9668
#   Val   - BalAcc: 0.7596 Acc: 0.9037 Sens: 0.5844 Spec: 0.9348
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.9694 Acc: 0.9578 Sens: 0.9835 Spec: 0.9553
#   Val   - BalAcc: 0.7772 Acc: 0.9016 Sens: 0.6260 Spec: 0.9285
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7155 Acc: 0.9175 Sens: 0.4698 Spec: 0.9613
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 0.9999 Acc: 0.9998 Sens: 1.0000 Spec: 0.9998
#   Val   - BalAcc: 0.7216 Acc: 0.9144 Sens: 0.4871 Spec: 0.9561
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 0.9992 Acc: 0.9986 Sens: 1.0000 Spec: 0.9985
#   Val   - BalAcc: 0.7296 Acc: 0.9149 Sens: 0.5043 Spec: 0.9550
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9976 Acc: 0.9957 Sens: 1.0000 Spec: 0.9953
#   Val   - BalAcc: 0.7379 Acc: 0.9099 Sens: 0.5286 Spec: 0.9471
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9946 Acc: 0.9905 Sens: 0.9996 Spec: 0.9896
#   Val   - BalAcc: 0.7421 Acc: 0.9094 Sens: 0.5386 Spec: 0.9456
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.9875 Acc: 0.9799 Sens: 0.9968 Spec: 0.9782
#   Val   - BalAcc: 0.7598 Acc: 0.9075 Sens: 0.5802 Spec: 0.9394
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7145 Acc: 0.9191 Sens: 0.4656 Spec: 0.9634
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7213 Acc: 0.9186 Sens: 0.4813 Spec: 0.9613
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 1.0000 Acc: 0.9999 Sens: 1.0000 Spec: 0.9999
#   Val   - BalAcc: 0.7275 Acc: 0.9169 Sens: 0.4971 Spec: 0.9579
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 0.9995 Acc: 0.9990 Sens: 1.0000 Spec: 0.9990
#   Val   - BalAcc: 0.7341 Acc: 0.9136 Sens: 0.5157 Spec: 0.9524
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9986 Acc: 0.9975 Sens: 1.0000 Spec: 0.9972
#   Val   - BalAcc: 0.7460 Acc: 0.9154 Sens: 0.5401 Spec: 0.9520
#
#
# Mean over folds for n_estimators=800, lr=0.1, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9952 Acc: 0.9912 Sens: 1.0000 Spec: 0.9904
#   Val   - BalAcc: 0.7563 Acc: 0.9117 Sens: 0.5673 Spec: 0.9453
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=2:
#   Train - BalAcc: 0.9888 Acc: 0.9839 Sens: 0.9946 Spec: 0.9829
#   Val   - BalAcc: 0.7364 Acc: 0.9037 Sens: 0.5329 Spec: 0.9399
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=4:
#   Train - BalAcc: 0.9867 Acc: 0.9809 Sens: 0.9939 Spec: 0.9796
#   Val   - BalAcc: 0.7411 Acc: 0.9040 Sens: 0.5429 Spec: 0.9393
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=8:
#   Train - BalAcc: 0.9835 Acc: 0.9759 Sens: 0.9928 Spec: 0.9742
#   Val   - BalAcc: 0.7495 Acc: 0.9040 Sens: 0.5615 Spec: 0.9375
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=16:
#   Train - BalAcc: 0.9798 Acc: 0.9702 Sens: 0.9914 Spec: 0.9682
#   Val   - BalAcc: 0.7549 Acc: 0.9021 Sens: 0.5758 Spec: 0.9340
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=32:
#   Train - BalAcc: 0.9697 Acc: 0.9589 Sens: 0.9828 Spec: 0.9565
#   Val   - BalAcc: 0.7663 Acc: 0.8983 Sens: 0.6058 Spec: 0.9268
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=3, l2_leaf_reg=64:
#   Train - BalAcc: 0.9592 Acc: 0.9495 Sens: 0.9710 Spec: 0.9474
#   Val   - BalAcc: 0.7751 Acc: 0.8989 Sens: 0.6245 Spec: 0.9257
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=2:
#   Train - BalAcc: 0.9999 Acc: 0.9999 Sens: 1.0000 Spec: 0.9999
#   Val   - BalAcc: 0.7208 Acc: 0.9141 Sens: 0.4856 Spec: 0.9559
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=4:
#   Train - BalAcc: 0.9998 Acc: 0.9996 Sens: 1.0000 Spec: 0.9995
#   Val   - BalAcc: 0.7251 Acc: 0.9136 Sens: 0.4957 Spec: 0.9544
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=8:
#   Train - BalAcc: 0.9991 Acc: 0.9984 Sens: 1.0000 Spec: 0.9983
#   Val   - BalAcc: 0.7200 Acc: 0.9127 Sens: 0.4857 Spec: 0.9544
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=16:
#   Train - BalAcc: 0.9974 Acc: 0.9953 Sens: 1.0000 Spec: 0.9949
#   Val   - BalAcc: 0.7293 Acc: 0.9096 Sens: 0.5100 Spec: 0.9487
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=32:
#   Train - BalAcc: 0.9942 Acc: 0.9903 Sens: 0.9989 Spec: 0.9894
#   Val   - BalAcc: 0.7369 Acc: 0.9105 Sens: 0.5257 Spec: 0.9481
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=5, l2_leaf_reg=64:
#   Train - BalAcc: 0.9867 Acc: 0.9788 Sens: 0.9964 Spec: 0.9771
#   Val   - BalAcc: 0.7539 Acc: 0.9049 Sens: 0.5701 Spec: 0.9376
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7195 Acc: 0.9177 Sens: 0.4785 Spec: 0.9606
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=4:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7105 Acc: 0.9131 Sens: 0.4641 Spec: 0.9569
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=8:
#   Train - BalAcc: 1.0000 Acc: 0.9999 Sens: 1.0000 Spec: 0.9999
#   Val   - BalAcc: 0.7174 Acc: 0.9150 Sens: 0.4770 Spec: 0.9578
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=16:
#   Train - BalAcc: 0.9998 Acc: 0.9996 Sens: 1.0000 Spec: 0.9996
#   Val   - BalAcc: 0.7315 Acc: 0.9172 Sens: 0.5057 Spec: 0.9573
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=32:
#   Train - BalAcc: 0.9989 Acc: 0.9980 Sens: 1.0000 Spec: 0.9978
#   Val   - BalAcc: 0.7297 Acc: 0.9103 Sens: 0.5100 Spec: 0.9494
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=7, l2_leaf_reg=64:
#   Train - BalAcc: 0.9965 Acc: 0.9937 Sens: 1.0000 Spec: 0.9930
#   Val   - BalAcc: 0.7451 Acc: 0.9102 Sens: 0.5444 Spec: 0.9459
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=2:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7110 Acc: 0.9174 Sens: 0.4598 Spec: 0.9621
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=4:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7073 Acc: 0.9178 Sens: 0.4513 Spec: 0.9634
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=8:
#   Train - BalAcc: 1.0000 Acc: 1.0000 Sens: 1.0000 Spec: 1.0000
#   Val   - BalAcc: 0.7118 Acc: 0.9165 Sens: 0.4627 Spec: 0.9608
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=16:
#   Train - BalAcc: 1.0000 Acc: 0.9999 Sens: 1.0000 Spec: 0.9999
#   Val   - BalAcc: 0.7197 Acc: 0.9156 Sens: 0.4814 Spec: 0.9580
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=32:
#   Train - BalAcc: 0.9998 Acc: 0.9997 Sens: 1.0000 Spec: 0.9997
#   Val   - BalAcc: 0.7292 Acc: 0.9153 Sens: 0.5028 Spec: 0.9555
#
#
# Mean over folds for n_estimators=800, lr=0.2, max_depth=9, l2_leaf_reg=64:
#   Train - BalAcc: 0.9992 Acc: 0.9985 Sens: 1.0000 Spec: 0.9983
#   Val   - BalAcc: 0.7297 Acc: 0.9139 Sens: 0.5057 Spec: 0.9537
#
#
# ✅ Best Grid Search Result:
#
# ✅ Best Grid Search Result:
# Best n_estimators: 200
# Best learning_rate: 0.05
# Best max_depth:     3
# Best l2_leaf_reg:   64
# Best Train Balanced Accuracy: 0.8146
# Best Train Accuracy:          0.8836
# Best Train Sensitivity:       0.7307
# Best Train Specificity:       0.8986
# Best Validation Balanced Accuracy: 0.8061
# Best Validation Accuracy:          0.8811
# Best Validation Sensitivity:       0.7148
# Best Validation Specificity:       0.8973

# %% [markdown]
# ##### Test

# %%
# === 測試集評估 ===
best_n_estimators, best_lr, best_max_depth, best_l2 = best_params
final_model = CatBoostClassifier(
    iterations=best_n_estimators,
    learning_rate=best_lr,
    depth=best_max_depth,
    l2_leaf_reg=best_l2,   #  改成最佳的 l2
    loss_function="Logloss",
    class_weights=class_weights,
    random_seed=seed,
    verbose=0,
    task_type="CPU"
)
final_model.fit(x, y)


y_test_pred = final_model.predict(X_test)
y_test_proba = final_model.predict_proba(X_test)[:, 1]

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
auc = roc_auc_score(y_test, y_test_proba)
f1 = f1_score(y_test, y_test_pred, zero_division=0)

confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"AUC:                       {auc:.4f}")
print(f"F1 Score:                  {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 119                  56
# Actual Negative                 180                1607
# Sensitivity (Recall, TPR): 0.6800
# Specificity (TNR):         0.8993
# Accuracy:                  0.8797
# Balanced Accuracy:         0.7896
# AUC:                       0.8662
# F1 Score:                  0.5021

# %% [markdown]
# ## Ensemble soft=>equal weight

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({np.int64(0): 7149, np.int64(1): 698})
# scale_pos_weight = 10.2421

# %%
rf_best_params =  {'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 40, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
rf_clf = RandomForestClassifier(
            **rf_best_params,
            random_state=seed,
            n_jobs=-1,
            class_weight='balanced'
)


lr_best_params = 512
lr_clf = LogisticRegression(
            C=lr_best_params,
            penalty='l2',
            max_iter=1000,
            solver='lbfgs',
            class_weight='balanced',
            random_state=seed
        )


svc_best_c =  0.0078125
svc_best_gamma = 0.25
svc_clf = SVC(
       C=svc_best_c,
       gamma=svc_best_gamma,
       kernel='rbf',
       class_weight='balanced',
       probability=True,
       random_state=seed
      )

xgb_best_params = {'colsample_bytree': 0.8831528055561403, 'gamma': 0.021020125361070625, 'learning_rate': 0.03754890989284685, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.8246355080259108}
xgb_clf = xgb.XGBClassifier(
            **xgb_best_params,
            eval_metric="logloss",
            tree_method="hist",
            scale_pos_weight=scale_pos_weight,
            random_state=seed
        )

# %%
from sklearn.ensemble import VotingClassifier
from itertools import combinations
# 定義 base 模型
models = {
    'rf': rf_clf,
    'lr': lr_clf,
    'svc': svc_clf,
    'xgb': xgb_clf,
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = []

for r in range(2, len(models) + 1):  # 組合長度 2~4
    for subset in combinations(models.items(), r):
        clf_names, clf_list = zip(*subset)

        eclf = VotingClassifier(
            estimators=list(subset),
            voting='soft',
            n_jobs=-1
        )

        train_bal_accs, train_accs, train_sens, train_spec = [], [], [], []
        val_bal_accs, val_accs, val_sens, val_spec = [], [], [], []

        for train_idx, val_idx in cv.split(x, y):
            X_train_fold, y_train_fold = x[train_idx], y[train_idx]
            X_val_fold, y_val_fold = x[val_idx], y[val_idx]

            eclf.fit(X_train_fold, y_train_fold)

            # 預測
            y_train_pred = eclf.predict(X_train_fold)
            y_val_pred = eclf.predict(X_val_fold)

            # === Train metrics ===
            train_bal_accs.append(balanced_accuracy_score(y_train_fold, y_train_pred))
            train_accs.append(accuracy_score(y_train_fold, y_train_pred))
            train_sens.append(recall_score(y_train_fold, y_train_pred, pos_label=1))
            train_spec.append(recall_score(y_train_fold, y_train_pred, pos_label=0))

            # === Val metrics ===
            val_bal_accs.append(balanced_accuracy_score(y_val_fold, y_val_pred))
            val_accs.append(accuracy_score(y_val_fold, y_val_pred))
            val_sens.append(recall_score(y_val_fold, y_val_pred, pos_label=1))
            val_spec.append(recall_score(y_val_fold, y_val_pred, pos_label=0))

        # 平均結果
        result = {
            'models': clf_names,
            'train_bal_acc': np.mean(train_bal_accs),
            'train_acc': np.mean(train_accs),
            'train_sens': np.mean(train_sens),
            'train_spec': np.mean(train_spec),
            'val_bal_acc': np.mean(val_bal_accs),
            'val_acc': np.mean(val_accs),
            'val_sens': np.mean(val_sens),
            'val_spec': np.mean(val_spec),
        }

        results.append(result)

        # 輸出格式化結果
        print(f"Models: {clf_names}")
        print(f" Train - Balanced Acc: {result['train_bal_acc']:.4f} | Acc: {result['train_acc']:.4f} | Sens: {result['train_sens']:.4f} | Spec: {result['train_spec']:.4f}")
        print(f" Val - Balanced Acc: {result['val_bal_acc']:.4f} | Acc: {result['val_acc']:.4f} | Sens: {result['val_sens']:.4f} | Spec: {result['val_spec']:.4f}")
        print("")

# 選出最佳組合（以 val_bal_acc 為主）
best_result = max(results, key=lambda r: r['val_bal_acc'])

print("=== Best Model Combination ===")
print(f"Models: {best_result['models']}")
print(f" Train - Balanced Acc: {best_result['train_bal_acc']:.4f} | Acc: {best_result['train_acc']:.4f} | Sens: {best_result['train_sens']:.4f} | Spec: {best_result['train_spec']:.4f}")
print(f"   Val - Balanced Acc: {best_result['val_bal_acc']:.4f} | Acc: {best_result['val_acc']:.4f} | Sens: {best_result['val_sens']:.4f} | Spec: {best_result['val_spec']:.4f}")
# Out:
# Models: ('rf', 'lr')
#  Train - Balanced Acc: 0.8135 | Acc: 0.8952 | Sens: 0.7142 | Spec: 0.9129
#  Val - Balanced Acc: 0.8007 | Acc: 0.8913 | Sens: 0.6904 | Spec: 0.9109
#
# Models: ('rf', 'svc')
#  Train - Balanced Acc: 0.8037 | Acc: 0.9043 | Sens: 0.6812 | Spec: 0.9261
#  Val - Balanced Acc: 0.7937 | Acc: 0.8997 | Sens: 0.6647 | Spec: 0.9226
#
# Models: ('rf', 'xgb')
#  Train - Balanced Acc: 0.8289 | Acc: 0.8976 | Sens: 0.7453 | Spec: 0.9124
#  Val - Balanced Acc: 0.8011 | Acc: 0.8898 | Sens: 0.6933 | Spec: 0.9089
#
# Models: ('lr', 'svc')
#  Train - Balanced Acc: 0.7974 | Acc: 0.9035 | Sens: 0.6683 | Spec: 0.9265
#  Val - Balanced Acc: 0.7915 | Acc: 0.9016 | Sens: 0.6575 | Spec: 0.9254
#
# Models: ('lr', 'xgb')
#  Train - Balanced Acc: 0.8206 | Acc: 0.8928 | Sens: 0.7328 | Spec: 0.9084
#  Val - Balanced Acc: 0.8000 | Acc: 0.8866 | Sens: 0.6947 | Spec: 0.9053
#
# Models: ('svc', 'xgb')
#  Train - Balanced Acc: 0.8059 | Acc: 0.9138 | Sens: 0.6748 | Spec: 0.9371
#  Val - Balanced Acc: 0.7862 | Acc: 0.9061 | Sens: 0.6403 | Spec: 0.9320
#
# Models: ('rf', 'lr', 'svc')
#  Train - Balanced Acc: 0.8028 | Acc: 0.8984 | Sens: 0.6866 | Spec: 0.9191
#  Val - Balanced Acc: 0.7971 | Acc: 0.8966 | Sens: 0.6761 | Spec: 0.9182
#
# Models: ('rf', 'lr', 'xgb')
#  Train - Balanced Acc: 0.8198 | Acc: 0.8957 | Sens: 0.7274 | Spec: 0.9121
#  Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105
#
# Models: ('rf', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8022 | Acc: 0.9010 | Sens: 0.6819 | Spec: 0.9224
#  Val - Balanced Acc: 0.7976 | Acc: 0.8987 | Sens: 0.6747 | Spec: 0.9205
#
# Models: ('lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8063 | Acc: 0.9018 | Sens: 0.6902 | Spec: 0.9224
#  Val - Balanced Acc: 0.7963 | Acc: 0.8975 | Sens: 0.6732 | Spec: 0.9194
#
# Models: ('rf', 'lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8072 | Acc: 0.8992 | Sens: 0.6952 | Spec: 0.9191
#  Val - Balanced Acc: 0.8002 | Acc: 0.8963 | Sens: 0.6833 | Spec: 0.9170
#
# === Best Model Combination ===
# Models: ('rf', 'lr', 'xgb')
#  Train - Balanced Acc: 0.8198 | Acc: 0.8957 | Sens: 0.7274 | Spec: 0.9121
#    Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105

# %% [markdown]
# ##### Test

# %%
# 取得最佳參數
best_estimators = [(name, models[name]) for name in best_result['models']]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='soft',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test.values)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 119                  56
# Actual Negative                 154                1633
# Sensitivity (Recall, TPR): 0.6800
# Specificity (TNR):         0.9138
# Accuracy:                  0.8930
# Balanced Accuracy:         0.7969
# F1 Score:         0.5312

# %% [markdown]
# ## Ensemble soft=>adjust weight

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({np.int64(0): 7149, np.int64(1): 698})
# scale_pos_weight = 10.2421

# %%
rf_best_params =  {'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 40, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
rf_clf = RandomForestClassifier(
            **rf_best_params,
            random_state=seed,
            n_jobs=-1,
            class_weight='balanced'
)


lr_best_params = 512
lr_clf = LogisticRegression(
            C=lr_best_params,
            penalty='l2',
            max_iter=1000,
            solver='lbfgs',
            class_weight='balanced',
            random_state=seed
        )


svc_best_c =  0.0078125
svc_best_gamma = 0.25
svc_clf = SVC(
       C=svc_best_c,
       gamma=svc_best_gamma,
       kernel='rbf',
       class_weight='balanced',
       probability=True,
       random_state=seed
      )

xgb_best_params = {'colsample_bytree': 0.8831528055561403, 'gamma': 0.021020125361070625, 'learning_rate': 0.03754890989284685, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.8246355080259108}
xgb_clf = xgb.XGBClassifier(
            **xgb_best_params,
            eval_metric="logloss",
            tree_method="hist",
            scale_pos_weight=scale_pos_weight,
            random_state=seed
        )

# %%
from sklearn.ensemble import VotingClassifier
from itertools import combinations
# 定義 base 模型
models = {
    'rf': rf_clf,
    'lr': lr_clf,
    'svc': svc_clf,
    'xgb': xgb_clf,
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = []

# 所有模型子集的長度（2~4）
for r in range(2, len(models) + 1):
    for subset in combinations(models.items(), r):
        clf_names, clf_list = zip(*subset)
        name_model_pairs = list(subset)

        # 權重搜尋範圍，例如：1 ~ 3（可以調整）
        weight_options = [1, 2, 3]

        # 枚舉所有權重排列（長度要等於模型個數）
        for weights in product(weight_options, repeat=r):
            eclf = VotingClassifier(
                estimators=name_model_pairs,
                voting='soft',
                weights=weights,
                n_jobs=-1
            )

            train_bal_accs, train_accs, train_sens, train_spec = [], [], [], []
            val_bal_accs, val_accs, val_sens, val_spec = [], [], [], []

            for train_idx, val_idx in cv.split(x, y):
                X_train_fold, y_train_fold = x[train_idx], y[train_idx]
                X_val_fold, y_val_fold = x[val_idx], y[val_idx]

                eclf.fit(X_train_fold, y_train_fold)

                y_train_pred = eclf.predict(X_train_fold)
                y_val_pred = eclf.predict(X_val_fold)

                train_bal_accs.append(balanced_accuracy_score(y_train_fold, y_train_pred))
                train_accs.append(accuracy_score(y_train_fold, y_train_pred))
                train_sens.append(recall_score(y_train_fold, y_train_pred, pos_label=1))
                train_spec.append(recall_score(y_train_fold, y_train_pred, pos_label=0))

                val_bal_accs.append(balanced_accuracy_score(y_val_fold, y_val_pred))
                val_accs.append(accuracy_score(y_val_fold, y_val_pred))
                val_sens.append(recall_score(y_val_fold, y_val_pred, pos_label=1))
                val_spec.append(recall_score(y_val_fold, y_val_pred, pos_label=0))

            result = {
                'models': clf_names,
                'weights': weights,  # 加入權重
                'train_bal_acc': np.mean(train_bal_accs),
                'train_acc': np.mean(train_accs),
                'train_sens': np.mean(train_sens),
                'train_spec': np.mean(train_spec),
                'val_bal_acc': np.mean(val_bal_accs),
                'val_acc': np.mean(val_accs),
                'val_sens': np.mean(val_sens),
                'val_spec': np.mean(val_spec),
            }

            results.append(result)

            print(f"Models: {clf_names} | Weights: {weights}")
            print(f" Train - Balanced Acc: {result['train_bal_acc']:.4f} | Acc: {result['train_acc']:.4f} | Sens: {result['train_sens']:.4f} | Spec: {result['train_spec']:.4f}")
            print(f" Val - Balanced Acc: {result['val_bal_acc']:.4f} | Acc: {result['val_acc']:.4f} | Sens: {result['val_sens']:.4f} | Spec: {result['val_spec']:.4f}")
            print("")


best_result = max(results, key=lambda r: r['val_bal_acc'])

print("=== Best Model Combination ===")
print(f"Models: {best_result['models']}")
print(f"Weights: {best_result['weights']}")
print(f" Train - Balanced Acc: {best_result['train_bal_acc']:.4f} | Acc: {best_result['train_acc']:.4f} | Sens: {best_result['train_sens']:.4f} | Spec: {best_result['train_spec']:.4f}")
print(f"   Val - Balanced Acc: {best_result['val_bal_acc']:.4f} | Acc: {best_result['val_acc']:.4f} | Sens: {best_result['val_sens']:.4f} | Spec: {best_result['val_spec']:.4f}")
# Out:
# Models: ('rf', 'lr') | Weights: (1, 1)
#  Train - Balanced Acc: 0.8135 | Acc: 0.8952 | Sens: 0.7142 | Spec: 0.9129
#  Val - Balanced Acc: 0.8007 | Acc: 0.8913 | Sens: 0.6904 | Spec: 0.9109
#
# Models: ('rf', 'lr') | Weights: (1, 2)
#  Train - Balanced Acc: 0.8135 | Acc: 0.8934 | Sens: 0.7163 | Spec: 0.9107
#  Val - Balanced Acc: 0.8017 | Acc: 0.8896 | Sens: 0.6947 | Spec: 0.9087
#
# Models: ('rf', 'lr') | Weights: (1, 3)
#  Train - Balanced Acc: 0.8127 | Acc: 0.8917 | Sens: 0.7167 | Spec: 0.9088
#  Val - Balanced Acc: 0.8019 | Acc: 0.8877 | Sens: 0.6976 | Spec: 0.9063
#
# Models: ('rf', 'lr') | Weights: (2, 1)
#  Train - Balanced Acc: 0.8131 | Acc: 0.8955 | Sens: 0.7127 | Spec: 0.9134
#  Val - Balanced Acc: 0.8019 | Acc: 0.8924 | Sens: 0.6919 | Spec: 0.9120
#
# Models: ('rf', 'lr') | Weights: (2, 2)
#  Train - Balanced Acc: 0.8135 | Acc: 0.8952 | Sens: 0.7142 | Spec: 0.9129
#  Val - Balanced Acc: 0.8007 | Acc: 0.8913 | Sens: 0.6904 | Spec: 0.9109
#
# Models: ('rf', 'lr') | Weights: (2, 3)
#  Train - Balanced Acc: 0.8138 | Acc: 0.8945 | Sens: 0.7156 | Spec: 0.9119
#  Val - Balanced Acc: 0.8026 | Acc: 0.8901 | Sens: 0.6961 | Spec: 0.9091
#
# Models: ('rf', 'lr') | Weights: (3, 1)
#  Train - Balanced Acc: 0.8138 | Acc: 0.8960 | Sens: 0.7138 | Spec: 0.9138
#  Val - Balanced Acc: 0.8016 | Acc: 0.8931 | Sens: 0.6904 | Spec: 0.9129
#
# Models: ('rf', 'lr') | Weights: (3, 2)
#  Train - Balanced Acc: 0.8134 | Acc: 0.8953 | Sens: 0.7138 | Spec: 0.9130
#  Val - Balanced Acc: 0.8009 | Acc: 0.8918 | Sens: 0.6904 | Spec: 0.9115
#
# Models: ('rf', 'lr') | Weights: (3, 3)
#  Train - Balanced Acc: 0.8135 | Acc: 0.8952 | Sens: 0.7142 | Spec: 0.9129
#  Val - Balanced Acc: 0.8007 | Acc: 0.8913 | Sens: 0.6904 | Spec: 0.9109
#
# Models: ('rf', 'svc') | Weights: (1, 1)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9043 | Sens: 0.6812 | Spec: 0.9261
#  Val - Balanced Acc: 0.7937 | Acc: 0.8997 | Sens: 0.6647 | Spec: 0.9226
#
# Models: ('rf', 'svc') | Weights: (1, 2)
#  Train - Balanced Acc: 0.7692 | Acc: 0.9228 | Sens: 0.5824 | Spec: 0.9561
#  Val - Balanced Acc: 0.7229 | Acc: 0.9132 | Sens: 0.4914 | Spec: 0.9544
#
# Models: ('rf', 'svc') | Weights: (1, 3)
#  Train - Balanced Acc: 0.7111 | Acc: 0.9214 | Sens: 0.4552 | Spec: 0.9669
#  Val - Balanced Acc: 0.6831 | Acc: 0.9161 | Sens: 0.3997 | Spec: 0.9666
#
# Models: ('rf', 'svc') | Weights: (2, 1)
#  Train - Balanced Acc: 0.7995 | Acc: 0.8961 | Sens: 0.6819 | Spec: 0.9170
#  Val - Balanced Acc: 0.7991 | Acc: 0.8955 | Sens: 0.6818 | Spec: 0.9164
#
# Models: ('rf', 'svc') | Weights: (2, 2)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9043 | Sens: 0.6812 | Spec: 0.9261
#  Val - Balanced Acc: 0.7937 | Acc: 0.8997 | Sens: 0.6647 | Spec: 0.9226
#
# Models: ('rf', 'svc') | Weights: (2, 3)
#  Train - Balanced Acc: 0.7952 | Acc: 0.9163 | Sens: 0.6479 | Spec: 0.9425
#  Val - Balanced Acc: 0.7619 | Acc: 0.9077 | Sens: 0.5845 | Spec: 0.9393
#
# Models: ('rf', 'svc') | Weights: (3, 1)
#  Train - Balanced Acc: 0.7994 | Acc: 0.8953 | Sens: 0.6827 | Spec: 0.9161
#  Val - Balanced Acc: 0.7989 | Acc: 0.8951 | Sens: 0.6818 | Spec: 0.9159
#
# Models: ('rf', 'svc') | Weights: (3, 2)
#  Train - Balanced Acc: 0.8003 | Acc: 0.8977 | Sens: 0.6819 | Spec: 0.9187
#  Val - Balanced Acc: 0.7997 | Acc: 0.8966 | Sens: 0.6818 | Spec: 0.9176
#
# Models: ('rf', 'svc') | Weights: (3, 3)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9043 | Sens: 0.6812 | Spec: 0.9261
#  Val - Balanced Acc: 0.7937 | Acc: 0.8997 | Sens: 0.6647 | Spec: 0.9226
#
# Models: ('rf', 'xgb') | Weights: (1, 1)
#  Train - Balanced Acc: 0.8289 | Acc: 0.8976 | Sens: 0.7453 | Spec: 0.9124
#  Val - Balanced Acc: 0.8011 | Acc: 0.8898 | Sens: 0.6933 | Spec: 0.9089
#
# Models: ('rf', 'xgb') | Weights: (1, 2)
#  Train - Balanced Acc: 0.8323 | Acc: 0.8967 | Sens: 0.7539 | Spec: 0.9107
#  Val - Balanced Acc: 0.8007 | Acc: 0.8866 | Sens: 0.6962 | Spec: 0.9052
#
# Models: ('rf', 'xgb') | Weights: (1, 3)
#  Train - Balanced Acc: 0.8325 | Acc: 0.8959 | Sens: 0.7554 | Spec: 0.9097
#  Val - Balanced Acc: 0.7995 | Acc: 0.8844 | Sens: 0.6961 | Spec: 0.9028
#
# Models: ('rf', 'xgb') | Weights: (2, 1)
#  Train - Balanced Acc: 0.8259 | Acc: 0.8978 | Sens: 0.7385 | Spec: 0.9133
#  Val - Balanced Acc: 0.8001 | Acc: 0.8914 | Sens: 0.6890 | Spec: 0.9112
#
# Models: ('rf', 'xgb') | Weights: (2, 2)
#  Train - Balanced Acc: 0.8289 | Acc: 0.8976 | Sens: 0.7453 | Spec: 0.9124
#  Val - Balanced Acc: 0.8011 | Acc: 0.8898 | Sens: 0.6933 | Spec: 0.9089
#
# Models: ('rf', 'xgb') | Weights: (2, 3)
#  Train - Balanced Acc: 0.8308 | Acc: 0.8969 | Sens: 0.7504 | Spec: 0.9112
#  Val - Balanced Acc: 0.7999 | Acc: 0.8876 | Sens: 0.6933 | Spec: 0.9066
#
# Models: ('rf', 'xgb') | Weights: (3, 1)
#  Train - Balanced Acc: 0.8242 | Acc: 0.8984 | Sens: 0.7339 | Spec: 0.9144
#  Val - Balanced Acc: 0.8001 | Acc: 0.8927 | Sens: 0.6876 | Spec: 0.9127
#
# Models: ('rf', 'xgb') | Weights: (3, 2)
#  Train - Balanced Acc: 0.8278 | Acc: 0.8979 | Sens: 0.7425 | Spec: 0.9131
#  Val - Balanced Acc: 0.8010 | Acc: 0.8907 | Sens: 0.6919 | Spec: 0.9101
#
# Models: ('rf', 'xgb') | Weights: (3, 3)
#  Train - Balanced Acc: 0.8289 | Acc: 0.8976 | Sens: 0.7453 | Spec: 0.9124
#  Val - Balanced Acc: 0.8011 | Acc: 0.8898 | Sens: 0.6933 | Spec: 0.9089
#
# Models: ('lr', 'svc') | Weights: (1, 1)
#  Train - Balanced Acc: 0.7974 | Acc: 0.9035 | Sens: 0.6683 | Spec: 0.9265
#  Val - Balanced Acc: 0.7915 | Acc: 0.9016 | Sens: 0.6575 | Spec: 0.9254
#
# Models: ('lr', 'svc') | Weights: (1, 2)
#  Train - Balanced Acc: 0.7744 | Acc: 0.9163 | Sens: 0.6017 | Spec: 0.9471
#  Val - Balanced Acc: 0.7544 | Acc: 0.9118 | Sens: 0.5630 | Spec: 0.9459
#
# Models: ('lr', 'svc') | Weights: (1, 3)
#  Train - Balanced Acc: 0.7281 | Acc: 0.9222 | Sens: 0.4921 | Spec: 0.9642
#  Val - Balanced Acc: 0.6979 | Acc: 0.9160 | Sens: 0.4327 | Spec: 0.9632
#
# Models: ('lr', 'svc') | Weights: (2, 1)
#  Train - Balanced Acc: 0.8032 | Acc: 0.8986 | Sens: 0.6873 | Spec: 0.9192
#  Val - Balanced Acc: 0.7984 | Acc: 0.8966 | Sens: 0.6790 | Spec: 0.9179
#
# Models: ('lr', 'svc') | Weights: (2, 2)
#  Train - Balanced Acc: 0.7974 | Acc: 0.9035 | Sens: 0.6683 | Spec: 0.9265
#  Val - Balanced Acc: 0.7915 | Acc: 0.9016 | Sens: 0.6575 | Spec: 0.9254
#
# Models: ('lr', 'svc') | Weights: (2, 3)
#  Train - Balanced Acc: 0.7923 | Acc: 0.9102 | Sens: 0.6490 | Spec: 0.9357
#  Val - Balanced Acc: 0.7789 | Acc: 0.9070 | Sens: 0.6232 | Spec: 0.9347
#
# Models: ('lr', 'svc') | Weights: (3, 1)
#  Train - Balanced Acc: 0.8063 | Acc: 0.8967 | Sens: 0.6963 | Spec: 0.9163
#  Val - Balanced Acc: 0.7994 | Acc: 0.8949 | Sens: 0.6833 | Spec: 0.9155
#
# Models: ('lr', 'svc') | Weights: (3, 2)
#  Train - Balanced Acc: 0.8010 | Acc: 0.9001 | Sens: 0.6805 | Spec: 0.9215
#  Val - Balanced Acc: 0.7959 | Acc: 0.8991 | Sens: 0.6704 | Spec: 0.9214
#
# Models: ('lr', 'svc') | Weights: (3, 3)
#  Train - Balanced Acc: 0.7974 | Acc: 0.9035 | Sens: 0.6683 | Spec: 0.9265
#  Val - Balanced Acc: 0.7915 | Acc: 0.9016 | Sens: 0.6575 | Spec: 0.9254
#
# Models: ('lr', 'xgb') | Weights: (1, 1)
#  Train - Balanced Acc: 0.8206 | Acc: 0.8928 | Sens: 0.7328 | Spec: 0.9084
#  Val - Balanced Acc: 0.8000 | Acc: 0.8866 | Sens: 0.6947 | Spec: 0.9053
#
# Models: ('lr', 'xgb') | Weights: (1, 2)
#  Train - Balanced Acc: 0.8264 | Acc: 0.8939 | Sens: 0.7443 | Spec: 0.9085
#  Val - Balanced Acc: 0.8000 | Acc: 0.8854 | Sens: 0.6961 | Spec: 0.9039
#
# Models: ('lr', 'xgb') | Weights: (1, 3)
#  Train - Balanced Acc: 0.8275 | Acc: 0.8939 | Sens: 0.7468 | Spec: 0.9082
#  Val - Balanced Acc: 0.8005 | Acc: 0.8840 | Sens: 0.6990 | Spec: 0.9021
#
# Models: ('lr', 'xgb') | Weights: (2, 1)
#  Train - Balanced Acc: 0.8165 | Acc: 0.8903 | Sens: 0.7267 | Spec: 0.9063
#  Val - Balanced Acc: 0.8011 | Acc: 0.8862 | Sens: 0.6976 | Spec: 0.9046
#
# Models: ('lr', 'xgb') | Weights: (2, 2)
#  Train - Balanced Acc: 0.8206 | Acc: 0.8928 | Sens: 0.7328 | Spec: 0.9084
#  Val - Balanced Acc: 0.8000 | Acc: 0.8866 | Sens: 0.6947 | Spec: 0.9053
#
# Models: ('lr', 'xgb') | Weights: (2, 3)
#  Train - Balanced Acc: 0.8241 | Acc: 0.8939 | Sens: 0.7393 | Spec: 0.9090
#  Val - Balanced Acc: 0.8003 | Acc: 0.8859 | Sens: 0.6961 | Spec: 0.9045
#
# Models: ('lr', 'xgb') | Weights: (3, 1)
#  Train - Balanced Acc: 0.8146 | Acc: 0.8889 | Sens: 0.7242 | Spec: 0.9050
#  Val - Balanced Acc: 0.8010 | Acc: 0.8849 | Sens: 0.6990 | Spec: 0.9031
#
# Models: ('lr', 'xgb') | Weights: (3, 2)
#  Train - Balanced Acc: 0.8184 | Acc: 0.8914 | Sens: 0.7296 | Spec: 0.9072
#  Val - Balanced Acc: 0.7986 | Acc: 0.8865 | Sens: 0.6918 | Spec: 0.9054
#
# Models: ('lr', 'xgb') | Weights: (3, 3)
#  Train - Balanced Acc: 0.8206 | Acc: 0.8928 | Sens: 0.7328 | Spec: 0.9084
#  Val - Balanced Acc: 0.8000 | Acc: 0.8866 | Sens: 0.6947 | Spec: 0.9053
#
# Models: ('svc', 'xgb') | Weights: (1, 1)
#  Train - Balanced Acc: 0.8059 | Acc: 0.9138 | Sens: 0.6748 | Spec: 0.9371
#  Val - Balanced Acc: 0.7862 | Acc: 0.9061 | Sens: 0.6403 | Spec: 0.9320
#
# Models: ('svc', 'xgb') | Weights: (1, 2)
#  Train - Balanced Acc: 0.8109 | Acc: 0.9071 | Sens: 0.6938 | Spec: 0.9280
#  Val - Balanced Acc: 0.7943 | Acc: 0.9010 | Sens: 0.6646 | Spec: 0.9240
#
# Models: ('svc', 'xgb') | Weights: (1, 3)
#  Train - Balanced Acc: 0.8193 | Acc: 0.9054 | Sens: 0.7145 | Spec: 0.9240
#  Val - Balanced Acc: 0.7956 | Acc: 0.8974 | Sens: 0.6718 | Spec: 0.9194
#
# Models: ('svc', 'xgb') | Weights: (2, 1)
#  Train - Balanced Acc: 0.7774 | Acc: 0.9256 | Sens: 0.5971 | Spec: 0.9577
#  Val - Balanced Acc: 0.7430 | Acc: 0.9169 | Sens: 0.5315 | Spec: 0.9545
#
# Models: ('svc', 'xgb') | Weights: (2, 2)
#  Train - Balanced Acc: 0.8059 | Acc: 0.9138 | Sens: 0.6748 | Spec: 0.9371
#  Val - Balanced Acc: 0.7862 | Acc: 0.9061 | Sens: 0.6403 | Spec: 0.9320
#
# Models: ('svc', 'xgb') | Weights: (2, 3)
#  Train - Balanced Acc: 0.8072 | Acc: 0.9089 | Sens: 0.6834 | Spec: 0.9310
#  Val - Balanced Acc: 0.7934 | Acc: 0.9028 | Sens: 0.6603 | Spec: 0.9264
#
# Models: ('svc', 'xgb') | Weights: (3, 1)
#  Train - Balanced Acc: 0.7259 | Acc: 0.9246 | Sens: 0.4842 | Spec: 0.9676
#  Val - Balanced Acc: 0.6917 | Acc: 0.9177 | Sens: 0.4169 | Spec: 0.9666
#
# Models: ('svc', 'xgb') | Weights: (3, 2)
#  Train - Balanced Acc: 0.7983 | Acc: 0.9210 | Sens: 0.6490 | Spec: 0.9476
#  Val - Balanced Acc: 0.7709 | Acc: 0.9123 | Sens: 0.5988 | Spec: 0.9429
#
# Models: ('svc', 'xgb') | Weights: (3, 3)
#  Train - Balanced Acc: 0.8059 | Acc: 0.9138 | Sens: 0.6748 | Spec: 0.9371
#  Val - Balanced Acc: 0.7862 | Acc: 0.9061 | Sens: 0.6403 | Spec: 0.9320
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 1, 1)
#  Train - Balanced Acc: 0.8028 | Acc: 0.8984 | Sens: 0.6866 | Spec: 0.9191
#  Val - Balanced Acc: 0.7971 | Acc: 0.8966 | Sens: 0.6761 | Spec: 0.9182
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 1, 2)
#  Train - Balanced Acc: 0.7995 | Acc: 0.9035 | Sens: 0.6730 | Spec: 0.9260
#  Val - Balanced Acc: 0.7922 | Acc: 0.9006 | Sens: 0.6603 | Spec: 0.9240
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 1, 3)
#  Train - Balanced Acc: 0.7939 | Acc: 0.9125 | Sens: 0.6497 | Spec: 0.9381
#  Val - Balanced Acc: 0.7725 | Acc: 0.9070 | Sens: 0.6088 | Spec: 0.9361
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 2, 1)
#  Train - Balanced Acc: 0.8064 | Acc: 0.8972 | Sens: 0.6959 | Spec: 0.9169
#  Val - Balanced Acc: 0.7986 | Acc: 0.8946 | Sens: 0.6818 | Spec: 0.9154
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 2, 2)
#  Train - Balanced Acc: 0.8023 | Acc: 0.9004 | Sens: 0.6830 | Spec: 0.9216
#  Val - Balanced Acc: 0.7955 | Acc: 0.8984 | Sens: 0.6704 | Spec: 0.9207
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 2, 3)
#  Train - Balanced Acc: 0.7988 | Acc: 0.9038 | Sens: 0.6712 | Spec: 0.9265
#  Val - Balanced Acc: 0.7903 | Acc: 0.9006 | Sens: 0.6561 | Spec: 0.9245
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 3, 1)
#  Train - Balanced Acc: 0.8076 | Acc: 0.8961 | Sens: 0.6998 | Spec: 0.9153
#  Val - Balanced Acc: 0.7985 | Acc: 0.8933 | Sens: 0.6833 | Spec: 0.9138
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 3, 2)
#  Train - Balanced Acc: 0.8038 | Acc: 0.8987 | Sens: 0.6884 | Spec: 0.9192
#  Val - Balanced Acc: 0.7979 | Acc: 0.8968 | Sens: 0.6775 | Spec: 0.9182
#
# Models: ('rf', 'lr', 'svc') | Weights: (1, 3, 3)
#  Train - Balanced Acc: 0.8016 | Acc: 0.9014 | Sens: 0.6802 | Spec: 0.9230
#  Val - Balanced Acc: 0.7944 | Acc: 0.8988 | Sens: 0.6675 | Spec: 0.9214
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 1, 1)
#  Train - Balanced Acc: 0.8028 | Acc: 0.8968 | Sens: 0.6884 | Spec: 0.9172
#  Val - Balanced Acc: 0.7983 | Acc: 0.8952 | Sens: 0.6804 | Spec: 0.9162
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 1, 2)
#  Train - Balanced Acc: 0.8007 | Acc: 0.8986 | Sens: 0.6816 | Spec: 0.9198
#  Val - Balanced Acc: 0.7973 | Acc: 0.8970 | Sens: 0.6761 | Spec: 0.9186
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 1, 3)
#  Train - Balanced Acc: 0.8014 | Acc: 0.9038 | Sens: 0.6769 | Spec: 0.9260
#  Val - Balanced Acc: 0.7917 | Acc: 0.8997 | Sens: 0.6603 | Spec: 0.9231
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 2, 1)
#  Train - Balanced Acc: 0.8070 | Acc: 0.8968 | Sens: 0.6977 | Spec: 0.9162
#  Val - Balanced Acc: 0.8005 | Acc: 0.8945 | Sens: 0.6861 | Spec: 0.9148
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 2, 2)
#  Train - Balanced Acc: 0.8028 | Acc: 0.8984 | Sens: 0.6866 | Spec: 0.9191
#  Val - Balanced Acc: 0.7971 | Acc: 0.8966 | Sens: 0.6761 | Spec: 0.9182
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 2, 3)
#  Train - Balanced Acc: 0.8008 | Acc: 0.9003 | Sens: 0.6798 | Spec: 0.9219
#  Val - Balanced Acc: 0.7942 | Acc: 0.8984 | Sens: 0.6675 | Spec: 0.9210
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 3, 1)
#  Train - Balanced Acc: 0.8082 | Acc: 0.8961 | Sens: 0.7013 | Spec: 0.9152
#  Val - Balanced Acc: 0.7988 | Acc: 0.8927 | Sens: 0.6847 | Spec: 0.9130
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 3, 2)
#  Train - Balanced Acc: 0.8049 | Acc: 0.8980 | Sens: 0.6916 | Spec: 0.9182
#  Val - Balanced Acc: 0.7980 | Acc: 0.8959 | Sens: 0.6790 | Spec: 0.9170
#
# Models: ('rf', 'lr', 'svc') | Weights: (2, 3, 3)
#  Train - Balanced Acc: 0.8024 | Acc: 0.8996 | Sens: 0.6841 | Spec: 0.9207
#  Val - Balanced Acc: 0.7971 | Acc: 0.8978 | Sens: 0.6747 | Spec: 0.9196
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 1, 1)
#  Train - Balanced Acc: 0.8037 | Acc: 0.8964 | Sens: 0.6909 | Spec: 0.9165
#  Val - Balanced Acc: 0.7982 | Acc: 0.8950 | Sens: 0.6804 | Spec: 0.9159
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 1, 2)
#  Train - Balanced Acc: 0.8004 | Acc: 0.8969 | Sens: 0.6830 | Spec: 0.9178
#  Val - Balanced Acc: 0.7987 | Acc: 0.8959 | Sens: 0.6804 | Spec: 0.9169
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 1, 3)
#  Train - Balanced Acc: 0.8012 | Acc: 0.8995 | Sens: 0.6816 | Spec: 0.9207
#  Val - Balanced Acc: 0.7955 | Acc: 0.8973 | Sens: 0.6718 | Spec: 0.9193
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 2, 1)
#  Train - Balanced Acc: 0.8075 | Acc: 0.8968 | Sens: 0.6988 | Spec: 0.9161
#  Val - Balanced Acc: 0.7996 | Acc: 0.8941 | Sens: 0.6847 | Spec: 0.9145
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 2, 2)
#  Train - Balanced Acc: 0.8026 | Acc: 0.8973 | Sens: 0.6873 | Spec: 0.9179
#  Val - Balanced Acc: 0.7980 | Acc: 0.8959 | Sens: 0.6790 | Spec: 0.9170
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 2, 3)
#  Train - Balanced Acc: 0.8013 | Acc: 0.8985 | Sens: 0.6830 | Spec: 0.9195
#  Val - Balanced Acc: 0.7966 | Acc: 0.8968 | Sens: 0.6747 | Spec: 0.9184
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 3, 1)
#  Train - Balanced Acc: 0.8082 | Acc: 0.8960 | Sens: 0.7013 | Spec: 0.9150
#  Val - Balanced Acc: 0.7996 | Acc: 0.8930 | Sens: 0.6861 | Spec: 0.9131
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 3, 2)
#  Train - Balanced Acc: 0.8052 | Acc: 0.8972 | Sens: 0.6934 | Spec: 0.9171
#  Val - Balanced Acc: 0.7989 | Acc: 0.8951 | Sens: 0.6818 | Spec: 0.9159
#
# Models: ('rf', 'lr', 'svc') | Weights: (3, 3, 3)
#  Train - Balanced Acc: 0.8028 | Acc: 0.8984 | Sens: 0.6866 | Spec: 0.9191
#  Val - Balanced Acc: 0.7971 | Acc: 0.8966 | Sens: 0.6761 | Spec: 0.9182
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 1, 1)
#  Train - Balanced Acc: 0.8198 | Acc: 0.8957 | Sens: 0.7274 | Spec: 0.9121
#  Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 1, 2)
#  Train - Balanced Acc: 0.8242 | Acc: 0.8955 | Sens: 0.7375 | Spec: 0.9109
#  Val - Balanced Acc: 0.8014 | Acc: 0.8891 | Sens: 0.6947 | Spec: 0.9081
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 1, 3)
#  Train - Balanced Acc: 0.8260 | Acc: 0.8950 | Sens: 0.7421 | Spec: 0.9099
#  Val - Balanced Acc: 0.8011 | Acc: 0.8873 | Sens: 0.6961 | Spec: 0.9060
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 2, 1)
#  Train - Balanced Acc: 0.8179 | Acc: 0.8950 | Sens: 0.7242 | Spec: 0.9117
#  Val - Balanced Acc: 0.8011 | Acc: 0.8898 | Sens: 0.6933 | Spec: 0.9089
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 2, 2)
#  Train - Balanced Acc: 0.8205 | Acc: 0.8947 | Sens: 0.7303 | Spec: 0.9107
#  Val - Balanced Acc: 0.8008 | Acc: 0.8893 | Sens: 0.6933 | Spec: 0.9084
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 2, 3)
#  Train - Balanced Acc: 0.8234 | Acc: 0.8952 | Sens: 0.7360 | Spec: 0.9107
#  Val - Balanced Acc: 0.8011 | Acc: 0.8885 | Sens: 0.6947 | Spec: 0.9074
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 3, 1)
#  Train - Balanced Acc: 0.8158 | Acc: 0.8931 | Sens: 0.7217 | Spec: 0.9098
#  Val - Balanced Acc: 0.8010 | Acc: 0.8895 | Sens: 0.6933 | Spec: 0.9087
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 3, 2)
#  Train - Balanced Acc: 0.8185 | Acc: 0.8940 | Sens: 0.7267 | Spec: 0.9103
#  Val - Balanced Acc: 0.8008 | Acc: 0.8893 | Sens: 0.6933 | Spec: 0.9084
#
# Models: ('rf', 'lr', 'xgb') | Weights: (1, 3, 3)
#  Train - Balanced Acc: 0.8207 | Acc: 0.8945 | Sens: 0.7310 | Spec: 0.9104
#  Val - Balanced Acc: 0.8012 | Acc: 0.8887 | Sens: 0.6947 | Spec: 0.9077
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 1, 1)
#  Train - Balanced Acc: 0.8188 | Acc: 0.8962 | Sens: 0.7246 | Spec: 0.9130
#  Val - Balanced Acc: 0.8014 | Acc: 0.8915 | Sens: 0.6918 | Spec: 0.9110
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 1, 2)
#  Train - Balanced Acc: 0.8228 | Acc: 0.8961 | Sens: 0.7335 | Spec: 0.9120
#  Val - Balanced Acc: 0.8009 | Acc: 0.8905 | Sens: 0.6918 | Spec: 0.9099
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 1, 3)
#  Train - Balanced Acc: 0.8254 | Acc: 0.8959 | Sens: 0.7396 | Spec: 0.9111
#  Val - Balanced Acc: 0.8025 | Acc: 0.8900 | Sens: 0.6961 | Spec: 0.9089
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 2, 1)
#  Train - Balanced Acc: 0.8167 | Acc: 0.8957 | Sens: 0.7206 | Spec: 0.9128
#  Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 2, 2)
#  Train - Balanced Acc: 0.8198 | Acc: 0.8957 | Sens: 0.7274 | Spec: 0.9121
#  Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 2, 3)
#  Train - Balanced Acc: 0.8217 | Acc: 0.8954 | Sens: 0.7321 | Spec: 0.9113
#  Val - Balanced Acc: 0.8017 | Acc: 0.8896 | Sens: 0.6947 | Spec: 0.9087
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 3, 1)
#  Train - Balanced Acc: 0.8167 | Acc: 0.8953 | Sens: 0.7210 | Spec: 0.9124
#  Val - Balanced Acc: 0.8016 | Acc: 0.8907 | Sens: 0.6933 | Spec: 0.9099
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 3, 2)
#  Train - Balanced Acc: 0.8183 | Acc: 0.8953 | Sens: 0.7246 | Spec: 0.9120
#  Val - Balanced Acc: 0.8022 | Acc: 0.8907 | Sens: 0.6947 | Spec: 0.9098
#
# Models: ('rf', 'lr', 'xgb') | Weights: (2, 3, 3)
#  Train - Balanced Acc: 0.8205 | Acc: 0.8950 | Sens: 0.7299 | Spec: 0.9111
#  Val - Balanced Acc: 0.8010 | Acc: 0.8895 | Sens: 0.6933 | Spec: 0.9087
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 1, 1)
#  Train - Balanced Acc: 0.8189 | Acc: 0.8967 | Sens: 0.7242 | Spec: 0.9135
#  Val - Balanced Acc: 0.8017 | Acc: 0.8921 | Sens: 0.6919 | Spec: 0.9116
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 1, 2)
#  Train - Balanced Acc: 0.8221 | Acc: 0.8966 | Sens: 0.7314 | Spec: 0.9128
#  Val - Balanced Acc: 0.8013 | Acc: 0.8913 | Sens: 0.6918 | Spec: 0.9108
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 1, 3)
#  Train - Balanced Acc: 0.8249 | Acc: 0.8965 | Sens: 0.7378 | Spec: 0.9120
#  Val - Balanced Acc: 0.8009 | Acc: 0.8905 | Sens: 0.6918 | Spec: 0.9099
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 2, 1)
#  Train - Balanced Acc: 0.8164 | Acc: 0.8959 | Sens: 0.7196 | Spec: 0.9132
#  Val - Balanced Acc: 0.8023 | Acc: 0.8919 | Sens: 0.6933 | Spec: 0.9113
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 2, 2)
#  Train - Balanced Acc: 0.8190 | Acc: 0.8960 | Sens: 0.7253 | Spec: 0.9126
#  Val - Balanced Acc: 0.8022 | Acc: 0.8918 | Sens: 0.6933 | Spec: 0.9112
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 2, 3)
#  Train - Balanced Acc: 0.8216 | Acc: 0.8960 | Sens: 0.7310 | Spec: 0.9121
#  Val - Balanced Acc: 0.8025 | Acc: 0.8910 | Sens: 0.6947 | Spec: 0.9102
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 3, 1)
#  Train - Balanced Acc: 0.8163 | Acc: 0.8958 | Sens: 0.7196 | Spec: 0.9130
#  Val - Balanced Acc: 0.8012 | Acc: 0.8912 | Sens: 0.6918 | Spec: 0.9106
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 3, 2)
#  Train - Balanced Acc: 0.8170 | Acc: 0.8957 | Sens: 0.7213 | Spec: 0.9127
#  Val - Balanced Acc: 0.8027 | Acc: 0.8914 | Sens: 0.6947 | Spec: 0.9106
#
# Models: ('rf', 'lr', 'xgb') | Weights: (3, 3, 3)
#  Train - Balanced Acc: 0.8198 | Acc: 0.8957 | Sens: 0.7274 | Spec: 0.9121
#  Val - Balanced Acc: 0.8026 | Acc: 0.8913 | Sens: 0.6947 | Spec: 0.9105
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 1, 1)
#  Train - Balanced Acc: 0.8022 | Acc: 0.9010 | Sens: 0.6819 | Spec: 0.9224
#  Val - Balanced Acc: 0.7976 | Acc: 0.8987 | Sens: 0.6747 | Spec: 0.9205
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 1, 2)
#  Train - Balanced Acc: 0.8103 | Acc: 0.9022 | Sens: 0.6984 | Spec: 0.9221
#  Val - Balanced Acc: 0.7988 | Acc: 0.8984 | Sens: 0.6775 | Spec: 0.9200
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 1, 3)
#  Train - Balanced Acc: 0.8179 | Acc: 0.9026 | Sens: 0.7149 | Spec: 0.9210
#  Val - Balanced Acc: 0.7984 | Acc: 0.8965 | Sens: 0.6790 | Spec: 0.9177
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 2, 1)
#  Train - Balanced Acc: 0.8056 | Acc: 0.9099 | Sens: 0.6787 | Spec: 0.9325
#  Val - Balanced Acc: 0.7892 | Acc: 0.9033 | Sens: 0.6503 | Spec: 0.9280
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 2, 2)
#  Train - Balanced Acc: 0.8046 | Acc: 0.9054 | Sens: 0.6819 | Spec: 0.9272
#  Val - Balanced Acc: 0.7956 | Acc: 0.9010 | Sens: 0.6675 | Spec: 0.9238
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 2, 3)
#  Train - Balanced Acc: 0.8052 | Acc: 0.9041 | Sens: 0.6848 | Spec: 0.9255
#  Val - Balanced Acc: 0.7956 | Acc: 0.8998 | Sens: 0.6689 | Spec: 0.9224
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 3, 1)
#  Train - Balanced Acc: 0.7976 | Acc: 0.9195 | Sens: 0.6493 | Spec: 0.9459
#  Val - Balanced Acc: 0.7653 | Acc: 0.9104 | Sens: 0.5888 | Spec: 0.9418
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 3, 2)
#  Train - Balanced Acc: 0.8056 | Acc: 0.9114 | Sens: 0.6769 | Spec: 0.9343
#  Val - Balanced Acc: 0.7883 | Acc: 0.9040 | Sens: 0.6475 | Spec: 0.9291
#
# Models: ('rf', 'svc', 'xgb') | Weights: (1, 3, 3)
#  Train - Balanced Acc: 0.8058 | Acc: 0.9076 | Sens: 0.6819 | Spec: 0.9296
#  Val - Balanced Acc: 0.7945 | Acc: 0.9024 | Sens: 0.6632 | Spec: 0.9257
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 1, 1)
#  Train - Balanced Acc: 0.8017 | Acc: 0.8974 | Sens: 0.6852 | Spec: 0.9182
#  Val - Balanced Acc: 0.7989 | Acc: 0.8964 | Sens: 0.6804 | Spec: 0.9175
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 1, 2)
#  Train - Balanced Acc: 0.8112 | Acc: 0.9001 | Sens: 0.7031 | Spec: 0.9193
#  Val - Balanced Acc: 0.7989 | Acc: 0.8964 | Sens: 0.6804 | Spec: 0.9175
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 1, 3)
#  Train - Balanced Acc: 0.8175 | Acc: 0.9013 | Sens: 0.7156 | Spec: 0.9194
#  Val - Balanced Acc: 0.7989 | Acc: 0.8951 | Sens: 0.6818 | Spec: 0.9159
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 2, 1)
#  Train - Balanced Acc: 0.8024 | Acc: 0.9014 | Sens: 0.6819 | Spec: 0.9228
#  Val - Balanced Acc: 0.7977 | Acc: 0.8988 | Sens: 0.6747 | Spec: 0.9207
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 2, 2)
#  Train - Balanced Acc: 0.8022 | Acc: 0.9010 | Sens: 0.6819 | Spec: 0.9224
#  Val - Balanced Acc: 0.7976 | Acc: 0.8987 | Sens: 0.6747 | Spec: 0.9205
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 2, 3)
#  Train - Balanced Acc: 0.8052 | Acc: 0.9015 | Sens: 0.6880 | Spec: 0.9223
#  Val - Balanced Acc: 0.7980 | Acc: 0.8983 | Sens: 0.6761 | Spec: 0.9200
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 3, 1)
#  Train - Balanced Acc: 0.8055 | Acc: 0.9083 | Sens: 0.6805 | Spec: 0.9305
#  Val - Balanced Acc: 0.7912 | Acc: 0.9024 | Sens: 0.6561 | Spec: 0.9264
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 3, 2)
#  Train - Balanced Acc: 0.8044 | Acc: 0.9050 | Sens: 0.6819 | Spec: 0.9268
#  Val - Balanced Acc: 0.7967 | Acc: 0.9006 | Sens: 0.6704 | Spec: 0.9231
#
# Models: ('rf', 'svc', 'xgb') | Weights: (2, 3, 3)
#  Train - Balanced Acc: 0.8036 | Acc: 0.9036 | Sens: 0.6819 | Spec: 0.9253
#  Val - Balanced Acc: 0.7971 | Acc: 0.9001 | Sens: 0.6718 | Spec: 0.9224
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 1, 1)
#  Train - Balanced Acc: 0.8039 | Acc: 0.8968 | Sens: 0.6909 | Spec: 0.9169
#  Val - Balanced Acc: 0.7990 | Acc: 0.8952 | Sens: 0.6818 | Spec: 0.9161
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 1, 2)
#  Train - Balanced Acc: 0.8113 | Acc: 0.8986 | Sens: 0.7052 | Spec: 0.9175
#  Val - Balanced Acc: 0.7992 | Acc: 0.8956 | Sens: 0.6818 | Spec: 0.9165
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 1, 3)
#  Train - Balanced Acc: 0.8171 | Acc: 0.8997 | Sens: 0.7167 | Spec: 0.9175
#  Val - Balanced Acc: 0.7987 | Acc: 0.8949 | Sens: 0.6818 | Spec: 0.9157
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 2, 1)
#  Train - Balanced Acc: 0.8007 | Acc: 0.8983 | Sens: 0.6819 | Spec: 0.9194
#  Val - Balanced Acc: 0.7984 | Acc: 0.8966 | Sens: 0.6790 | Spec: 0.9179
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 2, 2)
#  Train - Balanced Acc: 0.8015 | Acc: 0.8989 | Sens: 0.6830 | Spec: 0.9200
#  Val - Balanced Acc: 0.7979 | Acc: 0.8969 | Sens: 0.6775 | Spec: 0.9183
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 2, 3)
#  Train - Balanced Acc: 0.8060 | Acc: 0.9001 | Sens: 0.6916 | Spec: 0.9205
#  Val - Balanced Acc: 0.7980 | Acc: 0.8970 | Sens: 0.6775 | Spec: 0.9184
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 3, 1)
#  Train - Balanced Acc: 0.8027 | Acc: 0.9020 | Sens: 0.6819 | Spec: 0.9235
#  Val - Balanced Acc: 0.7977 | Acc: 0.8989 | Sens: 0.6747 | Spec: 0.9208
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 3, 2)
#  Train - Balanced Acc: 0.8022 | Acc: 0.9011 | Sens: 0.6819 | Spec: 0.9225
#  Val - Balanced Acc: 0.7969 | Acc: 0.8986 | Sens: 0.6732 | Spec: 0.9205
#
# Models: ('rf', 'svc', 'xgb') | Weights: (3, 3, 3)
#  Train - Balanced Acc: 0.8022 | Acc: 0.9010 | Sens: 0.6819 | Spec: 0.9224
#  Val - Balanced Acc: 0.7976 | Acc: 0.8987 | Sens: 0.6747 | Spec: 0.9205
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 1, 1)
#  Train - Balanced Acc: 0.8063 | Acc: 0.9018 | Sens: 0.6902 | Spec: 0.9224
#  Val - Balanced Acc: 0.7963 | Acc: 0.8975 | Sens: 0.6732 | Spec: 0.9194
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 1, 2)
#  Train - Balanced Acc: 0.8119 | Acc: 0.9017 | Sens: 0.7027 | Spec: 0.9211
#  Val - Balanced Acc: 0.8000 | Acc: 0.8972 | Sens: 0.6818 | Spec: 0.9182
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 1, 3)
#  Train - Balanced Acc: 0.8163 | Acc: 0.9017 | Sens: 0.7124 | Spec: 0.9201
#  Val - Balanced Acc: 0.8020 | Acc: 0.8961 | Sens: 0.6875 | Spec: 0.9165
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 2, 1)
#  Train - Balanced Acc: 0.8017 | Acc: 0.9078 | Sens: 0.6726 | Spec: 0.9307
#  Val - Balanced Acc: 0.7882 | Acc: 0.9028 | Sens: 0.6489 | Spec: 0.9275
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 2, 2)
#  Train - Balanced Acc: 0.8052 | Acc: 0.9053 | Sens: 0.6834 | Spec: 0.9269
#  Val - Balanced Acc: 0.7951 | Acc: 0.9012 | Sens: 0.6661 | Spec: 0.9242
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 2, 3)
#  Train - Balanced Acc: 0.8073 | Acc: 0.9042 | Sens: 0.6895 | Spec: 0.9251
#  Val - Balanced Acc: 0.7962 | Acc: 0.8996 | Sens: 0.6704 | Spec: 0.9219
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 3, 1)
#  Train - Balanced Acc: 0.7956 | Acc: 0.9161 | Sens: 0.6490 | Spec: 0.9422
#  Val - Balanced Acc: 0.7741 | Acc: 0.9099 | Sens: 0.6088 | Spec: 0.9393
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 3, 2)
#  Train - Balanced Acc: 0.8033 | Acc: 0.9098 | Sens: 0.6737 | Spec: 0.9329
#  Val - Balanced Acc: 0.7879 | Acc: 0.9034 | Sens: 0.6475 | Spec: 0.9284
#
# Models: ('lr', 'svc', 'xgb') | Weights: (1, 3, 3)
#  Train - Balanced Acc: 0.8052 | Acc: 0.9074 | Sens: 0.6809 | Spec: 0.9295
#  Val - Balanced Acc: 0.7914 | Acc: 0.9015 | Sens: 0.6575 | Spec: 0.9253
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 1, 1)
#  Train - Balanced Acc: 0.8086 | Acc: 0.8989 | Sens: 0.6988 | Spec: 0.9184
#  Val - Balanced Acc: 0.7992 | Acc: 0.8956 | Sens: 0.6818 | Spec: 0.9165
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 1, 2)
#  Train - Balanced Acc: 0.8112 | Acc: 0.8992 | Sens: 0.7041 | Spec: 0.9182
#  Val - Balanced Acc: 0.8012 | Acc: 0.8959 | Sens: 0.6861 | Spec: 0.9163
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 1, 3)
#  Train - Balanced Acc: 0.8152 | Acc: 0.8995 | Sens: 0.7127 | Spec: 0.9178
#  Val - Balanced Acc: 0.8028 | Acc: 0.8951 | Sens: 0.6904 | Spec: 0.9151
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 2, 1)
#  Train - Balanced Acc: 0.8040 | Acc: 0.9025 | Sens: 0.6841 | Spec: 0.9239
#  Val - Balanced Acc: 0.7967 | Acc: 0.8995 | Sens: 0.6718 | Spec: 0.9217
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 2, 2)
#  Train - Balanced Acc: 0.8063 | Acc: 0.9018 | Sens: 0.6902 | Spec: 0.9224
#  Val - Balanced Acc: 0.7963 | Acc: 0.8975 | Sens: 0.6732 | Spec: 0.9194
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 2, 3)
#  Train - Balanced Acc: 0.8087 | Acc: 0.9015 | Sens: 0.6959 | Spec: 0.9216
#  Val - Balanced Acc: 0.7967 | Acc: 0.8970 | Sens: 0.6747 | Spec: 0.9187
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 3, 1)
#  Train - Balanced Acc: 0.8001 | Acc: 0.9061 | Sens: 0.6712 | Spec: 0.9291
#  Val - Balanced Acc: 0.7893 | Acc: 0.9024 | Sens: 0.6518 | Spec: 0.9268
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 3, 2)
#  Train - Balanced Acc: 0.8029 | Acc: 0.9041 | Sens: 0.6798 | Spec: 0.9260
#  Val - Balanced Acc: 0.7954 | Acc: 0.9017 | Sens: 0.6661 | Spec: 0.9247
#
# Models: ('lr', 'svc', 'xgb') | Weights: (2, 3, 3)
#  Train - Balanced Acc: 0.8056 | Acc: 0.9038 | Sens: 0.6862 | Spec: 0.9251
#  Val - Balanced Acc: 0.7949 | Acc: 0.8997 | Sens: 0.6675 | Spec: 0.9224
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 1, 1)
#  Train - Balanced Acc: 0.8093 | Acc: 0.8973 | Sens: 0.7024 | Spec: 0.9163
#  Val - Balanced Acc: 0.7996 | Acc: 0.8941 | Sens: 0.6847 | Spec: 0.9145
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 1, 2)
#  Train - Balanced Acc: 0.8116 | Acc: 0.8980 | Sens: 0.7067 | Spec: 0.9166
#  Val - Balanced Acc: 0.8010 | Acc: 0.8944 | Sens: 0.6875 | Spec: 0.9145
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 1, 3)
#  Train - Balanced Acc: 0.8142 | Acc: 0.8982 | Sens: 0.7120 | Spec: 0.9164
#  Val - Balanced Acc: 0.8013 | Acc: 0.8937 | Sens: 0.6890 | Spec: 0.9137
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 2, 1)
#  Train - Balanced Acc: 0.8047 | Acc: 0.8998 | Sens: 0.6891 | Spec: 0.9203
#  Val - Balanced Acc: 0.7973 | Acc: 0.8970 | Sens: 0.6761 | Spec: 0.9186
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 2, 2)
#  Train - Balanced Acc: 0.8079 | Acc: 0.8999 | Sens: 0.6959 | Spec: 0.9198
#  Val - Balanced Acc: 0.7984 | Acc: 0.8966 | Sens: 0.6790 | Spec: 0.9179
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 2, 3)
#  Train - Balanced Acc: 0.8091 | Acc: 0.9000 | Sens: 0.6984 | Spec: 0.9197
#  Val - Balanced Acc: 0.8002 | Acc: 0.8963 | Sens: 0.6833 | Spec: 0.9170
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 3, 1)
#  Train - Balanced Acc: 0.8033 | Acc: 0.9031 | Sens: 0.6819 | Spec: 0.9247
#  Val - Balanced Acc: 0.7952 | Acc: 0.9002 | Sens: 0.6675 | Spec: 0.9229
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 3, 2)
#  Train - Balanced Acc: 0.8045 | Acc: 0.9022 | Sens: 0.6855 | Spec: 0.9234
#  Val - Balanced Acc: 0.7963 | Acc: 0.8987 | Sens: 0.6718 | Spec: 0.9208
#
# Models: ('lr', 'svc', 'xgb') | Weights: (3, 3, 3)
#  Train - Balanced Acc: 0.8063 | Acc: 0.9018 | Sens: 0.6902 | Spec: 0.9224
#  Val - Balanced Acc: 0.7963 | Acc: 0.8975 | Sens: 0.6732 | Spec: 0.9194
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 1, 1)
#  Train - Balanced Acc: 0.8072 | Acc: 0.8992 | Sens: 0.6952 | Spec: 0.9191
#  Val - Balanced Acc: 0.8002 | Acc: 0.8963 | Sens: 0.6833 | Spec: 0.9170
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 1, 2)
#  Train - Balanced Acc: 0.8124 | Acc: 0.9000 | Sens: 0.7059 | Spec: 0.9189
#  Val - Balanced Acc: 0.7995 | Acc: 0.8951 | Sens: 0.6833 | Spec: 0.9158
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 1, 3)
#  Train - Balanced Acc: 0.8154 | Acc: 0.9004 | Sens: 0.7120 | Spec: 0.9188
#  Val - Balanced Acc: 0.8013 | Acc: 0.8947 | Sens: 0.6876 | Spec: 0.9150
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 2, 1)
#  Train - Balanced Acc: 0.8027 | Acc: 0.9020 | Sens: 0.6819 | Spec: 0.9235
#  Val - Balanced Acc: 0.7945 | Acc: 0.8989 | Sens: 0.6675 | Spec: 0.9215
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 2, 2)
#  Train - Balanced Acc: 0.8044 | Acc: 0.9016 | Sens: 0.6862 | Spec: 0.9226
#  Val - Balanced Acc: 0.7976 | Acc: 0.8987 | Sens: 0.6747 | Spec: 0.9205
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 2, 3)
#  Train - Balanced Acc: 0.8071 | Acc: 0.9017 | Sens: 0.6920 | Spec: 0.9222
#  Val - Balanced Acc: 0.7981 | Acc: 0.8984 | Sens: 0.6761 | Spec: 0.9201
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 3, 1)
#  Train - Balanced Acc: 0.8022 | Acc: 0.9067 | Sens: 0.6751 | Spec: 0.9293
#  Val - Balanced Acc: 0.7913 | Acc: 0.9025 | Sens: 0.6561 | Spec: 0.9266
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 3, 2)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9044 | Sens: 0.6812 | Spec: 0.9262
#  Val - Balanced Acc: 0.7951 | Acc: 0.9011 | Sens: 0.6661 | Spec: 0.9240
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 1, 3, 3)
#  Train - Balanced Acc: 0.8044 | Acc: 0.9035 | Sens: 0.6837 | Spec: 0.9250
#  Val - Balanced Acc: 0.7959 | Acc: 0.9003 | Sens: 0.6689 | Spec: 0.9229
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 1, 1)
#  Train - Balanced Acc: 0.8085 | Acc: 0.8976 | Sens: 0.7002 | Spec: 0.9168
#  Val - Balanced Acc: 0.7997 | Acc: 0.8944 | Sens: 0.6847 | Spec: 0.9148
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 1, 2)
#  Train - Balanced Acc: 0.8116 | Acc: 0.8982 | Sens: 0.7063 | Spec: 0.9169
#  Val - Balanced Acc: 0.8018 | Acc: 0.8945 | Sens: 0.6890 | Spec: 0.9145
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 1, 3)
#  Train - Balanced Acc: 0.8152 | Acc: 0.8988 | Sens: 0.7135 | Spec: 0.9169
#  Val - Balanced Acc: 0.8020 | Acc: 0.8937 | Sens: 0.6904 | Spec: 0.9136
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 2, 1)
#  Train - Balanced Acc: 0.8050 | Acc: 0.9002 | Sens: 0.6891 | Spec: 0.9208
#  Val - Balanced Acc: 0.7975 | Acc: 0.8973 | Sens: 0.6761 | Spec: 0.9189
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 2, 2)
#  Train - Balanced Acc: 0.8069 | Acc: 0.9002 | Sens: 0.6934 | Spec: 0.9204
#  Val - Balanced Acc: 0.7985 | Acc: 0.8968 | Sens: 0.6790 | Spec: 0.9180
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 2, 3)
#  Train - Balanced Acc: 0.8090 | Acc: 0.9005 | Sens: 0.6977 | Spec: 0.9203
#  Val - Balanced Acc: 0.8003 | Acc: 0.8965 | Sens: 0.6833 | Spec: 0.9173
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 3, 1)
#  Train - Balanced Acc: 0.8020 | Acc: 0.9025 | Sens: 0.6798 | Spec: 0.9243
#  Val - Balanced Acc: 0.7951 | Acc: 0.9001 | Sens: 0.6675 | Spec: 0.9228
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 3, 2)
#  Train - Balanced Acc: 0.8042 | Acc: 0.9023 | Sens: 0.6848 | Spec: 0.9236
#  Val - Balanced Acc: 0.7956 | Acc: 0.8986 | Sens: 0.6704 | Spec: 0.9208
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 2, 3, 3)
#  Train - Balanced Acc: 0.8055 | Acc: 0.9018 | Sens: 0.6884 | Spec: 0.9227
#  Val - Balanced Acc: 0.7960 | Acc: 0.8982 | Sens: 0.6718 | Spec: 0.9203
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 1, 1)
#  Train - Balanced Acc: 0.8093 | Acc: 0.8967 | Sens: 0.7031 | Spec: 0.9156
#  Val - Balanced Acc: 0.7993 | Acc: 0.8936 | Sens: 0.6847 | Spec: 0.9140
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 1, 2)
#  Train - Balanced Acc: 0.8117 | Acc: 0.8973 | Sens: 0.7077 | Spec: 0.9158
#  Val - Balanced Acc: 0.8023 | Acc: 0.8944 | Sens: 0.6904 | Spec: 0.9143
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 1, 3)
#  Train - Balanced Acc: 0.8138 | Acc: 0.8977 | Sens: 0.7117 | Spec: 0.9159
#  Val - Balanced Acc: 0.8019 | Acc: 0.8936 | Sens: 0.6904 | Spec: 0.9134
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 2, 1)
#  Train - Balanced Acc: 0.8059 | Acc: 0.8987 | Sens: 0.6930 | Spec: 0.9188
#  Val - Balanced Acc: 0.7970 | Acc: 0.8952 | Sens: 0.6775 | Spec: 0.9165
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 2, 2)
#  Train - Balanced Acc: 0.8083 | Acc: 0.8989 | Sens: 0.6981 | Spec: 0.9186
#  Val - Balanced Acc: 0.7977 | Acc: 0.8954 | Sens: 0.6790 | Spec: 0.9165
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 2, 3)
#  Train - Balanced Acc: 0.8090 | Acc: 0.8990 | Sens: 0.6995 | Spec: 0.9185
#  Val - Balanced Acc: 0.8005 | Acc: 0.8958 | Sens: 0.6847 | Spec: 0.9164
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 3, 1)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9009 | Sens: 0.6855 | Spec: 0.9219
#  Val - Balanced Acc: 0.7962 | Acc: 0.8986 | Sens: 0.6718 | Spec: 0.9207
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 3, 2)
#  Train - Balanced Acc: 0.8055 | Acc: 0.9009 | Sens: 0.6895 | Spec: 0.9215
#  Val - Balanced Acc: 0.7964 | Acc: 0.8977 | Sens: 0.6732 | Spec: 0.9196
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (1, 3, 3, 3)
#  Train - Balanced Acc: 0.8066 | Acc: 0.9009 | Sens: 0.6920 | Spec: 0.9213
#  Val - Balanced Acc: 0.7979 | Acc: 0.8969 | Sens: 0.6775 | Spec: 0.9183
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 1, 1)
#  Train - Balanced Acc: 0.8074 | Acc: 0.8977 | Sens: 0.6977 | Spec: 0.9172
#  Val - Balanced Acc: 0.7997 | Acc: 0.8955 | Sens: 0.6833 | Spec: 0.9162
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 1, 2)
#  Train - Balanced Acc: 0.8125 | Acc: 0.8989 | Sens: 0.7074 | Spec: 0.9176
#  Val - Balanced Acc: 0.7991 | Acc: 0.8944 | Sens: 0.6833 | Spec: 0.9150
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 1, 3)
#  Train - Balanced Acc: 0.8162 | Acc: 0.8997 | Sens: 0.7145 | Spec: 0.9178
#  Val - Balanced Acc: 0.8010 | Acc: 0.8942 | Sens: 0.6876 | Spec: 0.9144
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 2, 1)
#  Train - Balanced Acc: 0.8023 | Acc: 0.8993 | Sens: 0.6844 | Spec: 0.9202
#  Val - Balanced Acc: 0.7989 | Acc: 0.8975 | Sens: 0.6790 | Spec: 0.9189
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 2, 2)
#  Train - Balanced Acc: 0.8040 | Acc: 0.8997 | Sens: 0.6877 | Spec: 0.9204
#  Val - Balanced Acc: 0.7995 | Acc: 0.8974 | Sens: 0.6804 | Spec: 0.9186
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 2, 3)
#  Train - Balanced Acc: 0.8084 | Acc: 0.9005 | Sens: 0.6963 | Spec: 0.9205
#  Val - Balanced Acc: 0.7994 | Acc: 0.8972 | Sens: 0.6804 | Spec: 0.9183
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 3, 1)
#  Train - Balanced Acc: 0.8025 | Acc: 0.9019 | Sens: 0.6816 | Spec: 0.9234
#  Val - Balanced Acc: 0.7952 | Acc: 0.8991 | Sens: 0.6689 | Spec: 0.9215
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 3, 2)
#  Train - Balanced Acc: 0.8027 | Acc: 0.9014 | Sens: 0.6827 | Spec: 0.9227
#  Val - Balanced Acc: 0.7977 | Acc: 0.8989 | Sens: 0.6747 | Spec: 0.9208
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 1, 3, 3)
#  Train - Balanced Acc: 0.8037 | Acc: 0.9014 | Sens: 0.6848 | Spec: 0.9225
#  Val - Balanced Acc: 0.7977 | Acc: 0.8989 | Sens: 0.6747 | Spec: 0.9208
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 1, 1)
#  Train - Balanced Acc: 0.8085 | Acc: 0.8969 | Sens: 0.7009 | Spec: 0.9160
#  Val - Balanced Acc: 0.7993 | Acc: 0.8935 | Sens: 0.6847 | Spec: 0.9138
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 1, 2)
#  Train - Balanced Acc: 0.8117 | Acc: 0.8974 | Sens: 0.7074 | Spec: 0.9160
#  Val - Balanced Acc: 0.8006 | Acc: 0.8935 | Sens: 0.6876 | Spec: 0.9136
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 1, 3)
#  Train - Balanced Acc: 0.8147 | Acc: 0.8981 | Sens: 0.7131 | Spec: 0.9162
#  Val - Balanced Acc: 0.8022 | Acc: 0.8941 | Sens: 0.6904 | Spec: 0.9140
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 2, 1)
#  Train - Balanced Acc: 0.8048 | Acc: 0.8987 | Sens: 0.6905 | Spec: 0.9190
#  Val - Balanced Acc: 0.7990 | Acc: 0.8965 | Sens: 0.6804 | Spec: 0.9176
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 2, 2)
#  Train - Balanced Acc: 0.8072 | Acc: 0.8992 | Sens: 0.6952 | Spec: 0.9191
#  Val - Balanced Acc: 0.8002 | Acc: 0.8963 | Sens: 0.6833 | Spec: 0.9170
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 2, 3)
#  Train - Balanced Acc: 0.8094 | Acc: 0.8995 | Sens: 0.6998 | Spec: 0.9190
#  Val - Balanced Acc: 0.7997 | Acc: 0.8954 | Sens: 0.6833 | Spec: 0.9161
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 3, 1)
#  Train - Balanced Acc: 0.8025 | Acc: 0.9002 | Sens: 0.6837 | Spec: 0.9214
#  Val - Balanced Acc: 0.7958 | Acc: 0.8978 | Sens: 0.6718 | Spec: 0.9198
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 3, 2)
#  Train - Balanced Acc: 0.8036 | Acc: 0.9004 | Sens: 0.6859 | Spec: 0.9214
#  Val - Balanced Acc: 0.7986 | Acc: 0.8980 | Sens: 0.6775 | Spec: 0.9196
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 2, 3, 3)
#  Train - Balanced Acc: 0.8051 | Acc: 0.9007 | Sens: 0.6887 | Spec: 0.9214
#  Val - Balanced Acc: 0.7998 | Acc: 0.8980 | Sens: 0.6804 | Spec: 0.9193
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 1, 1)
#  Train - Balanced Acc: 0.8093 | Acc: 0.8963 | Sens: 0.7034 | Spec: 0.9151
#  Val - Balanced Acc: 0.8005 | Acc: 0.8933 | Sens: 0.6876 | Spec: 0.9134
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 1, 2)
#  Train - Balanced Acc: 0.8114 | Acc: 0.8969 | Sens: 0.7074 | Spec: 0.9154
#  Val - Balanced Acc: 0.8007 | Acc: 0.8937 | Sens: 0.6876 | Spec: 0.9138
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 1, 3)
#  Train - Balanced Acc: 0.8140 | Acc: 0.8975 | Sens: 0.7124 | Spec: 0.9156
#  Val - Balanced Acc: 0.8018 | Acc: 0.8933 | Sens: 0.6904 | Spec: 0.9131
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 2, 1)
#  Train - Balanced Acc: 0.8062 | Acc: 0.8980 | Sens: 0.6945 | Spec: 0.9179
#  Val - Balanced Acc: 0.7984 | Acc: 0.8955 | Sens: 0.6804 | Spec: 0.9165
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 2, 2)
#  Train - Balanced Acc: 0.8085 | Acc: 0.8984 | Sens: 0.6991 | Spec: 0.9179
#  Val - Balanced Acc: 0.7987 | Acc: 0.8947 | Sens: 0.6818 | Spec: 0.9155
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 2, 3)
#  Train - Balanced Acc: 0.8099 | Acc: 0.8986 | Sens: 0.7020 | Spec: 0.9178
#  Val - Balanced Acc: 0.8000 | Acc: 0.8949 | Sens: 0.6847 | Spec: 0.9154
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 3, 1)
#  Train - Balanced Acc: 0.8043 | Acc: 0.8996 | Sens: 0.6884 | Spec: 0.9202
#  Val - Balanced Acc: 0.7981 | Acc: 0.8972 | Sens: 0.6775 | Spec: 0.9186
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 3, 2)
#  Train - Balanced Acc: 0.8055 | Acc: 0.8996 | Sens: 0.6909 | Spec: 0.9200
#  Val - Balanced Acc: 0.7981 | Acc: 0.8972 | Sens: 0.6775 | Spec: 0.9186
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (2, 3, 3, 3)
#  Train - Balanced Acc: 0.8073 | Acc: 0.9000 | Sens: 0.6945 | Spec: 0.9200
#  Val - Balanced Acc: 0.7997 | Acc: 0.8966 | Sens: 0.6818 | Spec: 0.9176
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 1, 1)
#  Train - Balanced Acc: 0.8083 | Acc: 0.8975 | Sens: 0.6998 | Spec: 0.9168
#  Val - Balanced Acc: 0.7998 | Acc: 0.8956 | Sens: 0.6833 | Spec: 0.9164
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 1, 2)
#  Train - Balanced Acc: 0.8128 | Acc: 0.8983 | Sens: 0.7088 | Spec: 0.9168
#  Val - Balanced Acc: 0.7998 | Acc: 0.8944 | Sens: 0.6847 | Spec: 0.9148
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 1, 3)
#  Train - Balanced Acc: 0.8160 | Acc: 0.8988 | Sens: 0.7153 | Spec: 0.9167
#  Val - Balanced Acc: 0.8017 | Acc: 0.8944 | Sens: 0.6890 | Spec: 0.9144
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 2, 1)
#  Train - Balanced Acc: 0.8013 | Acc: 0.8973 | Sens: 0.6844 | Spec: 0.9181
#  Val - Balanced Acc: 0.7988 | Acc: 0.8961 | Sens: 0.6804 | Spec: 0.9172
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 2, 2)
#  Train - Balanced Acc: 0.8043 | Acc: 0.8984 | Sens: 0.6898 | Spec: 0.9188
#  Val - Balanced Acc: 0.7983 | Acc: 0.8964 | Sens: 0.6790 | Spec: 0.9176
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 2, 3)
#  Train - Balanced Acc: 0.8083 | Acc: 0.8995 | Sens: 0.6973 | Spec: 0.9192
#  Val - Balanced Acc: 0.7990 | Acc: 0.8965 | Sens: 0.6804 | Spec: 0.9176
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 3, 1)
#  Train - Balanced Acc: 0.8013 | Acc: 0.8995 | Sens: 0.6819 | Spec: 0.9208
#  Val - Balanced Acc: 0.7991 | Acc: 0.8978 | Sens: 0.6790 | Spec: 0.9191
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 3, 2)
#  Train - Balanced Acc: 0.8022 | Acc: 0.8996 | Sens: 0.6837 | Spec: 0.9207
#  Val - Balanced Acc: 0.7991 | Acc: 0.8979 | Sens: 0.6790 | Spec: 0.9193
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 1, 3, 3)
#  Train - Balanced Acc: 0.8034 | Acc: 0.9000 | Sens: 0.6859 | Spec: 0.9209
#  Val - Balanced Acc: 0.7992 | Acc: 0.8980 | Sens: 0.6790 | Spec: 0.9194
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 1, 1)
#  Train - Balanced Acc: 0.8091 | Acc: 0.8969 | Sens: 0.7024 | Spec: 0.9159
#  Val - Balanced Acc: 0.8000 | Acc: 0.8936 | Sens: 0.6861 | Spec: 0.9138
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 1, 2)
#  Train - Balanced Acc: 0.8122 | Acc: 0.8972 | Sens: 0.7088 | Spec: 0.9156
#  Val - Balanced Acc: 0.8005 | Acc: 0.8933 | Sens: 0.6876 | Spec: 0.9134
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 1, 3)
#  Train - Balanced Acc: 0.8139 | Acc: 0.8976 | Sens: 0.7120 | Spec: 0.9157
#  Val - Balanced Acc: 0.8005 | Acc: 0.8933 | Sens: 0.6876 | Spec: 0.9134
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 2, 1)
#  Train - Balanced Acc: 0.8053 | Acc: 0.8979 | Sens: 0.6927 | Spec: 0.9179
#  Val - Balanced Acc: 0.7986 | Acc: 0.8958 | Sens: 0.6804 | Spec: 0.9168
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 2, 2)
#  Train - Balanced Acc: 0.8076 | Acc: 0.8985 | Sens: 0.6970 | Spec: 0.9182
#  Val - Balanced Acc: 0.8000 | Acc: 0.8960 | Sens: 0.6833 | Spec: 0.9168
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 2, 3)
#  Train - Balanced Acc: 0.8095 | Acc: 0.8988 | Sens: 0.7009 | Spec: 0.9181
#  Val - Balanced Acc: 0.7995 | Acc: 0.8951 | Sens: 0.6833 | Spec: 0.9158
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 3, 1)
#  Train - Balanced Acc: 0.8020 | Acc: 0.8986 | Sens: 0.6844 | Spec: 0.9195
#  Val - Balanced Acc: 0.7979 | Acc: 0.8969 | Sens: 0.6775 | Spec: 0.9183
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 3, 2)
#  Train - Balanced Acc: 0.8034 | Acc: 0.8991 | Sens: 0.6870 | Spec: 0.9198
#  Val - Balanced Acc: 0.7994 | Acc: 0.8973 | Sens: 0.6804 | Spec: 0.9184
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 2, 3, 3)
#  Train - Balanced Acc: 0.8048 | Acc: 0.8994 | Sens: 0.6898 | Spec: 0.9198
#  Val - Balanced Acc: 0.7994 | Acc: 0.8972 | Sens: 0.6804 | Spec: 0.9183
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 1, 1)
#  Train - Balanced Acc: 0.8094 | Acc: 0.8963 | Sens: 0.7038 | Spec: 0.9151
#  Val - Balanced Acc: 0.8011 | Acc: 0.8932 | Sens: 0.6890 | Spec: 0.9131
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 1, 2)
#  Train - Balanced Acc: 0.8115 | Acc: 0.8966 | Sens: 0.7081 | Spec: 0.9150
#  Val - Balanced Acc: 0.8017 | Acc: 0.8932 | Sens: 0.6904 | Spec: 0.9130
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 1, 3)
#  Train - Balanced Acc: 0.8136 | Acc: 0.8968 | Sens: 0.7124 | Spec: 0.9148
#  Val - Balanced Acc: 0.8016 | Acc: 0.8931 | Sens: 0.6904 | Spec: 0.9129
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 2, 1)
#  Train - Balanced Acc: 0.8068 | Acc: 0.8974 | Sens: 0.6966 | Spec: 0.9170
#  Val - Balanced Acc: 0.7990 | Acc: 0.8952 | Sens: 0.6818 | Spec: 0.9161
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 2, 2)
#  Train - Balanced Acc: 0.8084 | Acc: 0.8979 | Sens: 0.6995 | Spec: 0.9173
#  Val - Balanced Acc: 0.7985 | Acc: 0.8945 | Sens: 0.6818 | Spec: 0.9152
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 2, 3)
#  Train - Balanced Acc: 0.8102 | Acc: 0.8983 | Sens: 0.7031 | Spec: 0.9174
#  Val - Balanced Acc: 0.7999 | Acc: 0.8946 | Sens: 0.6847 | Spec: 0.9151
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 3, 1)
#  Train - Balanced Acc: 0.8043 | Acc: 0.8986 | Sens: 0.6895 | Spec: 0.9190
#  Val - Balanced Acc: 0.7984 | Acc: 0.8965 | Sens: 0.6790 | Spec: 0.9177
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 3, 2)
#  Train - Balanced Acc: 0.8058 | Acc: 0.8989 | Sens: 0.6927 | Spec: 0.9190
#  Val - Balanced Acc: 0.7989 | Acc: 0.8963 | Sens: 0.6804 | Spec: 0.9173
#
# Models: ('rf', 'lr', 'svc', 'xgb') | Weights: (3, 3, 3, 3)
#  Train - Balanced Acc: 0.8072 | Acc: 0.8992 | Sens: 0.6952 | Spec: 0.9191
#  Val - Balanced Acc: 0.8002 | Acc: 0.8963 | Sens: 0.6833 | Spec: 0.9170
#
# === Best Model Combination ===
# Models: ('lr', 'svc', 'xgb')
# Weights: (2, 1, 3)
#  Train - Balanced Acc: 0.8152 | Acc: 0.8995 | Sens: 0.7127 | Spec: 0.9178
#    Val - Balanced Acc: 0.8028 | Acc: 0.8951 | Sens: 0.6904 | Spec: 0.9151

# %% [markdown]
# ##### Test

# %%
# 取得最佳參數
best_estimators = [(name, models[name]) for name in best_result['models']]

final_model = VotingClassifier(
    estimators=best_estimators,
    voting='soft',
    weights=best_result['weights'],  # 加上這個
    n_jobs=-1
)
final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test.values)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 115                  60
# Actual Negative                 141                1646
# Sensitivity (Recall, TPR): 0.6571
# Specificity (TNR):         0.9211
# Accuracy:                  0.8976
# Balanced Accuracy:         0.7891
# F1 Score:         0.5336

# %% [markdown]
# ## Ensemble hard=>equal weight

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({np.int64(0): 7149, np.int64(1): 698})
# scale_pos_weight = 10.2421

# %%
rf_best_params =  {'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 40, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
rf_clf = RandomForestClassifier(
            **rf_best_params,
            random_state=seed,
            n_jobs=-1,
            class_weight='balanced'
)


lr_best_params = 512
lr_clf = LogisticRegression(
            C=lr_best_params,
            penalty='l2',
            max_iter=1000,
            solver='lbfgs',
            class_weight='balanced',
            random_state=seed
        )


svc_best_c =  0.0078125
svc_best_gamma = 0.25
svc_clf = SVC(
       C=svc_best_c,
       gamma=svc_best_gamma,
       kernel='rbf',
       class_weight='balanced',
       probability=False,
       random_state=seed
      )

xgb_best_params = {'colsample_bytree': 0.8831528055561403, 'gamma': 0.021020125361070625, 'learning_rate': 0.03754890989284685, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.8246355080259108}
xgb_clf = xgb.XGBClassifier(
            **xgb_best_params,
            eval_metric="logloss",
            tree_method="hist",
            scale_pos_weight=scale_pos_weight,
            random_state=seed
        )

# %%
from sklearn.ensemble import VotingClassifier
from itertools import combinations
# 定義 base 模型
models = {
    'rf': rf_clf,
    'lr': lr_clf,
    'svc': svc_clf,
    'xgb': xgb_clf,
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = []

for r in range(2, len(models) + 1):  # 組合長度 2~4
    for subset in combinations(models.items(), r):
        clf_names, clf_list = zip(*subset)

        eclf = VotingClassifier(
            estimators=list(subset),
            voting='hard',
            n_jobs=-1
        )

        train_bal_accs, train_accs, train_sens, train_spec = [], [], [], []
        val_bal_accs, val_accs, val_sens, val_spec = [], [], [], []

        for train_idx, val_idx in cv.split(x, y):
            X_train_fold, y_train_fold = x[train_idx], y[train_idx]
            X_val_fold, y_val_fold = x[val_idx], y[val_idx]

            eclf.fit(X_train_fold, y_train_fold)

            # 預測
            y_train_pred = eclf.predict(X_train_fold)
            y_val_pred = eclf.predict(X_val_fold)

            # === Train metrics ===
            train_bal_accs.append(balanced_accuracy_score(y_train_fold, y_train_pred))
            train_accs.append(accuracy_score(y_train_fold, y_train_pred))
            train_sens.append(recall_score(y_train_fold, y_train_pred, pos_label=1))
            train_spec.append(recall_score(y_train_fold, y_train_pred, pos_label=0))

            # === Val metrics ===
            val_bal_accs.append(balanced_accuracy_score(y_val_fold, y_val_pred))
            val_accs.append(accuracy_score(y_val_fold, y_val_pred))
            val_sens.append(recall_score(y_val_fold, y_val_pred, pos_label=1))
            val_spec.append(recall_score(y_val_fold, y_val_pred, pos_label=0))

        # 平均結果
        result = {
            'models': clf_names,
            'train_bal_acc': np.mean(train_bal_accs),
            'train_acc': np.mean(train_accs),
            'train_sens': np.mean(train_sens),
            'train_spec': np.mean(train_spec),
            'val_bal_acc': np.mean(val_bal_accs),
            'val_acc': np.mean(val_accs),
            'val_sens': np.mean(val_sens),
            'val_spec': np.mean(val_spec),
        }

        results.append(result)

        # 輸出格式化結果
        print(f"Models: {clf_names}")
        print(f" Train - Balanced Acc: {result['train_bal_acc']:.4f} | Acc: {result['train_acc']:.4f} | Sens: {result['train_sens']:.4f} | Spec: {result['train_spec']:.4f}")
        print(f" Val - Balanced Acc: {result['val_bal_acc']:.4f} | Acc: {result['val_acc']:.4f} | Sens: {result['val_sens']:.4f} | Spec: {result['val_spec']:.4f}")
        print("")

# 選出最佳組合（以 val_bal_acc 為主）
best_result = max(results, key=lambda r: r['val_bal_acc'])

print("=== Best Model Combination ===")
print(f"Models: {best_result['models']}")
print(f" Train - Balanced Acc: {best_result['train_bal_acc']:.4f} | Acc: {best_result['train_acc']:.4f} | Sens: {best_result['train_sens']:.4f} | Spec: {best_result['train_spec']:.4f}")
print(f"   Val - Balanced Acc: {best_result['val_bal_acc']:.4f} | Acc: {best_result['val_acc']:.4f} | Sens: {best_result['val_sens']:.4f} | Spec: {best_result['val_spec']:.4f}")
# Out:
# Models: ('rf', 'lr')
#  Train - Balanced Acc: 0.8110 | Acc: 0.8995 | Sens: 0.7034 | Spec: 0.9186
#  Val - Balanced Acc: 0.7975 | Acc: 0.8961 | Sens: 0.6775 | Spec: 0.9175
#
# Models: ('rf', 'svc')
#  Train - Balanced Acc: 0.7993 | Acc: 0.8952 | Sens: 0.6827 | Spec: 0.9159
#  Val - Balanced Acc: 0.7989 | Acc: 0.8951 | Sens: 0.6818 | Spec: 0.9159
#
# Models: ('rf', 'xgb')
#  Train - Balanced Acc: 0.8205 | Acc: 0.9041 | Sens: 0.7188 | Spec: 0.9222
#  Val - Balanced Acc: 0.7983 | Acc: 0.8988 | Sens: 0.6761 | Spec: 0.9205
#
# Models: ('lr', 'svc')
#  Train - Balanced Acc: 0.8004 | Acc: 0.8977 | Sens: 0.6819 | Spec: 0.9188
#  Val - Balanced Acc: 0.7955 | Acc: 0.8960 | Sens: 0.6732 | Spec: 0.9177
#
# Models: ('lr', 'xgb')
#  Train - Balanced Acc: 0.8148 | Acc: 0.9004 | Sens: 0.7106 | Spec: 0.9190
#  Val - Balanced Acc: 0.7981 | Acc: 0.8949 | Sens: 0.6804 | Spec: 0.9158
#
# Models: ('svc', 'xgb')
#  Train - Balanced Acc: 0.8030 | Acc: 0.9013 | Sens: 0.6834 | Spec: 0.9226
#  Val - Balanced Acc: 0.7965 | Acc: 0.8989 | Sens: 0.6718 | Spec: 0.9211
#
# Models: ('rf', 'lr', 'svc')
#  Train - Balanced Acc: 0.8106 | Acc: 0.8970 | Sens: 0.7056 | Spec: 0.9157
#  Val - Balanced Acc: 0.8009 | Acc: 0.8952 | Sens: 0.6861 | Spec: 0.9157
#
# Models: ('rf', 'lr', 'xgb')
#  Train - Balanced Acc: 0.8195 | Acc: 0.8957 | Sens: 0.7267 | Spec: 0.9122
#  Val - Balanced Acc: 0.8017 | Acc: 0.8909 | Sens: 0.6933 | Spec: 0.9102
#
# Models: ('rf', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8175 | Acc: 0.8981 | Sens: 0.7196 | Spec: 0.9155
#  Val - Balanced Acc: 0.8007 | Acc: 0.8950 | Sens: 0.6861 | Spec: 0.9154
#
# Models: ('lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8122 | Acc: 0.8945 | Sens: 0.7120 | Spec: 0.9124
#  Val - Balanced Acc: 0.8019 | Acc: 0.8912 | Sens: 0.6933 | Spec: 0.9105
#
# Models: ('rf', 'lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8112 | Acc: 0.8984 | Sens: 0.7052 | Spec: 0.9172
#  Val - Balanced Acc: 0.7999 | Acc: 0.8958 | Sens: 0.6832 | Spec: 0.9165
#
# === Best Model Combination ===
# Models: ('lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8122 | Acc: 0.8945 | Sens: 0.7120 | Spec: 0.9124
#    Val - Balanced Acc: 0.8019 | Acc: 0.8912 | Sens: 0.6933 | Spec: 0.9105

# %% [markdown]
# ##### Test

# %%
# 取得最佳參數
best_estimators = [(name, models[name]) for name in best_result['models']]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test.values)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 115                  60
# Actual Negative                 150                1637
# Sensitivity (Recall, TPR): 0.6571
# Specificity (TNR):         0.9161
# Accuracy:                  0.8930
# Balanced Accuracy:         0.7866
# F1 Score:         0.5227

# %% [markdown]
# ## Ensemble hard=>equal weight(all model)

# %%
x = X_train
y = y_train

# %%
from collections import Counter

# 先計算 scale_pos_weight
counter = Counter(y)
print(counter)

n_pos = counter[1]
n_neg = counter[0]
scale_pos_weight = n_neg / n_pos
print(f"scale_pos_weight = {scale_pos_weight:.4f}")
# Out:
# Counter({0: 7149, 1: 698})
# scale_pos_weight = 10.2421

# %%
import lightgbm as lgb
rf_best_params =  {'max_depth': 10, 'max_features': 'log2', 'max_leaf_nodes': 40, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200}
rf_clf = RandomForestClassifier(
            **rf_best_params,
            random_state=seed,
            n_jobs=-1,
            class_weight='balanced'
)


lr_best_params = 512
lr_clf = LogisticRegression(
            C=lr_best_params,
            penalty='l2',
            max_iter=1000,
            solver='lbfgs',
            class_weight='balanced',
            random_state=seed
        )


svc_best_c =  0.0078125
svc_best_gamma = 0.25
svc_clf = SVC(
       C=svc_best_c,
       gamma=svc_best_gamma,
       kernel='rbf',
       class_weight='balanced',
       probability=False,
       random_state=seed
      )

xgb_best_params = {'colsample_bytree': 0.8831528055561403, 'gamma': 0.021020125361070625, 'learning_rate': 0.03754890989284685, 'max_depth': 3, 'n_estimators': 181, 'subsample': 0.8246355080259108}
xgb_clf = xgb.XGBClassifier(
            **xgb_best_params,
            eval_metric="logloss",
            tree_method="hist",
            scale_pos_weight=scale_pos_weight,
            random_state=seed
        )

ada_best_n_estimators = 50
ada_best_learning_rate = 0.001
ada_best_base_estimator = DecisionTreeClassifier(class_weight='balanced', max_depth=2)

ada_clf = AdaBoostClassifier(
    estimator=ada_best_base_estimator,
    n_estimators=ada_best_n_estimators,
    learning_rate=ada_best_learning_rate,
    random_state=seed
)

lgb_best_n_estimators = 400
lgb_best_learning_rate = 0.01
lgb_best_num_leaves = 15
lgb_best_max_depth = 9

lgb_clf = lgb.LGBMClassifier(
    n_estimators=lgb_best_n_estimators,
    learning_rate=lgb_best_learning_rate,
    num_leaves=lgb_best_num_leaves,
    max_depth=lgb_best_max_depth,
    class_weight="balanced",
    random_state=seed,
    n_jobs=-1)

class_weights = {0: 1.0, 1: scale_pos_weight}

cat_best_n_estimators = 200
cat_best_learning_rate = 0.05
cat_best_max_depth = 3
cat_best_l2_leaf_reg = 64

cat_clf = CatBoostClassifier(
        iterations=cat_best_n_estimators,
        learning_rate=cat_best_learning_rate,
        depth=cat_best_max_depth,
        l2_leaf_reg=cat_best_l2_leaf_reg,
        loss_function="Logloss",
        eval_metric="BalancedAccuracy",  # CPU 模式支援 BalancedAccuracy
        class_weights=class_weights,
        random_seed=seed,
        verbose=0,
        task_type="CPU"   # 改成 CPU
)

# %%
from sklearn.ensemble import VotingClassifier
from itertools import combinations
# 定義 base 模型
models = {
    'rf': rf_clf,
    'lr': lr_clf,
    'svc': svc_clf,
    'xgb': xgb_clf,
    'ada': ada_clf,
    'lgb': lgb_clf,
    'cat': cat_clf,
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = []

for r in range(3, len(models) + 1, 2):
    for subset in combinations(models.items(), r):
        clf_names, clf_list = zip(*subset)

        eclf = VotingClassifier(
            estimators=list(subset),
            voting='hard',
            n_jobs=-1
        )

        train_bal_accs, train_accs, train_sens, train_spec = [], [], [], []
        val_bal_accs, val_accs, val_sens, val_spec = [], [], [], []

        for train_idx, val_idx in cv.split(x, y):
            x_train_fold, y_train_fold = x.iloc[train_idx], y.iloc[train_idx]
            x_val_fold, y_val_fold     = x.iloc[val_idx], y.iloc[val_idx]

            eclf.fit(x_train_fold, y_train_fold)

            # 預測
            y_train_pred = eclf.predict(x_train_fold)
            y_val_pred = eclf.predict(x_val_fold)

            # === Train metrics ===
            train_bal_accs.append(balanced_accuracy_score(y_train_fold, y_train_pred))
            train_accs.append(accuracy_score(y_train_fold, y_train_pred))
            train_sens.append(recall_score(y_train_fold, y_train_pred, pos_label=1))
            train_spec.append(recall_score(y_train_fold, y_train_pred, pos_label=0))

            # === Val metrics ===
            val_bal_accs.append(balanced_accuracy_score(y_val_fold, y_val_pred))
            val_accs.append(accuracy_score(y_val_fold, y_val_pred))
            val_sens.append(recall_score(y_val_fold, y_val_pred, pos_label=1))
            val_spec.append(recall_score(y_val_fold, y_val_pred, pos_label=0))

        # 平均結果
        result = {
            'models': clf_names,
            'train_bal_acc': np.mean(train_bal_accs),
            'train_acc': np.mean(train_accs),
            'train_sens': np.mean(train_sens),
            'train_spec': np.mean(train_spec),
            'val_bal_acc': np.mean(val_bal_accs),
            'val_acc': np.mean(val_accs),
            'val_sens': np.mean(val_sens),
            'val_spec': np.mean(val_spec),
        }

        results.append(result)

        # 輸出格式化結果
        print(f"Models: {clf_names}")
        print(f" Train - Balanced Acc: {result['train_bal_acc']:.4f} | Acc: {result['train_acc']:.4f} | Sens: {result['train_sens']:.4f} | Spec: {result['train_spec']:.4f}")
        print(f" Val - Balanced Acc: {result['val_bal_acc']:.4f} | Acc: {result['val_acc']:.4f} | Sens: {result['val_sens']:.4f} | Spec: {result['val_spec']:.4f}")
        print("")

# 選出最佳組合（以 val_bal_acc 為主）
best_result = max(results, key=lambda r: r['val_bal_acc'])

print("=== Best Model Combination ===")
print(f"Models: {best_result['models']}")
print(f" Train - Balanced Acc: {best_result['train_bal_acc']:.4f} | Acc: {best_result['train_acc']:.4f} | Sens: {best_result['train_sens']:.4f} | Spec: {best_result['train_spec']:.4f}")
print(f"   Val - Balanced Acc: {best_result['val_bal_acc']:.4f} | Acc: {best_result['val_acc']:.4f} | Sens: {best_result['val_sens']:.4f} | Spec: {best_result['val_spec']:.4f}")
# Out:
# Models: ('rf', 'lr', 'svc')
#  Train - Balanced Acc: 0.8106 | Acc: 0.8970 | Sens: 0.7056 | Spec: 0.9157
#  Val - Balanced Acc: 0.8009 | Acc: 0.8952 | Sens: 0.6861 | Spec: 0.9157
#
# Models: ('rf', 'lr', 'xgb')
#  Train - Balanced Acc: 0.8195 | Acc: 0.8957 | Sens: 0.7267 | Spec: 0.9122
#  Val - Balanced Acc: 0.8017 | Acc: 0.8909 | Sens: 0.6933 | Spec: 0.9102
#
# Models: ('rf', 'lr', 'ada')
#  Train - Balanced Acc: 0.8155 | Acc: 0.8917 | Sens: 0.7228 | Spec: 0.9082
#  Val - Balanced Acc: 0.8035 | Acc: 0.8894 | Sens: 0.6990 | Spec: 0.9080
#
# Models: ('rf', 'lr', 'lgb')
#  Train - Balanced Acc: 0.8213 | Acc: 0.8967 | Sens: 0.7296 | Spec: 0.9131
#  Val - Balanced Acc: 0.8029 | Acc: 0.8918 | Sens: 0.6947 | Spec: 0.9110
#
# Models: ('rf', 'lr', 'cat')
#  Train - Balanced Acc: 0.8164 | Acc: 0.8939 | Sens: 0.7221 | Spec: 0.9107
#  Val - Balanced Acc: 0.8038 | Acc: 0.8912 | Sens: 0.6976 | Spec: 0.9101
#
# Models: ('rf', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8175 | Acc: 0.8981 | Sens: 0.7196 | Spec: 0.9155
#  Val - Balanced Acc: 0.8007 | Acc: 0.8950 | Sens: 0.6861 | Spec: 0.9154
#
# Models: ('rf', 'svc', 'ada')
#  Train - Balanced Acc: 0.8172 | Acc: 0.8980 | Sens: 0.7188 | Spec: 0.9155
#  Val - Balanced Acc: 0.8007 | Acc: 0.8950 | Sens: 0.6861 | Spec: 0.9154
#
# Models: ('rf', 'svc', 'lgb')
#  Train - Balanced Acc: 0.8177 | Acc: 0.8981 | Sens: 0.7199 | Spec: 0.9155
#  Val - Balanced Acc: 0.8007 | Acc: 0.8950 | Sens: 0.6861 | Spec: 0.9154
#
# Models: ('rf', 'svc', 'cat')
#  Train - Balanced Acc: 0.8156 | Acc: 0.8977 | Sens: 0.7156 | Spec: 0.9155
#  Val - Balanced Acc: 0.8007 | Acc: 0.8950 | Sens: 0.6861 | Spec: 0.9154
#
# Models: ('rf', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8240 | Acc: 0.8867 | Sens: 0.7478 | Spec: 0.9002
#  Val - Balanced Acc: 0.7998 | Acc: 0.8779 | Sens: 0.7047 | Spec: 0.8948
#
# Models: ('rf', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8372 | Acc: 0.8985 | Sens: 0.7625 | Spec: 0.9118
#  Val - Balanced Acc: 0.8018 | Acc: 0.8875 | Sens: 0.6976 | Spec: 0.9060
#
# Models: ('rf', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8190 | Acc: 0.8892 | Sens: 0.7335 | Spec: 0.9044
#  Val - Balanced Acc: 0.8021 | Acc: 0.8834 | Sens: 0.7033 | Spec: 0.9010
#
# Models: ('rf', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8265 | Acc: 0.8894 | Sens: 0.7500 | Spec: 0.9030
#  Val - Balanced Acc: 0.8022 | Acc: 0.8822 | Sens: 0.7047 | Spec: 0.8996
#
# Models: ('rf', 'ada', 'cat')
#  Train - Balanced Acc: 0.8153 | Acc: 0.8833 | Sens: 0.7324 | Spec: 0.8981
#  Val - Balanced Acc: 0.8058 | Acc: 0.8807 | Sens: 0.7148 | Spec: 0.8969
#
# Models: ('rf', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8210 | Acc: 0.8917 | Sens: 0.7350 | Spec: 0.9070
#  Val - Balanced Acc: 0.8030 | Acc: 0.8862 | Sens: 0.7019 | Spec: 0.9042
#
# Models: ('lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8122 | Acc: 0.8945 | Sens: 0.7120 | Spec: 0.9124
#  Val - Balanced Acc: 0.8019 | Acc: 0.8912 | Sens: 0.6933 | Spec: 0.9105
#
# Models: ('lr', 'svc', 'ada')
#  Train - Balanced Acc: 0.8086 | Acc: 0.8907 | Sens: 0.7088 | Spec: 0.9084
#  Val - Balanced Acc: 0.8036 | Acc: 0.8896 | Sens: 0.6990 | Spec: 0.9082
#
# Models: ('lr', 'svc', 'lgb')
#  Train - Balanced Acc: 0.8142 | Acc: 0.8956 | Sens: 0.7152 | Spec: 0.9132
#  Val - Balanced Acc: 0.8030 | Acc: 0.8921 | Sens: 0.6947 | Spec: 0.9113
#
# Models: ('lr', 'svc', 'cat')
#  Train - Balanced Acc: 0.8093 | Acc: 0.8928 | Sens: 0.7077 | Spec: 0.9108
#  Val - Balanced Acc: 0.8040 | Acc: 0.8914 | Sens: 0.6976 | Spec: 0.9103
#
# Models: ('lr', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8247 | Acc: 0.8858 | Sens: 0.7504 | Spec: 0.8990
#  Val - Balanced Acc: 0.7992 | Acc: 0.8769 | Sens: 0.7047 | Spec: 0.8937
#
# Models: ('lr', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8381 | Acc: 0.8973 | Sens: 0.7661 | Spec: 0.9101
#  Val - Balanced Acc: 0.8017 | Acc: 0.8861 | Sens: 0.6990 | Spec: 0.9043
#
# Models: ('lr', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8198 | Acc: 0.8886 | Sens: 0.7360 | Spec: 0.9035
#  Val - Balanced Acc: 0.8012 | Acc: 0.8829 | Sens: 0.7019 | Spec: 0.9005
#
# Models: ('lr', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8277 | Acc: 0.8878 | Sens: 0.7547 | Spec: 0.9008
#  Val - Balanced Acc: 0.8029 | Acc: 0.8801 | Sens: 0.7090 | Spec: 0.8968
#
# Models: ('lr', 'ada', 'cat')
#  Train - Balanced Acc: 0.8144 | Acc: 0.8818 | Sens: 0.7324 | Spec: 0.8964
#  Val - Balanced Acc: 0.8057 | Acc: 0.8792 | Sens: 0.7162 | Spec: 0.8951
#
# Models: ('lr', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8222 | Acc: 0.8907 | Sens: 0.7389 | Spec: 0.9055
#  Val - Balanced Acc: 0.8035 | Acc: 0.8848 | Sens: 0.7047 | Spec: 0.9024
#
# Models: ('svc', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8233 | Acc: 0.8865 | Sens: 0.7464 | Spec: 0.9002
#  Val - Balanced Acc: 0.7998 | Acc: 0.8779 | Sens: 0.7047 | Spec: 0.8948
#
# Models: ('svc', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8366 | Acc: 0.8984 | Sens: 0.7615 | Spec: 0.9118
#  Val - Balanced Acc: 0.8018 | Acc: 0.8875 | Sens: 0.6976 | Spec: 0.9060
#
# Models: ('svc', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8177 | Acc: 0.8890 | Sens: 0.7310 | Spec: 0.9044
#  Val - Balanced Acc: 0.8021 | Acc: 0.8834 | Sens: 0.7033 | Spec: 0.9010
#
# Models: ('svc', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8256 | Acc: 0.8893 | Sens: 0.7482 | Spec: 0.9030
#  Val - Balanced Acc: 0.8022 | Acc: 0.8822 | Sens: 0.7047 | Spec: 0.8996
#
# Models: ('svc', 'ada', 'cat')
#  Train - Balanced Acc: 0.8140 | Acc: 0.8831 | Sens: 0.7299 | Spec: 0.8981
#  Val - Balanced Acc: 0.8058 | Acc: 0.8807 | Sens: 0.7148 | Spec: 0.8969
#
# Models: ('svc', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8192 | Acc: 0.8914 | Sens: 0.7314 | Spec: 0.9070
#  Val - Balanced Acc: 0.8030 | Acc: 0.8862 | Sens: 0.7019 | Spec: 0.9042
#
# Models: ('xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8336 | Acc: 0.8903 | Sens: 0.7647 | Spec: 0.9025
#  Val - Balanced Acc: 0.7995 | Acc: 0.8786 | Sens: 0.7033 | Spec: 0.8956
#
# Models: ('xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8223 | Acc: 0.8821 | Sens: 0.7496 | Spec: 0.8950
#  Val - Balanced Acc: 0.8039 | Acc: 0.8760 | Sens: 0.7162 | Spec: 0.8916
#
# Models: ('xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8348 | Acc: 0.8937 | Sens: 0.7633 | Spec: 0.9064
#  Val - Balanced Acc: 0.8014 | Acc: 0.8831 | Sens: 0.7019 | Spec: 0.9008
#
# Models: ('ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8232 | Acc: 0.8825 | Sens: 0.7511 | Spec: 0.8953
#  Val - Balanced Acc: 0.8054 | Acc: 0.8775 | Sens: 0.7176 | Spec: 0.8931
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8163 | Acc: 0.8940 | Sens: 0.7217 | Spec: 0.9108
#  Val - Balanced Acc: 0.8029 | Acc: 0.8907 | Sens: 0.6961 | Spec: 0.9096
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8196 | Acc: 0.8968 | Sens: 0.7256 | Spec: 0.9135
#  Val - Balanced Acc: 0.8024 | Acc: 0.8921 | Sens: 0.6933 | Spec: 0.9115
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8170 | Acc: 0.8950 | Sens: 0.7221 | Spec: 0.9119
#  Val - Balanced Acc: 0.8032 | Acc: 0.8913 | Sens: 0.6961 | Spec: 0.9103
#
# Models: ('rf', 'lr', 'svc', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8171 | Acc: 0.8949 | Sens: 0.7224 | Spec: 0.9118
#  Val - Balanced Acc: 0.8028 | Acc: 0.8917 | Sens: 0.6947 | Spec: 0.9109
#
# Models: ('rf', 'lr', 'svc', 'ada', 'cat')
#  Train - Balanced Acc: 0.8158 | Acc: 0.8935 | Sens: 0.7213 | Spec: 0.9103
#  Val - Balanced Acc: 0.8037 | Acc: 0.8910 | Sens: 0.6976 | Spec: 0.9099
#
# Models: ('rf', 'lr', 'svc', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8175 | Acc: 0.8957 | Sens: 0.7224 | Spec: 0.9126
#  Val - Balanced Acc: 0.8031 | Acc: 0.8922 | Sens: 0.6947 | Spec: 0.9115
#
# Models: ('rf', 'lr', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8284 | Acc: 0.8920 | Sens: 0.7511 | Spec: 0.9058
#  Val - Balanced Acc: 0.8016 | Acc: 0.8835 | Sens: 0.7019 | Spec: 0.9012
#
# Models: ('rf', 'lr', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8176 | Acc: 0.8872 | Sens: 0.7328 | Spec: 0.9023
#  Val - Balanced Acc: 0.8023 | Acc: 0.8825 | Sens: 0.7047 | Spec: 0.8998
#
# Models: ('rf', 'lr', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8221 | Acc: 0.8923 | Sens: 0.7367 | Spec: 0.9075
#  Val - Balanced Acc: 0.8022 | Acc: 0.8859 | Sens: 0.7004 | Spec: 0.9040
#
# Models: ('rf', 'lr', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8191 | Acc: 0.8892 | Sens: 0.7339 | Spec: 0.9044
#  Val - Balanced Acc: 0.8034 | Acc: 0.8845 | Sens: 0.7047 | Spec: 0.9021
#
# Models: ('rf', 'svc', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8269 | Acc: 0.8921 | Sens: 0.7475 | Spec: 0.9062
#  Val - Balanced Acc: 0.8021 | Acc: 0.8845 | Sens: 0.7019 | Spec: 0.9024
#
# Models: ('rf', 'svc', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8178 | Acc: 0.8885 | Sens: 0.7317 | Spec: 0.9038
#  Val - Balanced Acc: 0.8019 | Acc: 0.8830 | Sens: 0.7033 | Spec: 0.9005
#
# Models: ('rf', 'svc', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8211 | Acc: 0.8929 | Sens: 0.7339 | Spec: 0.9084
#  Val - Balanced Acc: 0.8028 | Acc: 0.8870 | Sens: 0.7005 | Spec: 0.9052
#
# Models: ('rf', 'svc', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8196 | Acc: 0.8909 | Sens: 0.7328 | Spec: 0.9064
#  Val - Balanced Acc: 0.8028 | Acc: 0.8858 | Sens: 0.7019 | Spec: 0.9038
#
# Models: ('rf', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8261 | Acc: 0.8880 | Sens: 0.7507 | Spec: 0.9014
#  Val - Balanced Acc: 0.8019 | Acc: 0.8806 | Sens: 0.7062 | Spec: 0.8976
#
# Models: ('lr', 'svc', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8273 | Acc: 0.8918 | Sens: 0.7489 | Spec: 0.9058
#  Val - Balanced Acc: 0.8016 | Acc: 0.8835 | Sens: 0.7019 | Spec: 0.9012
#
# Models: ('lr', 'svc', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8170 | Acc: 0.8872 | Sens: 0.7317 | Spec: 0.9023
#  Val - Balanced Acc: 0.8023 | Acc: 0.8825 | Sens: 0.7047 | Spec: 0.8998
#
# Models: ('lr', 'svc', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8210 | Acc: 0.8921 | Sens: 0.7346 | Spec: 0.9075
#  Val - Balanced Acc: 0.8022 | Acc: 0.8859 | Sens: 0.7004 | Spec: 0.9040
#
# Models: ('lr', 'svc', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8180 | Acc: 0.8890 | Sens: 0.7317 | Spec: 0.9044
#  Val - Balanced Acc: 0.8034 | Acc: 0.8845 | Sens: 0.7047 | Spec: 0.9021
#
# Models: ('lr', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8264 | Acc: 0.8878 | Sens: 0.7518 | Spec: 0.9011
#  Val - Balanced Acc: 0.8017 | Acc: 0.8802 | Sens: 0.7062 | Spec: 0.8972
#
# Models: ('svc', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8255 | Acc: 0.8879 | Sens: 0.7496 | Spec: 0.9014
#  Val - Balanced Acc: 0.8019 | Acc: 0.8806 | Sens: 0.7062 | Spec: 0.8976
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8194 | Acc: 0.8909 | Sens: 0.7324 | Spec: 0.9064
#  Val - Balanced Acc: 0.8027 | Acc: 0.8856 | Sens: 0.7019 | Spec: 0.9035
#
# === Best Model Combination ===
# Models: ('rf', 'ada', 'cat')
#  Train - Balanced Acc: 0.8153 | Acc: 0.8833 | Sens: 0.7324 | Spec: 0.8981
#    Val - Balanced Acc: 0.8058 | Acc: 0.8807 | Sens: 0.7148 | Spec: 0.8969

# %% [markdown]
# ##### Test

# %%
# 取得最佳參數
best_estimators = [(name, models[name]) for name in best_result['models']]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 119                  56
# Actual Negative                 180                1607
# Sensitivity (Recall, TPR): 0.6800
# Specificity (TNR):         0.8993
# Accuracy:                  0.8797
# Balanced Accuracy:         0.7896
# F1 Score:         0.5021

# %%
from scipy.stats import mode
class VotingClassifierWithTieBreaker(VotingClassifier):
    def predict(self, X):
        """
        自訂 hard voting 的 predict 方法：
        - 若 0 和 1 票數相同，預測為 1。
        """
        # 預測每個子模型的結果，轉成 (n_samples, n_classifiers)
        predictions = np.asarray([clf.predict(X) for clf in self.estimators_]).T

        majority_votes = []
        for row in predictions:
            vote_counts = np.bincount(row, minlength=2)
            # 強制在平手時猜 1
            majority_votes.append(0 if vote_counts[0] > vote_counts[1] else 1)

        return np.array(majority_votes)

# %%
from sklearn.ensemble import VotingClassifier
from itertools import combinations
# 定義 base 模型
models = {
    'rf': rf_clf,
    'lr': lr_clf,
    'svc': svc_clf,
    'xgb': xgb_clf,
    'ada': ada_clf,
    'lgb': lgb_clf,
    'cat': cat_clf,
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = []

for r in range(2, len(models), 2):
    for subset in combinations(models.items(), r):
        clf_names, clf_list = zip(*subset)

        eclf = VotingClassifierWithTieBreaker(
            estimators=list(subset),
            voting='hard',
            n_jobs=-1
        )

        train_bal_accs, train_accs, train_sens, train_spec = [], [], [], []
        val_bal_accs, val_accs, val_sens, val_spec = [], [], [], []

        for train_idx, val_idx in cv.split(x, y):
            x_train_fold, y_train_fold = x.iloc[train_idx], y.iloc[train_idx]
            x_val_fold, y_val_fold     = x.iloc[val_idx], y.iloc[val_idx]

            eclf.fit(x_train_fold, y_train_fold)

            # 預測
            y_train_pred = eclf.predict(x_train_fold)
            y_val_pred = eclf.predict(x_val_fold)

            # === Train metrics ===
            train_bal_accs.append(balanced_accuracy_score(y_train_fold, y_train_pred))
            train_accs.append(accuracy_score(y_train_fold, y_train_pred))
            train_sens.append(recall_score(y_train_fold, y_train_pred, pos_label=1))
            train_spec.append(recall_score(y_train_fold, y_train_pred, pos_label=0))

            # === Val metrics ===
            val_bal_accs.append(balanced_accuracy_score(y_val_fold, y_val_pred))
            val_accs.append(accuracy_score(y_val_fold, y_val_pred))
            val_sens.append(recall_score(y_val_fold, y_val_pred, pos_label=1))
            val_spec.append(recall_score(y_val_fold, y_val_pred, pos_label=0))

        # 平均結果
        result = {
            'models': clf_names,
            'train_bal_acc': np.mean(train_bal_accs),
            'train_acc': np.mean(train_accs),
            'train_sens': np.mean(train_sens),
            'train_spec': np.mean(train_spec),
            'val_bal_acc': np.mean(val_bal_accs),
            'val_acc': np.mean(val_accs),
            'val_sens': np.mean(val_sens),
            'val_spec': np.mean(val_spec),
        }

        results.append(result)

        # 輸出格式化結果
        print(f"Models: {clf_names}")
        print(f" Train - Balanced Acc: {result['train_bal_acc']:.4f} | Acc: {result['train_acc']:.4f} | Sens: {result['train_sens']:.4f} | Spec: {result['train_spec']:.4f}")
        print(f" Val - Balanced Acc: {result['val_bal_acc']:.4f} | Acc: {result['val_acc']:.4f} | Sens: {result['val_sens']:.4f} | Spec: {result['val_spec']:.4f}")
        print("")

# 選出最佳組合（以 val_bal_acc 為主）
best_result = max(results, key=lambda r: r['val_bal_acc'])

print("=== Best Model Combination ===")
print(f"Models: {best_result['models']}")
print(f" Train - Balanced Acc: {best_result['train_bal_acc']:.4f} | Acc: {best_result['train_acc']:.4f} | Sens: {best_result['train_sens']:.4f} | Spec: {best_result['train_spec']:.4f}")
print(f"   Val - Balanced Acc: {best_result['val_bal_acc']:.4f} | Acc: {best_result['val_acc']:.4f} | Sens: {best_result['val_sens']:.4f} | Spec: {best_result['val_spec']:.4f}")
# Out:
# Models: ('rf', 'lr')
#  Train - Balanced Acc: 0.8161 | Acc: 0.8819 | Sens: 0.7360 | Spec: 0.8961
#  Val - Balanced Acc: 0.8041 | Acc: 0.8800 | Sens: 0.7119 | Spec: 0.8963
#
# Models: ('rf', 'svc')
#  Train - Balanced Acc: 0.8179 | Acc: 0.8981 | Sens: 0.7203 | Spec: 0.9155
#  Val - Balanced Acc: 0.8015 | Acc: 0.8951 | Sens: 0.6876 | Spec: 0.9154
#
# Models: ('rf', 'xgb')
#  Train - Balanced Acc: 0.8319 | Acc: 0.8875 | Sens: 0.7643 | Spec: 0.8995
#  Val - Balanced Acc: 0.8000 | Acc: 0.8771 | Sens: 0.7062 | Spec: 0.8938
#
# Models: ('rf', 'ada')
#  Train - Balanced Acc: 0.8074 | Acc: 0.8538 | Sens: 0.7511 | Spec: 0.8638
#  Val - Balanced Acc: 0.8046 | Acc: 0.8537 | Sens: 0.7449 | Spec: 0.8643
#
# Models: ('rf', 'lgb')
#  Train - Balanced Acc: 0.8555 | Acc: 0.8943 | Sens: 0.8084 | Spec: 0.9026
#  Val - Balanced Acc: 0.8031 | Acc: 0.8816 | Sens: 0.7076 | Spec: 0.8986
#
# Models: ('rf', 'cat')
#  Train - Balanced Acc: 0.8166 | Acc: 0.8835 | Sens: 0.7353 | Spec: 0.8980
#  Val - Balanced Acc: 0.8058 | Acc: 0.8807 | Sens: 0.7148 | Spec: 0.8969
#
# Models: ('lr', 'svc')
#  Train - Balanced Acc: 0.8088 | Acc: 0.8808 | Sens: 0.7213 | Spec: 0.8963
#  Val - Balanced Acc: 0.8050 | Acc: 0.8803 | Sens: 0.7133 | Spec: 0.8966
#
# Models: ('lr', 'xgb')
#  Train - Balanced Acc: 0.8297 | Acc: 0.8764 | Sens: 0.7729 | Spec: 0.8865
#  Val - Balanced Acc: 0.8004 | Acc: 0.8672 | Sens: 0.7190 | Spec: 0.8817
#
# Models: ('lr', 'ada')
#  Train - Balanced Acc: 0.8069 | Acc: 0.8437 | Sens: 0.7622 | Spec: 0.8517
#  Val - Balanced Acc: 0.8052 | Acc: 0.8443 | Sens: 0.7578 | Spec: 0.8527
#
# Models: ('lr', 'lgb')
#  Train - Balanced Acc: 0.8513 | Acc: 0.8820 | Sens: 0.8141 | Spec: 0.8886
#  Val - Balanced Acc: 0.8035 | Acc: 0.8705 | Sens: 0.7219 | Spec: 0.8850
#
# Models: ('lr', 'cat')
#  Train - Balanced Acc: 0.8150 | Acc: 0.8720 | Sens: 0.7457 | Spec: 0.8843
#  Val - Balanced Acc: 0.8063 | Acc: 0.8698 | Sens: 0.7291 | Spec: 0.8835
#
# Models: ('svc', 'xgb')
#  Train - Balanced Acc: 0.8316 | Acc: 0.8874 | Sens: 0.7636 | Spec: 0.8995
#  Val - Balanced Acc: 0.8007 | Acc: 0.8773 | Sens: 0.7076 | Spec: 0.8938
#
# Models: ('svc', 'ada')
#  Train - Balanced Acc: 0.8067 | Acc: 0.8536 | Sens: 0.7496 | Spec: 0.8638
#  Val - Balanced Acc: 0.8053 | Acc: 0.8538 | Sens: 0.7464 | Spec: 0.8643
#
# Models: ('svc', 'lgb')
#  Train - Balanced Acc: 0.8553 | Acc: 0.8942 | Sens: 0.8080 | Spec: 0.9026
#  Val - Balanced Acc: 0.8038 | Acc: 0.8817 | Sens: 0.7090 | Spec: 0.8986
#
# Models: ('svc', 'cat')
#  Train - Balanced Acc: 0.8150 | Acc: 0.8832 | Sens: 0.7321 | Spec: 0.8979
#  Val - Balanced Acc: 0.8066 | Acc: 0.8808 | Sens: 0.7162 | Spec: 0.8969
#
# Models: ('xgb', 'ada')
#  Train - Balanced Acc: 0.8150 | Acc: 0.8545 | Sens: 0.7668 | Spec: 0.8631
#  Val - Balanced Acc: 0.8048 | Acc: 0.8529 | Sens: 0.7464 | Spec: 0.8633
#
# Models: ('xgb', 'lgb')
#  Train - Balanced Acc: 0.8559 | Acc: 0.8935 | Sens: 0.8102 | Spec: 0.9016
#  Val - Balanced Acc: 0.7994 | Acc: 0.8771 | Sens: 0.7047 | Spec: 0.8940
#
# Models: ('xgb', 'cat')
#  Train - Balanced Acc: 0.8295 | Acc: 0.8828 | Sens: 0.7647 | Spec: 0.8943
#  Val - Balanced Acc: 0.8041 | Acc: 0.8752 | Sens: 0.7176 | Spec: 0.8906
#
# Models: ('ada', 'lgb')
#  Train - Balanced Acc: 0.8364 | Acc: 0.8586 | Sens: 0.8095 | Spec: 0.8634
#  Val - Balanced Acc: 0.8056 | Acc: 0.8531 | Sens: 0.7478 | Spec: 0.8633
#
# Models: ('ada', 'cat')
#  Train - Balanced Acc: 0.8077 | Acc: 0.8537 | Sens: 0.7518 | Spec: 0.8637
#  Val - Balanced Acc: 0.8046 | Acc: 0.8537 | Sens: 0.7449 | Spec: 0.8643
#
# Models: ('lgb', 'cat')
#  Train - Balanced Acc: 0.8518 | Acc: 0.8872 | Sens: 0.8087 | Spec: 0.8948
#  Val - Balanced Acc: 0.8063 | Acc: 0.8769 | Sens: 0.7205 | Spec: 0.8921
#
# Models: ('rf', 'lr', 'svc', 'xgb')
#  Train - Balanced Acc: 0.8187 | Acc: 0.8943 | Sens: 0.7267 | Spec: 0.9107
#  Val - Balanced Acc: 0.8028 | Acc: 0.8904 | Sens: 0.6961 | Spec: 0.9094
#
# Models: ('rf', 'lr', 'svc', 'ada')
#  Train - Balanced Acc: 0.8155 | Acc: 0.8917 | Sens: 0.7228 | Spec: 0.9082
#  Val - Balanced Acc: 0.8035 | Acc: 0.8894 | Sens: 0.6990 | Spec: 0.9080
#
# Models: ('rf', 'lr', 'svc', 'lgb')
#  Train - Balanced Acc: 0.8206 | Acc: 0.8954 | Sens: 0.7296 | Spec: 0.9116
#  Val - Balanced Acc: 0.8033 | Acc: 0.8914 | Sens: 0.6961 | Spec: 0.9105
#
# Models: ('rf', 'lr', 'svc', 'cat')
#  Train - Balanced Acc: 0.8165 | Acc: 0.8935 | Sens: 0.7228 | Spec: 0.9102
#  Val - Balanced Acc: 0.8037 | Acc: 0.8910 | Sens: 0.6976 | Spec: 0.9099
#
# Models: ('rf', 'lr', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8248 | Acc: 0.8846 | Sens: 0.7521 | Spec: 0.8975
#  Val - Balanced Acc: 0.8002 | Acc: 0.8764 | Sens: 0.7076 | Spec: 0.8928
#
# Models: ('rf', 'lr', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8361 | Acc: 0.8931 | Sens: 0.7668 | Spec: 0.9054
#  Val - Balanced Acc: 0.8028 | Acc: 0.8834 | Sens: 0.7047 | Spec: 0.9008
#
# Models: ('rf', 'lr', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8200 | Acc: 0.8876 | Sens: 0.7378 | Spec: 0.9022
#  Val - Balanced Acc: 0.8022 | Acc: 0.8822 | Sens: 0.7047 | Spec: 0.8996
#
# Models: ('rf', 'lr', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8277 | Acc: 0.8866 | Sens: 0.7561 | Spec: 0.8994
#  Val - Balanced Acc: 0.8033 | Acc: 0.8797 | Sens: 0.7105 | Spec: 0.8962
#
# Models: ('rf', 'lr', 'ada', 'cat')
#  Train - Balanced Acc: 0.8151 | Acc: 0.8816 | Sens: 0.7342 | Spec: 0.8960
#  Val - Balanced Acc: 0.8056 | Acc: 0.8791 | Sens: 0.7162 | Spec: 0.8949
#
# Models: ('rf', 'lr', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8226 | Acc: 0.8897 | Sens: 0.7410 | Spec: 0.9042
#  Val - Balanced Acc: 0.8039 | Acc: 0.8843 | Sens: 0.7062 | Spec: 0.9017
#
# Models: ('rf', 'svc', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8240 | Acc: 0.8867 | Sens: 0.7478 | Spec: 0.9002
#  Val - Balanced Acc: 0.7998 | Acc: 0.8779 | Sens: 0.7047 | Spec: 0.8948
#
# Models: ('rf', 'svc', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8344 | Acc: 0.8934 | Sens: 0.7625 | Spec: 0.9062
#  Val - Balanced Acc: 0.8028 | Acc: 0.8845 | Sens: 0.7033 | Spec: 0.9022
#
# Models: ('rf', 'svc', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8190 | Acc: 0.8887 | Sens: 0.7342 | Spec: 0.9038
#  Val - Balanced Acc: 0.8019 | Acc: 0.8830 | Sens: 0.7033 | Spec: 0.9005
#
# Models: ('rf', 'svc', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8265 | Acc: 0.8894 | Sens: 0.7500 | Spec: 0.9030
#  Val - Balanced Acc: 0.8022 | Acc: 0.8822 | Sens: 0.7047 | Spec: 0.8996
#
# Models: ('rf', 'svc', 'ada', 'cat')
#  Train - Balanced Acc: 0.8156 | Acc: 0.8834 | Sens: 0.7332 | Spec: 0.8981
#  Val - Balanced Acc: 0.8058 | Acc: 0.8807 | Sens: 0.7148 | Spec: 0.8969
#
# Models: ('rf', 'svc', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8210 | Acc: 0.8912 | Sens: 0.7357 | Spec: 0.9064
#  Val - Balanced Acc: 0.8028 | Acc: 0.8858 | Sens: 0.7019 | Spec: 0.9038
#
# Models: ('rf', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8310 | Acc: 0.8852 | Sens: 0.7650 | Spec: 0.8969
#  Val - Balanced Acc: 0.8005 | Acc: 0.8756 | Sens: 0.7090 | Spec: 0.8919
#
# Models: ('rf', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8226 | Acc: 0.8816 | Sens: 0.7507 | Spec: 0.8944
#  Val - Balanced Acc: 0.8037 | Acc: 0.8756 | Sens: 0.7162 | Spec: 0.8912
#
# Models: ('rf', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8326 | Acc: 0.8891 | Sens: 0.7640 | Spec: 0.9013
#  Val - Balanced Acc: 0.8025 | Acc: 0.8806 | Sens: 0.7076 | Spec: 0.8975
#
# Models: ('rf', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8234 | Acc: 0.8820 | Sens: 0.7521 | Spec: 0.8947
#  Val - Balanced Acc: 0.8052 | Acc: 0.8771 | Sens: 0.7176 | Spec: 0.8927
#
# Models: ('lr', 'svc', 'xgb', 'ada')
#  Train - Balanced Acc: 0.8239 | Acc: 0.8844 | Sens: 0.7504 | Spec: 0.8975
#  Val - Balanced Acc: 0.8002 | Acc: 0.8764 | Sens: 0.7076 | Spec: 0.8928
#
# Models: ('lr', 'svc', 'xgb', 'lgb')
#  Train - Balanced Acc: 0.8357 | Acc: 0.8930 | Sens: 0.7661 | Spec: 0.9054
#  Val - Balanced Acc: 0.8028 | Acc: 0.8834 | Sens: 0.7047 | Spec: 0.9008
#
# Models: ('lr', 'svc', 'xgb', 'cat')
#  Train - Balanced Acc: 0.8191 | Acc: 0.8874 | Sens: 0.7360 | Spec: 0.9022
#  Val - Balanced Acc: 0.8022 | Acc: 0.8822 | Sens: 0.7047 | Spec: 0.8996
#
# Models: ('lr', 'svc', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8270 | Acc: 0.8865 | Sens: 0.7547 | Spec: 0.8993
#  Val - Balanced Acc: 0.8033 | Acc: 0.8797 | Sens: 0.7105 | Spec: 0.8962
#
# Models: ('lr', 'svc', 'ada', 'cat')
#  Train - Balanced Acc: 0.8142 | Acc: 0.8814 | Sens: 0.7324 | Spec: 0.8960
#  Val - Balanced Acc: 0.8056 | Acc: 0.8791 | Sens: 0.7162 | Spec: 0.8949
#
# Models: ('lr', 'svc', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8215 | Acc: 0.8894 | Sens: 0.7389 | Spec: 0.9041
#  Val - Balanced Acc: 0.8039 | Acc: 0.8843 | Sens: 0.7062 | Spec: 0.9017
#
# Models: ('lr', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8324 | Acc: 0.8845 | Sens: 0.7690 | Spec: 0.8958
#  Val - Balanced Acc: 0.8012 | Acc: 0.8746 | Sens: 0.7119 | Spec: 0.8905
#
# Models: ('lr', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8229 | Acc: 0.8808 | Sens: 0.7525 | Spec: 0.8934
#  Val - Balanced Acc: 0.8036 | Acc: 0.8743 | Sens: 0.7176 | Spec: 0.8896
#
# Models: ('lr', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8342 | Acc: 0.8889 | Sens: 0.7676 | Spec: 0.9008
#  Val - Balanced Acc: 0.8029 | Acc: 0.8801 | Sens: 0.7090 | Spec: 0.8968
#
# Models: ('lr', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8251 | Acc: 0.8812 | Sens: 0.7568 | Spec: 0.8933
#  Val - Balanced Acc: 0.8057 | Acc: 0.8757 | Sens: 0.7205 | Spec: 0.8909
#
# Models: ('svc', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8308 | Acc: 0.8852 | Sens: 0.7647 | Spec: 0.8969
#  Val - Balanced Acc: 0.8005 | Acc: 0.8756 | Sens: 0.7090 | Spec: 0.8919
#
# Models: ('svc', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8220 | Acc: 0.8815 | Sens: 0.7496 | Spec: 0.8944
#  Val - Balanced Acc: 0.8037 | Acc: 0.8756 | Sens: 0.7162 | Spec: 0.8912
#
# Models: ('svc', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8323 | Acc: 0.8890 | Sens: 0.7633 | Spec: 0.9013
#  Val - Balanced Acc: 0.8025 | Acc: 0.8806 | Sens: 0.7076 | Spec: 0.8975
#
# Models: ('svc', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8229 | Acc: 0.8819 | Sens: 0.7511 | Spec: 0.8947
#  Val - Balanced Acc: 0.8052 | Acc: 0.8771 | Sens: 0.7176 | Spec: 0.8927
#
# Models: ('xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8289 | Acc: 0.8817 | Sens: 0.7647 | Spec: 0.8931
#  Val - Balanced Acc: 0.8044 | Acc: 0.8745 | Sens: 0.7191 | Spec: 0.8896
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'ada', 'lgb')
#  Train - Balanced Acc: 0.8278 | Acc: 0.8908 | Sens: 0.7511 | Spec: 0.9045
#  Val - Balanced Acc: 0.8020 | Acc: 0.8831 | Sens: 0.7033 | Spec: 0.9007
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'ada', 'cat')
#  Train - Balanced Acc: 0.8174 | Acc: 0.8869 | Sens: 0.7328 | Spec: 0.9019
#  Val - Balanced Acc: 0.8022 | Acc: 0.8824 | Sens: 0.7047 | Spec: 0.8997
#
# Models: ('rf', 'lr', 'svc', 'xgb', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8215 | Acc: 0.8913 | Sens: 0.7367 | Spec: 0.9064
#  Val - Balanced Acc: 0.8026 | Acc: 0.8854 | Sens: 0.7019 | Spec: 0.9033
#
# Models: ('rf', 'lr', 'svc', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8189 | Acc: 0.8888 | Sens: 0.7339 | Spec: 0.9040
#  Val - Balanced Acc: 0.8033 | Acc: 0.8844 | Sens: 0.7047 | Spec: 0.9019
#
# Models: ('rf', 'lr', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8266 | Acc: 0.8869 | Sens: 0.7532 | Spec: 0.9000
#  Val - Balanced Acc: 0.8020 | Acc: 0.8797 | Sens: 0.7076 | Spec: 0.8965
#
# Models: ('rf', 'svc', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8258 | Acc: 0.8875 | Sens: 0.7507 | Spec: 0.9008
#  Val - Balanced Acc: 0.8017 | Acc: 0.8802 | Sens: 0.7062 | Spec: 0.8972
#
# Models: ('lr', 'svc', 'xgb', 'ada', 'lgb', 'cat')
#  Train - Balanced Acc: 0.8259 | Acc: 0.8868 | Sens: 0.7518 | Spec: 0.9000
#  Val - Balanced Acc: 0.8020 | Acc: 0.8797 | Sens: 0.7076 | Spec: 0.8965
#
# === Best Model Combination ===
# Models: ('svc', 'cat')
#  Train - Balanced Acc: 0.8150 | Acc: 0.8832 | Sens: 0.7321 | Spec: 0.8979
#    Val - Balanced Acc: 0.8066 | Acc: 0.8808 | Sens: 0.7162 | Spec: 0.8969

# %%
# 取得最佳參數
best_estimators = [(name, models[name]) for name in best_result['models']]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 119                  56
# Actual Negative                 180                1607
# Sensitivity (Recall, TPR): 0.6800
# Specificity (TNR):         0.8993
# Accuracy:                  0.8797
# Balanced Accuracy:         0.7896
# F1 Score:         0.5021

# %%
# 取得最佳參數
selected_models = ('xgb', 'lgb', 'cat')
# selected_models = ('ada', 'lgb', 'cat')
# selected_models = ('xgb', 'ada', 'cat')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 120                  55
# Actual Negative                 172                1615
# Sensitivity (Recall, TPR): 0.6857
# Specificity (TNR):         0.9037
# Accuracy:                  0.8843
# Balanced Accuracy:         0.7947
# F1 Score:         0.5139

# %%
# 取得最佳參數
selected_models = ('ada', 'lgb', 'cat')
# selected_models = ('xgb', 'ada', 'cat')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 123                  52
# Actual Negative                 189                1598
# Sensitivity (Recall, TPR): 0.7029
# Specificity (TNR):         0.8942
# Accuracy:                  0.8772
# Balanced Accuracy:         0.7985
# F1 Score:         0.5051

# %%
# 取得最佳參數
selected_models = ('xgb', 'ada', 'cat')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifier(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 121                  54
# Actual Negative                 190                1597
# Sensitivity (Recall, TPR): 0.6914
# Specificity (TNR):         0.8937
# Accuracy:                  0.8756
# Balanced Accuracy:         0.7926
# F1 Score:         0.4979

# %%
# 取得最佳參數
selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 127                  48
# Actual Negative                 247                1540
# Sensitivity (Recall, TPR): 0.7257
# Specificity (TNR):         0.8618
# Accuracy:                  0.8496
# Balanced Accuracy:         0.7937
# F1 Score:         0.4627

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 122                  53
# Actual Negative                 183                1604
# Sensitivity (Recall, TPR): 0.6971
# Specificity (TNR):         0.8976
# Accuracy:                  0.8797
# Balanced Accuracy:         0.7974
# F1 Score:         0.5083

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 121                  54
# Actual Negative                 191                1596
# Sensitivity (Recall, TPR): 0.6914
# Specificity (TNR):         0.8931
# Accuracy:                  0.8751
# Balanced Accuracy:         0.7923
# F1 Score:         0.4969

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 123                  52
# Actual Negative                 190                1597
# Sensitivity (Recall, TPR): 0.7029
# Specificity (TNR):         0.8937
# Accuracy:                  0.8767
# Balanced Accuracy:         0.7983
# F1 Score:         0.5041

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
selected_models = ('ada', 'xgb')
#selected_models = ('ada', 'lgb', 'cat' 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 127                  48
# Actual Negative                 247                1540
# Sensitivity (Recall, TPR): 0.7257
# Specificity (TNR):         0.8618
# Accuracy:                  0.8496
# Balanced Accuracy:         0.7937
# F1 Score:         0.4627

# %%
# 取得最佳參數
#selected_models = ('ada', 'lgb')
#selected_models = ('xgb', 'lgb')
#selected_models = ('xgb', 'cat')
#selected_models = ('lgb', 'cat')
#selected_models = ('ada', 'cat')
#selected_models = ('ada', 'xgb')
selected_models = ('ada', 'lgb', 'cat', 'xgb')
best_estimators = [(name, models[name]) for name in selected_models]
final_model = VotingClassifierWithTieBreaker(
            estimators=best_estimators,
            voting='hard',
            n_jobs=-1
        )


final_model.fit(x, y)


# 預測
y_test_pred = final_model.predict(X_test)                  # 分類標籤

# 混淆矩陣
from sklearn.metrics import confusion_matrix, roc_auc_score

cm = confusion_matrix(y_test, y_test_pred)
tn, fp, fn, tp = cm.ravel()

# 指標計算
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
accuracy = (tp + tn) / (tp + tn + fp + fn)
balanced_acc = (sensitivity + specificity) / 2
f1 = f1_score(y_test, y_test_pred, zero_division=0)

# 轉成 DataFrame (Wikipedia 標準)
confusion_df = pd.DataFrame(
    data=[[tp, fn], [fp, tn]],
    index=["Actual Positive", "Actual Negative"],
    columns=["Predicted Positive", "Predicted Negative"]
)

print("\n✅ Confusion Matrix (DataFrame, Wikipedia format):")
print(confusion_df)

# 顯示結果
print(f"Sensitivity (Recall, TPR): {sensitivity:.4f}")
print(f"Specificity (TNR):         {specificity:.4f}")
print(f"Accuracy:                  {accuracy:.4f}")
print(f"Balanced Accuracy:         {balanced_acc:.4f}")
print(f"F1 Score:         {f1:.4f}")
# Out:
# ✅ Confusion Matrix (DataFrame, Wikipedia format):
#                  Predicted Positive  Predicted Negative
# Actual Positive                 123                  52
# Actual Negative                 194                1593
# Sensitivity (Recall, TPR): 0.7029
# Specificity (TNR):         0.8914
# Accuracy:                  0.8746
# Balanced Accuracy:         0.7971
# F1 Score:         0.5000
